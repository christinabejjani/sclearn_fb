# %% [markdown]
# For some reason, the jupyter magic used to call the R script in the Python Jupyter notebook is calling R version 3.4.3, which I do not even have installed on my computer. So, in the meantime, I will run these R scripts in an actual 3.5.1 notebook...

# %%
setwd("C:/Users/cb383/Desktop/YearThree/controllearning/fbproject/LWPCfb_rep/data/csvdata")

# %%
library(afex)
# Out:
# Warning message:
# "package 'afex' was built under R version 3.5.3"Loading required package: lme4
# Loading required package: Matrix
# ************
# Welcome to afex. For support visit: http://afex.singmann.science/
# - Functions for ANOVAs: aov_car(), aov_ez(), and aov_4()
# - Methods for calculating p-values with mixed(): 'KR', 'S', 'LRT', and 'PB'
# - 'afex_aov' and 'mixed' objects can be passed to emmeans() for follow-up tests
# - NEWS: library('emmeans') now needs to be called explicitly!
# - Get and set global package options with: afex_options()
# - Set orthogonal sum-to-zero contrasts globally: set_sum_contrasts()
# - For example analyses see: browseVignettes("afex")
# ************
#
# Attaching package: 'afex'
#
# The following object is masked from 'package:lme4':
#
#     lmer

# %%
rawRTData <- read.csv('SC_ANOVA_RT.csv')
aov_car(RT ~ Feedback * BlockOrder + Error(subject/(Congruency*BlockType)), data = rawRTData, anova_table = list(es = "pes"))
# Out:
# Contrasts set to contr.sum for the following variables: Feedback, BlockOrder
# Anova Table (Type 3 tests)
#
# Response: RT
#                                      Effect     df      MSE         F   pes
# 1                                  Feedback 1, 116 20484.82      0.81  .007
# 2                                BlockOrder 1, 116 20484.82      1.99   .02
# 3                       Feedback:BlockOrder 1, 116 20484.82      0.64  .005
# 4                                Congruency 1, 116   468.78 68.34 ***   .37
# 5                       Feedback:Congruency 1, 116   468.78    4.27 *   .04
# 6                     BlockOrder:Congruency 1, 116   468.78      0.09 .0008
# 7            Feedback:BlockOrder:Congruency 1, 116   468.78      0.02 .0002
# 8                                 BlockType 1, 116  1049.96      1.12  .010
# 9                        Feedback:BlockType 1, 116  1049.96      0.13  .001
# 10                     BlockOrder:BlockType 1, 116  1049.96 31.45 ***   .21
# 11            Feedback:BlockOrder:BlockType 1, 116  1049.96      0.31  .003
# 12                     Congruency:BlockType 1, 116   459.58 18.68 ***   .14
# 13            Feedback:Congruency:BlockType 1, 116   459.58      0.25  .002
# 14          BlockOrder:Congruency:BlockType 1, 116   459.58      0.80  .007
# 15 Feedback:BlockOrder:Congruency:BlockType 1, 116   459.58    3.22 +   .03
#    p.value
# 1      .37
# 2      .16
# 3      .43
# 4   <.0001
# 5      .04
# 6      .76
# 7      .88
# 8      .29
# 9      .72
# 10  <.0001
# 11     .58
# 12  <.0001
# 13     .62
# 14     .37
# 15     .08
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '+' 0.1 ' ' 1

# %%
rawACCData <- read.csv('SC_ANOVA_ACC.csv')
aov_car(Accuracy ~ Feedback * BlockOrder + Error(subject/(Congruency*BlockType)), data = rawACCData, anova_table = list(es = "pes"))
# Out:
# Contrasts set to contr.sum for the following variables: Feedback, BlockOrder
# Anova Table (Type 3 tests)
#
# Response: Accuracy
#                                      Effect     df  MSE         F    pes
# 1                                  Feedback 1, 116 0.02      0.00 <.0001
# 2                                BlockOrder 1, 116 0.02      1.69    .01
# 3                       Feedback:BlockOrder 1, 116 0.02      0.16   .001
# 4                                Congruency 1, 116 0.00 37.89 ***    .25
# 5                       Feedback:Congruency 1, 116 0.00      1.90    .02
# 6                     BlockOrder:Congruency 1, 116 0.00      0.31   .003
# 7            Feedback:BlockOrder:Congruency 1, 116 0.00      0.32   .003
# 8                                 BlockType 1, 116 0.01      1.36    .01
# 9                        Feedback:BlockType 1, 116 0.01      0.10  .0009
# 10                     BlockOrder:BlockType 1, 116 0.01      1.36    .01
# 11            Feedback:BlockOrder:BlockType 1, 116 0.01      0.28   .002
# 12                     Congruency:BlockType 1, 116 0.00 36.04 ***    .24
# 13            Feedback:Congruency:BlockType 1, 116 0.00    4.46 *    .04
# 14          BlockOrder:Congruency:BlockType 1, 116 0.00    4.15 *    .03
# 15 Feedback:BlockOrder:Congruency:BlockType 1, 116 0.00      0.46   .004
#    p.value
# 1      .97
# 2      .20
# 3      .69
# 4   <.0001
# 5      .17
# 6      .58
# 7      .57
# 8      .25
# 9      .75
# 10     .25
# 11     .60
# 12  <.0001
# 13     .04
# 14     .04
# 15     .50
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '+' 0.1 ' ' 1

# %%
rawIEData <- read.csv('IE_Main.csv')
aov_car(IE ~ Feedback * BlockOrder + Error(SubjectID/(TrialType*CueType)), data = rawIEData, anova_table = list(es = "pes"))
# Out:
# Contrasts set to contr.sum for the following variables: Feedback, BlockOrder
# Anova Table (Type 3 tests)
#
# Response: IE
#                                   Effect     df      MSE         F    pes
# 1                               Feedback 1, 116 68722.56      0.06  .0005
# 2                             BlockOrder 1, 116 68722.56      2.23    .02
# 3                    Feedback:BlockOrder 1, 116 68722.56      0.46   .004
# 4                              TrialType 1, 116  7814.37 41.58 ***    .26
# 5                     Feedback:TrialType 1, 116  7814.37      1.93    .02
# 6                   BlockOrder:TrialType 1, 116  7814.37      0.27   .002
# 7          Feedback:BlockOrder:TrialType 1, 116  7814.37      0.53   .005
# 8                                CueType 1, 116 14020.91      2.14    .02
# 9                       Feedback:CueType 1, 116 14020.91      0.19   .002
# 10                    BlockOrder:CueType 1, 116 14020.91    5.07 *    .04
# 11           Feedback:BlockOrder:CueType 1, 116 14020.91      0.16   .001
# 12                     TrialType:CueType 1, 116  8033.45 29.04 ***    .20
# 13            Feedback:TrialType:CueType 1, 116  8033.45      0.97   .008
# 14          BlockOrder:TrialType:CueType 1, 116  8033.45      1.51    .01
# 15 Feedback:BlockOrder:TrialType:CueType 1, 116  8033.45      0.00 <.0001
#    p.value
# 1      .81
# 2      .14
# 3      .50
# 4   <.0001
# 5      .17
# 6      .60
# 7      .47
# 8      .15
# 9      .66
# 10     .03
# 11     .69
# 12  <.0001
# 13     .33
# 14     .22
# 15     .96
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '+' 0.1 ' ' 1

# %% [markdown]
# What about transfer?

# %%
rawRTData_T <- read.csv('SCT_ANOVA_RT.csv')
aov_car(RT ~ Feedback * BlockOrder + Error(subject/(Congruency*BlockType)), data = rawRTData_T, anova_table = list(es = "pes"))
# Out:
# Contrasts set to contr.sum for the following variables: Feedback, BlockOrder
# Anova Table (Type 3 tests)
#
# Response: RT
#                                      Effect     df      MSE         F    pes
# 1                                  Feedback 1, 116 19580.19      0.36   .003
# 2                                BlockOrder 1, 116 19580.19      1.98    .02
# 3                       Feedback:BlockOrder 1, 116 19580.19      0.54   .005
# 4                                Congruency 1, 116   418.39 93.35 ***    .45
# 5                       Feedback:Congruency 1, 116   418.39      0.64   .006
# 6                     BlockOrder:Congruency 1, 116   418.39      0.00 <.0001
# 7            Feedback:BlockOrder:Congruency 1, 116   418.39      0.06  .0005
# 8                                 BlockType 1, 116   690.03   8.56 **    .07
# 9                        Feedback:BlockType 1, 116   690.03      0.88   .008
# 10                     BlockOrder:BlockType 1, 116   690.03  10.09 **    .08
# 11            Feedback:BlockOrder:BlockType 1, 116   690.03      0.15   .001
# 12                     Congruency:BlockType 1, 116   175.20    4.88 *    .04
# 13            Feedback:Congruency:BlockType 1, 116   175.20    4.31 *    .04
# 14          BlockOrder:Congruency:BlockType 1, 116   175.20      0.12  .0010
# 15 Feedback:BlockOrder:Congruency:BlockType 1, 116   175.20      0.50   .004
#    p.value
# 1      .55
# 2      .16
# 3      .46
# 4   <.0001
# 5      .42
# 6     >.99
# 7      .81
# 8     .004
# 9      .35
# 10    .002
# 11     .70
# 12     .03
# 13     .04
# 14     .73
# 15     .48
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '+' 0.1 ' ' 1

# %%
rawACCData_T <- read.csv('SCT_ANOVA_ACC.csv')
aov_car(Accuracy ~ Feedback * BlockOrder + Error(subject/(Congruency*BlockType)), data = rawACCData_T, anova_table = list(es = "pes"))
# Out:
# Contrasts set to contr.sum for the following variables: Feedback, BlockOrder
# Anova Table (Type 3 tests)
#
# Response: Accuracy
#                                      Effect     df  MSE         F    pes
# 1                                  Feedback 1, 116 0.03      0.09  .0008
# 2                                BlockOrder 1, 116 0.03    3.75 +    .03
# 3                       Feedback:BlockOrder 1, 116 0.03      0.00 <.0001
# 4                                Congruency 1, 116 0.00 16.46 ***    .12
# 5                       Feedback:Congruency 1, 116 0.00      0.18   .002
# 6                     BlockOrder:Congruency 1, 116 0.00      0.18   .002
# 7            Feedback:BlockOrder:Congruency 1, 116 0.00      0.25   .002
# 8                                 BlockType 1, 116 0.01      0.74   .006
# 9                        Feedback:BlockType 1, 116 0.01      2.33    .02
# 10                     BlockOrder:BlockType 1, 116 0.01    4.99 *    .04
# 11            Feedback:BlockOrder:BlockType 1, 116 0.01      2.07    .02
# 12                     Congruency:BlockType 1, 116 0.00      0.17   .002
# 13            Feedback:Congruency:BlockType 1, 116 0.00      0.17   .002
# 14          BlockOrder:Congruency:BlockType 1, 116 0.00    5.17 *    .04
# 15 Feedback:BlockOrder:Congruency:BlockType 1, 116 0.00      0.05  .0005
#    p.value
# 1      .76
# 2      .06
# 3      .98
# 4   <.0001
# 5      .67
# 6      .67
# 7      .62
# 8      .39
# 9      .13
# 10     .03
# 11     .15
# 12     .68
# 13     .68
# 14     .02
# 15     .82
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '+' 0.1 ' ' 1

# %%
rawIEData_T <- read.csv('IE_transfer.csv')
aov_car(IE ~ Feedback * BlockOrder + Error(SubjectID/(TrialType*CueType)), data = rawIEData_T, anova_table = list(es = "pes"))
# Out:
# Contrasts set to contr.sum for the following variables: Feedback, BlockOrder
# Anova Table (Type 3 tests)
#
# Response: IE
#                                   Effect     df       MSE         F    pes
# 1                               Feedback 1, 116 117759.42      0.16   .001
# 2                             BlockOrder 1, 116 117759.42    4.01 *    .03
# 3                    Feedback:BlockOrder 1, 116 117759.42      0.39   .003
# 4                              TrialType 1, 116   8571.18 31.83 ***    .22
# 5                     Feedback:TrialType 1, 116   8571.18      0.23   .002
# 6                   BlockOrder:TrialType 1, 116   8571.18      0.04  .0003
# 7          Feedback:BlockOrder:TrialType 1, 116   8571.18      0.34   .003
# 8                                CueType 1, 116  21357.60      1.39    .01
# 9                       Feedback:CueType 1, 116  21357.60    2.82 +    .02
# 10                    BlockOrder:CueType 1, 116  21357.60    5.65 *    .05
# 11           Feedback:BlockOrder:CueType 1, 116  21357.60      1.29    .01
# 12                     TrialType:CueType 1, 116   4347.09      0.01 <.0001
# 13            Feedback:TrialType:CueType 1, 116   4347.09      1.79    .02
# 14          BlockOrder:TrialType:CueType 1, 116   4347.09    5.27 *    .04
# 15 Feedback:BlockOrder:TrialType:CueType 1, 116   4347.09      0.44   .004
#    p.value
# 1      .69
# 2      .05
# 3      .53
# 4   <.0001
# 5      .63
# 6      .85
# 7      .56
# 8      .24
# 9      .10
# 10     .02
# 11     .26
# 12     .93
# 13     .18
# 14     .02
# 15     .51
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '+' 0.1 ' ' 1

# %% [markdown]
# The exploratory ANOVAs on the CSE at the end of the Jupyter notebook..

# %%
CSE_RT <- read.csv('CSE_ANOVA_RT.csv')
aov_car(RT ~ Feedback + Error(subject/(PrevCong*Congruency)), data = CSE_RT, anova_table = list(es = "pes"))
# Out:
# Contrasts set to contr.sum for the following variables: Feedback
# Anova Table (Type 3 tests)
#
# Response: RT
#                         Effect     df      MSE         F  pes p.value
# 1                     Feedback 1, 118 20244.89      0.70 .006     .40
# 2                     PrevCong 1, 118   212.06      0.17 .001     .68
# 3            Feedback:PrevCong 1, 118   212.06      0.42 .004     .52
# 4                   Congruency 1, 118   641.67 36.75 ***  .24  <.0001
# 5          Feedback:Congruency 1, 118   641.67    4.24 *  .03     .04
# 6          PrevCong:Congruency 1, 118   228.67   8.80 **  .07    .004
# 7 Feedback:PrevCong:Congruency 1, 118   228.67      0.61 .005     .43
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '+' 0.1 ' ' 1

# %%
CSE_ACC <- read.csv('CSE_ANOVA_ACC.csv')
aov_car(Accuracy ~ Feedback + Error(subject/(PrevCong*Congruency)), data = CSE_ACC, anova_table = list(es = "pes"))
# Out:
# Contrasts set to contr.sum for the following variables: Feedback
# Anova Table (Type 3 tests)
#
# Response: Accuracy
#                         Effect     df  MSE         F   pes p.value
# 1                     Feedback 1, 118 0.01      0.63  .005     .43
# 2                     PrevCong 1, 118 0.00   9.83 **   .08    .002
# 3            Feedback:PrevCong 1, 118 0.00      0.02 .0001     .90
# 4                   Congruency 1, 118 0.00 25.15 ***   .18  <.0001
# 5          Feedback:Congruency 1, 118 0.00      2.28   .02     .13
# 6          PrevCong:Congruency 1, 118 0.00 22.23 ***   .16  <.0001
# 7 Feedback:PrevCong:Congruency 1, 118 0.00      0.22  .002     .64
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '+' 0.1 ' ' 1

# %% [markdown]
# ### Bayesian ANOVAs

# %%
library(methods)
library(BayesFactor)
library(BFEffects)
# Out:
# Loading required package: coda
# Warning message:
# "package 'coda' was built under R version 3.5.2"************
# Welcome to BayesFactor 0.9.12-4.2. If you have questions, please contact Richard Morey (richarddmorey@gmail.com).
#
# Type BFManual() to open the manual.
# ************
# Warning message:
# "replacing previous import 'magrittr::set_names' by 'purrr::set_names' when loading 'BFEffects'"

# %%
rawRTData <- read.csv('SC_ANOVA_RT.csv')
rawRTData$RT <- as.numeric(as.character(rawRTData$RT))

rawRTData <- within(rawRTData, {
  subject <- factor(subject)
  Congruency <- factor(Congruency)
  BlockType <- factor(BlockType)
   Feedback <- factor(Feedback)
    BlockOrder <- factor(BlockOrder)
})

SC_RT_runANOVA <- anovaBF(RT ~ BlockType*Congruency*Feedback*BlockOrder + subject,
                                  data=rawRTData,
                                  whichRandom="subject")

png(file="Bayes_SC_RT.png", width = 3000, height = 700, res = 60)
plot(SC_RT_runANOVA)
dev.off()
print(SC_RT_runANOVA)
print(inclusionBF(SC_RT_runANOVA))
# Out:
# Warning message in doNwaySampling(method, y, X, rscale, iterations, gMap, incCont, :
# "Some NAs were removed from sampling results: 1 in total."
# png
#   2
# Bayes factor analysis
# --------------
# [1] BlockType + subject                                                                                                                                                                                                                                                                                                                                                                         : 0.1918942    ±1.32%
# [2] Congruency + subject                                                                                                                                                                                                                                                                                                                                                                        : 20886793     ±1.09%
# [3] BlockType + Congruency + subject                                                                                                                                                                                                                                                                                                                                                            : 4535703      ±3.14%
# [4] BlockType + Congruency + BlockType:Congruency + subject                                                                                                                                                                                                                                                                                                                                     : 126740684    ±1.59%
# [5] Feedback + subject                                                                                                                                                                                                                                                                                                                                                                          : 0.5004308    ±3.81%
# [6] BlockType + Feedback + subject                                                                                                                                                                                                                                                                                                                                                              : 0.1029377    ±4.65%
# [7] Congruency + Feedback + subject                                                                                                                                                                                                                                                                                                                                                             : 11162887     ±4.39%
# [8] BlockType + Congruency + Feedback + subject                                                                                                                                                                                                                                                                                                                                                 : 2396596      ±5.61%
# [9] BlockType + Congruency + BlockType:Congruency + Feedback + subject                                                                                                                                                                                                                                                                                                                          : 76142340     ±6.04%
# [10] BlockType + Feedback + BlockType:Feedback + subject                                                                                                                                                                                                                                                                                                                                        : 0.0143596    ±5.49%
# [11] BlockType + Congruency + Feedback + BlockType:Feedback + subject                                                                                                                                                                                                                                                                                                                           : 355314.3     ±6.33%
# [12] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + subject                                                                                                                                                                                                                                                                                                    : 12840525     ±7.47%
# [13] Congruency + Feedback + Congruency:Feedback + subject                                                                                                                                                                                                                                                                                                                                      : 5466120      ±5.2%
# [14] BlockType + Congruency + Feedback + Congruency:Feedback + subject                                                                                                                                                                                                                                                                                                                          : 1165587      ±6.1%
# [15] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + subject                                                                                                                                                                                                                                                                                                   : 36221946     ±7.13%
# [16] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + subject                                                                                                                                                                                                                                                                                                     : 168926.9     ±7.99%
# [17] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + subject                                                                                                                                                                                                                                                                              : 6634113      ±7.6%
# [18] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + subject                                                                                                                                                                                                                                              : 1369839      ±11.23%
# [19] BlockOrder + subject                                                                                                                                                                                                                                                                                                                                                                       : 0.741597     ±1.39%
# [20] BlockType + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                                           : 0.1476085    ±4.99%
# [21] Congruency + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                                          : 18008353     ±12.73%
# [22] BlockType + Congruency + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                              : 3728092      ±5.27%
# [23] BlockType + Congruency + BlockType:Congruency + BlockOrder + subject                                                                                                                                                                                                                                                                                                                       : 107436428    ±5.57%
# [24] Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                                            : 0.4044852    ±4.23%
# [25] BlockType + Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                                : 0.08817535   ±4.85%
# [26] Congruency + Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                               : 8799501      ±4.81%
# [27] BlockType + Congruency + Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                   : 2054741      ±5.8%
# [28] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                            : 54117678     ±6.75%
# [29] BlockType + Feedback + BlockType:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                                           : 0.01376003   ±6.51%
# [30] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                              : 288553.8     ±7.17%
# [31] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                       : 10580985     ±7.88%
# [32] Congruency + Feedback + Congruency:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                                         : 4584260      ±5.86%
# [33] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                             : 1166261      ±7.42%
# [34] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                      : 31967507     ±7.83%
# [35] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                        : 151371.5     ±8.26%
# [36] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                 : 4543430      ±9.08%
# [37] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     subject                                                                                                                                                                                                                             : 1143907      ±9.71%
# [38] BlockType + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                                                                    : 6279374      ±2.95%
# [39] BlockType + Congruency + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                                                       : 1.985198e+15 ±21.27%
# [40] BlockType + Congruency + BlockType:Congruency + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                                : 9.407476e+16 ±3.52%
# [41] BlockType + Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                                                         : 3615053      ±5.58%
# [42] BlockType + Congruency + Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                                            : 9.718581e+14 ±6.36%
# [43] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                     : 6.224519e+16 ±7.5%
# [44] BlockType + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                                    : 579422.6     ±7.1%
# [45] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                       : 1.772846e+14 ±8.28%
# [46] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                : 9.323194e+15 ±8.15%
# [47] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                      : 5.082231e+14 ±7.88%
# [48] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                               : 3.698308e+16 ±9.31%
# [49] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                 : 1.012773e+14 ±10.27%
# [50] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     subject                                                                                                                                                                                                                                      : 6.450518e+15 ±10.74%
# [51] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + subject                                                                                                                                                                                                      : 1.124865e+15 ±9.29%
# [52] Congruency + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                                                                  : 2384428      ±5.33%
# [53] BlockType + Congruency + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                                                      : 494342.7     ±6.37%
# [54] BlockType + Congruency + BlockType:Congruency + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                               : 13555922     ±3.12%
# [55] Congruency + Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                                                       : 1441148      ±5.76%
# [56] BlockType + Congruency + Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                                           : 285354.5     ±7.11%
# [57] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                    : 9563410      ±7.64%
# [58] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                      : 49750.76     ±10.32%
# [59] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                               : 1240644      ±8.18%
# [60] Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                                 : 663879.8     ±6.66%
# [61] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                     : 157547.3     ±8.17%
# [62] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                              : 3863698      ±8.98%
# [63] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                : 19437        ±9.81%
# [64] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder +     subject                                                                                                                                                                                                                                     : 677390.6     ±11.81%
# [65] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     Congruency:BlockOrder + subject                                                                                                                                                                                                     : 211130.2     ±15.92%
# [66] BlockType + Congruency + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                               : 2.661334e+14 ±9.96%
# [67] BlockType + Congruency + BlockType:Congruency + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                        : 1.343982e+16 ±4.09%
# [68] BlockType + Congruency + Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                    : 1.299348e+14 ±7.85%
# [69] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                             : 1.111127e+16 ±8.38%
# [70] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                               : 2.107709e+13 ±9.18%
# [71] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     subject                                                                                                                                                                                                                                    : 1.541149e+15 ±10.67%
# [72] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                              : 8.068579e+13 ±8.04%
# [73] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     subject                                                                                                                                                                                                                                   : 4.822581e+15 ±10.37%
# [74] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     subject                                                                                                                                                                                                                                     : 1.211192e+13 ±11.81%
# [75] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + subject                                                                                                                                                                                                              : 8.35988e+14  ±11.13%
# [76] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                              : 1.807311e+14 ±16.45%
# [77] BlockType + Congruency + BlockType:Congruency + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     subject                                                                                                                                                                                                                                  : 4.11443e+15  ±9.06%
# [78] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     subject                                                                                                                                                                                                                       : 2.083789e+15 ±9.51%
# [79] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     BlockType:Congruency:BlockOrder + subject                                                                                                                                                                                                  : 4.606622e+14 ±13.48%
# [80] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     BlockType:Congruency:BlockOrder + subject                                                                                                                                                                                                 : 1.293041e+15 ±10.83%
# [81] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     subject                                                                                                                                                                        : 1.467794e+14 ±12.45%
# [82] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     subject                                                                                                                                        : 5.7775e+13   ±15.81%
# [83] Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                                                      : 0.2443711    ±4.69%
# [84] BlockType + Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                                          : 0.0518902    ±5.65%
# [85] Congruency + Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                                         : 5531746      ±5.12%
# [86] BlockType + Congruency + Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                             : 1235157      ±6.22%
# [87] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                      : 38397926     ±6.85%
# [88] BlockType + Feedback + BlockType:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                     : 0.007132012  ±6.79%
# [89] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                        : 206360       ±9.39%
# [90] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                 : 6120106      ±8.25%
# [91] Congruency + Feedback + Congruency:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                   : 2888708      ±6.22%
# [92] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                       : 578448.5     ±7.83%
# [93] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                : 20793989     ±10.13%
# [94] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                  : 91051.7      ±9%
# [95] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                       : 3016625      ±8.93%
# [96] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     Feedback:BlockOrder + subject                                                                                                                                                                                                       : 671169.2     ±13.46%
# [97] BlockType + Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                   : 2247251      ±6.82%
# [98] BlockType + Congruency + Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                      : 5.961845e+14 ±7.7%
# [99] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                               : 4.115127e+16 ±8.12%
# [100] BlockType + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                             : 320356.8     ±7.59%
# [101] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                : 9.601285e+13 ±7.08%
# [102] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                     : 6.365368e+15 ±10.49%
# [103] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                               : 3.231397e+14 ±8.38%
# [104] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                    : 2.454775e+16 ±9.85%
# [105] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                      : 5.769015e+13 ±11.07%
# [106] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Feedback:BlockOrder + subject                                                                                                                                                                                                               : 4.041413e+15 ±13.2%
# [107] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                               : 7.836505e+14 ±12.54%
# [108] Congruency + Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                : 735980.6     ±6.19%
# [109] BlockType + Congruency + Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                    : 167519.8     ±7.52%
# [110] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                             : 5231968      ±8.35%
# [111] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                               : 30637.87     ±10.45%
# [112] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                    : 678137.9     ±10.17%
# [113] Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                          : 412300.9     ±8.48%
# [114] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                              : 84207.98     ±8.77%
# [115] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                   : 2756666      ±10.69%
# [116] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                     : 13956.36     ±10.04%
# [117] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + subject                                                                                                                                                                                                              : 473170.7     ±15.8%
# ...
# [132] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + subject                                                                                                                 : 5.342922e+13 ±46.53%
# [133] BlockType + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + BlockType:Feedback:BlockOrder + subject                                                                                                                                                                                                                                             : 82450.61     ±7.89%
# [134] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + BlockType:Feedback:BlockOrder +     subject                                                                                                                                                                                                                            : 2.159764e+13 ±10.63%
# [135] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder +     BlockType:Feedback:BlockOrder + subject                                                                                                                                                                                                     : 1.396946e+15 ±10.12%
# [136] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder +     BlockType:Feedback:BlockOrder + subject                                                                                                                                                                                                      : 1.471837e+13 ±10.79%
# [137] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + subject                                                                                                                                                                               : 1.012025e+15 ±10.12%
# [138] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Feedback:BlockOrder + BlockType:Feedback:BlockOrder +     subject                                                                                                                                           : 1.629934e+14 ±16.45%
# [139] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     BlockType:Feedback:BlockOrder + subject                                                                                                                                                                                                    : 3.213118e+12 ±12.46%
# [140] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + subject                                                                                                                                                                             : 2.369876e+14 ±12.63%
# [141] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + subject                                                                                                                                                                              : 1.925726e+12 ±11.23%
# [142] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + Feedback:BlockOrder + BlockType:Feedback:BlockOrder +     subject                                                                                                                                                   : 1.452945e+14 ±14.1%
# [143] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     BlockType:Feedback:BlockOrder + subject                                                                                                                   : 1.924856e+13 ±11.17%
# [144] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     BlockType:Congruency:BlockOrder + Feedback:BlockOrder + BlockType:Feedback:BlockOrder +     subject                                                                                                                                       : 6.022504e+13 ±21.41%
# [145] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + subject                                                                                                                 : 3.784397e+13 ±18.11%
# [146] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + subject                                                                                 : 9.858339e+12 ±27.49%
# [147] Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + Congruency:Feedback:BlockOrder + subject                                                                                                                                                                                                                                         : 85078.6      ±7.96%
# [148] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                                                                                                                                                                         : 18361.52     ±12.12%
# [149] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     Congruency:Feedback:BlockOrder + subject                                                                                                                                                                                                  : 492687.2     ±14.21%
# [150] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     Congruency:Feedback:BlockOrder + subject                                                                                                                                                                                                    : 3151.787     ±14.64%
# [151] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + Congruency:Feedback:BlockOrder + subject                                                                                                                                                                             : 91336.37     ±20.19%
# [152] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     Congruency:BlockOrder + Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                                                                                         : 17653.25     ±13.79%
# [153] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     Congruency:Feedback:BlockOrder + subject                                                                                                                                                                                                  : 1.024593e+13 ±11.74%
# [154] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + Congruency:Feedback:BlockOrder + subject                                                                                                                                                                           : 6.130488e+14 ±9.77%
# [155] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + Congruency:Feedback:BlockOrder + subject                                                                                                                                                                             : 1.498977e+12 ±18.34%
# [156] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                                                                                                  : 1.135286e+14 ±18.92%
# [157] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     Congruency:Feedback:BlockOrder + subject                                                                                                                  : 3.176881e+13 ±27.02%
# [158] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     BlockType:Congruency:BlockOrder + Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                                                                                     : 1.889377e+14 ±16.14%
# [159] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + Congruency:Feedback:BlockOrder + subject                                                                                                                : 2.331242e+13 ±14.74%
# [160] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + Congruency:Feedback:BlockOrder + subject                                                                                : 4.253732e+12 ±16.95%
# [161] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                                                                                         : 332545112726 ±11.58%
# [162] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + Feedback:BlockOrder + BlockType:Feedback:BlockOrder +     Congruency:Feedback:BlockOrder + subject                                                                                                                  : 2.645149e+13 ±20.3%
# [163] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     BlockType:Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                              : 5.467981e+12 ±16.79%
# [164] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                            : 4.739626e+12 ±15.91%
# [165] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                            : 1.826307e+12 ±26.46%
# [166] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     BlockType:Congruency:Feedback:BlockOrder + subject : 639814175228 ±13.8%
#
# Against denominator:
#   RT ~ subject
# ---
# Bayes factor type: BFlinearModel, JZS
#                                          Pr(prior) Pr(posterior) Inclusion BF
# BlockType                                    0.886         1.000 5.431308e+08
# Congruency                                   0.886         1.000 3.437059e+09
# BlockType:Congruency                         0.503         0.984 6.157200e+01
# Feedback                                     0.886         0.676 2.680000e-01
# BlockType:Feedback                           0.503         0.105 1.160000e-01
# Congruency:Feedback                          0.503         0.259 3.440000e-01
# BlockType:Congruency:Feedback                0.120         0.007 5.300000e-02
# BlockOrder                                   0.886         1.000 1.473686e+08
# BlockType:BlockOrder                         0.503         1.000 5.104384e+08
# Congruency:BlockOrder                        0.503         0.162 1.910000e-01
# BlockType:Congruency:BlockOrder              0.120         0.033 2.510000e-01
# Feedback:BlockOrder                          0.503         0.276 3.760000e-01
# BlockType:Feedback:BlockOrder                0.120         0.009 6.700000e-02
# Congruency:Feedback:BlockOrder               0.120         0.003 2.200000e-02
# BlockType:Congruency:Feedback:BlockOrder     0.006         0.000 0.000000e+00
#
# Inclusion BFs compared among all models.

# %%
rawACCData <- read.csv('SC_ANOVA_ACC.csv')
rawACCData$Accuracy <- as.numeric(as.character(rawACCData$Accuracy))

rawACCData <- within(rawACCData, {
  subject <- factor(subject)
  Congruency <- factor(Congruency)
  BlockType <- factor(BlockType)
    Feedback <- factor(Feedback)
    BlockOrder <- factor(BlockOrder)
})

SC_ACC_runANOVA <- anovaBF(Accuracy ~ BlockType*Congruency*Feedback*BlockOrder + subject,
                                  data=rawACCData,
                                  whichRandom="subject")

png(file="Bayes_SC_ACC.png", width = 3000, height = 700, res = 60)
plot(SC_ACC_runANOVA)
dev.off()
print(SC_ACC_runANOVA)
print(inclusionBF(SC_ACC_runANOVA))
# Out:
# png
#   2
# Bayes factor analysis
# --------------
# [1] BlockType + subject                                                                                                                                                                                                                                                                                                                                                                         : 0.2362311    ±0.88%
# [2] Congruency + subject                                                                                                                                                                                                                                                                                                                                                                        : 18904.53     ±0.81%
# [3] BlockType + Congruency + subject                                                                                                                                                                                                                                                                                                                                                            : 4900.379     ±1.76%
# [4] BlockType + Congruency + BlockType:Congruency + subject                                                                                                                                                                                                                                                                                                                                     : 151691087    ±2.47%
# [5] Feedback + subject                                                                                                                                                                                                                                                                                                                                                                          : 0.1796234    ±0.85%
# [6] BlockType + Feedback + subject                                                                                                                                                                                                                                                                                                                                                              : 0.04275912   ±1.38%
# [7] Congruency + Feedback + subject                                                                                                                                                                                                                                                                                                                                                             : 195635.7     ±98.15%
# [8] BlockType + Congruency + Feedback + subject                                                                                                                                                                                                                                                                                                                                                 : 922.9687     ±3.42%
# [9] BlockType + Congruency + BlockType:Congruency + Feedback + subject                                                                                                                                                                                                                                                                                                                          : 29726291     ±2.66%
# [10] BlockType + Feedback + BlockType:Feedback + subject                                                                                                                                                                                                                                                                                                                                        : 0.00612021   ±1.98%
# [11] BlockType + Congruency + Feedback + BlockType:Feedback + subject                                                                                                                                                                                                                                                                                                                           : 132.307      ±2.88%
# [12] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + subject                                                                                                                                                                                                                                                                                                    : 4824570      ±7.19%
# [13] Congruency + Feedback + Congruency:Feedback + subject                                                                                                                                                                                                                                                                                                                                      : 872.7341     ±1.43%
# [14] BlockType + Congruency + Feedback + Congruency:Feedback + subject                                                                                                                                                                                                                                                                                                                          : 222.6353     ±2.26%
# [15] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + subject                                                                                                                                                                                                                                                                                                   : 7885352      ±3.02%
# [16] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + subject                                                                                                                                                                                                                                                                                                     : 36.06468     ±4.1%
# [17] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + subject                                                                                                                                                                                                                                                                              : 1322555      ±5.12%
# [18] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + subject                                                                                                                                                                                                                                              : 1143040      ±5.71%
# [19] BlockOrder + subject                                                                                                                                                                                                                                                                                                                                                                       : 0.389718     ±1.16%
# [20] BlockType + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                                           : 0.09367647   ±2.56%
# [21] Congruency + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                                          : 7549.791     ±1.14%
# [22] BlockType + Congruency + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                              : 1917.392     ±2.09%
# [23] BlockType + Congruency + BlockType:Congruency + BlockOrder + subject                                                                                                                                                                                                                                                                                                                       : 65778521     ±4.54%
# [24] Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                                            : 0.07093355   ±1.84%
# [25] BlockType + Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                                : 0.01794676   ±4.71%
# [26] Congruency + Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                               : 1425.903     ±2.65%
# [27] BlockType + Congruency + Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                   : 372.2863     ±2.89%
# [28] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                            : 12256544     ±3.15%
# [29] BlockType + Feedback + BlockType:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                                           : 0.002411032  ±2.37%
# [30] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                              : 53.12254     ±3.75%
# [31] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                       : 2236081      ±14.27%
# [32] Congruency + Feedback + Congruency:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                                         : 400.6536     ±10.54%
# [33] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                             : 98.75912     ±6.14%
# [34] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                      : 3256346      ±3.21%
# [35] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                        : 16.59165     ±14.42%
# [36] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                 : 538179.8     ±8.13%
# [37] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     subject                                                                                                                                                                                                                             : 404693.8     ±4.75%
# [38] BlockType + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                                                                    : 0.03204852   ±4.37%
# [39] BlockType + Congruency + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                                                       : 658.6153     ±2.17%
# [40] BlockType + Congruency + BlockType:Congruency + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                                : 28902467     ±10.46%
# [41] BlockType + Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                                                         : 0.00577226   ±3.61%
# [42] BlockType + Congruency + Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                                            : 122.1683     ±2.32%
# [43] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                     : 4579933      ±4.6%
# [44] BlockType + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                                    : 0.0008830358 ±7.83%
# [45] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                       : 20.44434     ±8.74%
# [46] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                : 670492       ±4.21%
# [47] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                      : 33.56666     ±4.81%
# [48] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                               : 1245044      ±4.88%
# [49] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                 : 4.926498     ±5.2%
# [50] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     subject                                                                                                                                                                                                                                      : 175978.8     ±4.58%
# [51] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + subject                                                                                                                                                                                                      : 174575.6     ±10.38%
# [52] Congruency + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                                                                  : 1164.295     ±1.85%
# [53] BlockType + Congruency + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                                                      : 307.525      ±3.91%
# [54] BlockType + Congruency + BlockType:Congruency + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                               : 11199930     ±11.12%
# [55] Congruency + Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                                                       : 224.0019     ±3.13%
# [56] BlockType + Congruency + Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                                           : 56.94061     ±4.78%
# [57] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                    : 2459880      ±20.91%
# [58] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                      : 15.99196     ±47.69%
# [59] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                               : 291981.4     ±6%
# [60] Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                                 : 58.67654     ±4.02%
# [61] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                     : 15.34725     ±6.58%
# [62] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                              : 541260       ±4.03%
# [63] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                : 2.422263     ±8.53%
# [64] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder +     subject                                                                                                                                                                                                                                     : 76307.72     ±6.66%
# [65] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     Congruency:BlockOrder + subject                                                                                                                                                                                                     : 66103.66     ±7.66%
# [66] BlockType + Congruency + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                               : 113.2011     ±8.79%
# [67] BlockType + Congruency + BlockType:Congruency + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                        : 3631459      ±3.95%
# [68] BlockType + Congruency + Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                    : 19.37297     ±4.41%
# [69] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                             : 711045.6     ±3.86%
# [70] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                               : 2.903134     ±5.82%
# [71] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     subject                                                                                                                                                                                                                                    : 93400.58     ±3.7%
# [72] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                              : 4.88283      ±4.93%
# [73] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     subject                                                                                                                                                                                                                                   : 189039.1     ±4.62%
# [74] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     subject                                                                                                                                                                                                                                     : 0.9267647    ±14.65%
# [75] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + subject                                                                                                                                                                                                              : 33513.28     ±15.96%
# [76] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                              : 22120.14     ±4.62%
# [77] BlockType + Congruency + BlockType:Congruency + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     subject                                                                                                                                                                                                                                  : 2928871      ±4.23%
# [78] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     subject                                                                                                                                                                                                                       : 509755.7     ±4.26%
# [79] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     BlockType:Congruency:BlockOrder + subject                                                                                                                                                                                                  : 81024.67     ±6.95%
# [80] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     BlockType:Congruency:BlockOrder + subject                                                                                                                                                                                                 : 166449.5     ±11.12%
# [81] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     subject                                                                                                                                                                        : 34953.19     ±30.08%
# [82] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     subject                                                                                                                                        : 51779.64     ±61.19%
# [83] Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                                                      : 0.01843505   ±1.4%
# [84] BlockType + Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                                          : 0.004353561  ±1.8%
# [85] Congruency + Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                                         : 403.898      ±2.87%
# [86] BlockType + Congruency + Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                             : 104.6831     ±5.07%
# [87] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                      : 7098246      ±48.88%
# [88] BlockType + Feedback + BlockType:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                     : 0.0006730994 ±5.23%
# [89] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                        : 14.3156      ±2.96%
# [90] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                 : 534864.8     ±5.88%
# [91] Congruency + Feedback + Congruency:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                   : 96.92208     ±2.2%
# [92] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                       : 35.16568     ±25.4%
# [93] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                : 931586.5     ±7.42%
# [94] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                  : 3.805121     ±4.57%
# [95] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                       : 138018.5     ±6.41%
# [96] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     Feedback:BlockOrder + subject                                                                                                                                                                                                       : 145134.2     ±21.58%
# [97] BlockType + Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                   : 0.001499966  ±4.44%
# [98] BlockType + Congruency + Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                      : 35.45587     ±4.54%
# [99] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                               : 1384077      ±5.88%
# [100] BlockType + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                             : 0.0002147605 ±4.49%
# [101] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                : 5.20081      ±5.7%
# [102] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                     : 181286.4     ±4.93%
# [103] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                               : 10.88628     ±8.8%
# [104] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                    : 345901.2     ±4.71%
# [105] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                      : 1.309912     ±4.43%
# [106] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Feedback:BlockOrder + subject                                                                                                                                                                                                               : 52164.12     ±7.43%
# [107] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                               : 42690.55     ±5.61%
# [108] Congruency + Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                : 59.53318     ±2.64%
# [109] BlockType + Congruency + Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                    : 23.43904     ±35.43%
# [110] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                             : 498790.6     ±4.12%
# [111] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                               : 4.77915      ±43.19%
# [112] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                    : 81773.78     ±4.56%
# [113] Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                          : 16.2296      ±3.86%
# [114] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                              : 3.777003     ±3.22%
# [115] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                   : 146518.2     ±6.73%
# [116] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                     : 0.577278     ±4.55%
# [117] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + subject                                                                                                                                                                                                              : 23919.62     ±8.26%
# [118] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     Congruency:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                              : 15934.7      ±3.07%
# ...
# [132] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + subject                                                                                                                 : 5942.968     ±13.22%
# [133] BlockType + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + BlockType:Feedback:BlockOrder + subject                                                                                                                                                                                                                                             : 4.787424e-05 ±3.92%
# [134] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + BlockType:Feedback:BlockOrder +     subject                                                                                                                                                                                                                            : 1.20015      ±6.24%
# [135] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder +     BlockType:Feedback:BlockOrder + subject                                                                                                                                                                                                     : 56354.81     ±9.51%
# [136] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder +     BlockType:Feedback:BlockOrder + subject                                                                                                                                                                                                      : 0.2963193    ±10.25%
# [137] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + subject                                                                                                                                                                               : 13655.84     ±7.77%
# [138] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Feedback:BlockOrder + BlockType:Feedback:BlockOrder +     subject                                                                                                                                           : 12429.37     ±15.41%
# [139] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     BlockType:Feedback:BlockOrder + subject                                                                                                                                                                                                    : 0.2393894    ±9.58%
# [140] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + subject                                                                                                                                                                             : 6463.739     ±5.83%
# [141] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + subject                                                                                                                                                                              : 0.04630476   ±5.38%
# [142] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + Feedback:BlockOrder + BlockType:Feedback:BlockOrder +     subject                                                                                                                                                   : 2181.103     ±19.49%
# [143] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     BlockType:Feedback:BlockOrder + subject                                                                                                                   : 1458.094     ±5.8%
# [144] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     BlockType:Congruency:BlockOrder + Feedback:BlockOrder + BlockType:Feedback:BlockOrder +     subject                                                                                                                                       : 5060.916     ±5.43%
# [145] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + subject                                                                                                                 : 1561.586     ±13.45%
# [146] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + subject                                                                                 : 1186.616     ±6.45%
# [147] Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + Congruency:Feedback:BlockOrder + subject                                                                                                                                                                                                                                         : 3.445906     ±6.5%
# [148] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                                                                                                                                                                         : 0.8289583    ±4.73%
# [149] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     Congruency:Feedback:BlockOrder + subject                                                                                                                                                                                                  : 46368.42     ±31.77%
# [150] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     Congruency:Feedback:BlockOrder + subject                                                                                                                                                                                                    : 0.1246542    ±6.02%
# [151] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + Congruency:Feedback:BlockOrder + subject                                                                                                                                                                             : 4247.48      ±4.76%
# [152] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     Congruency:BlockOrder + Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                                                                                         : 5486.73      ±12.2%
# [153] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     Congruency:Feedback:BlockOrder + subject                                                                                                                                                                                                  : 0.2954603    ±9.96%
# [154] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + Congruency:Feedback:BlockOrder + subject                                                                                                                                                                           : 11428.91     ±9.19%
# [155] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + Congruency:Feedback:BlockOrder + subject                                                                                                                                                                             : 0.04383332   ±5.16%
# [156] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                                                                                                  : 1837.224     ±7.67%
# [157] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     Congruency:Feedback:BlockOrder + subject                                                                                                                  : 1379.197     ±5.71%
# [158] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     BlockType:Congruency:BlockOrder + Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                                                                                     : 10488.24     ±10.16%
# [159] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + Congruency:Feedback:BlockOrder + subject                                                                                                                : 1470.863     ±12.95%
# [160] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + Congruency:Feedback:BlockOrder + subject                                                                                : 1144.63      ±7.35%
# [161] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                                                                                         : 0.009790417  ±4.88%
# [162] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + Feedback:BlockOrder + BlockType:Feedback:BlockOrder +     Congruency:Feedback:BlockOrder + subject                                                                                                                  : 444.4322     ±14.57%
# [163] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     BlockType:Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                              : 361.7232     ±7.82%
# [164] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                            : 318.0569     ±7.98%
# [165] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                            : 283.2209     ±10.14%
# [166] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     BlockType:Congruency:Feedback:BlockOrder + subject : 97.55446     ±16.98%
#
# Against denominator:
#   Accuracy ~ subject
# ---
# Bayes factor type: BFlinearModel, JZS
#                                          Pr(prior) Pr(posterior) Inclusion BF
# BlockType                                    0.886         0.999      199.451
# Congruency                                   0.886         1.000 21522008.098
# BlockType:Congruency                         0.503         0.999     1468.355
# Feedback                                     0.886         0.251        0.043
# BlockType:Feedback                           0.503         0.039        0.040
# Congruency:Feedback                          0.503         0.055        0.058
# BlockType:Congruency:Feedback                0.120         0.006        0.044
# BlockOrder                                   0.886         0.442        0.102
# BlockType:BlockOrder                         0.503         0.133        0.152
# Congruency:BlockOrder                        0.503         0.070        0.074
# BlockType:Congruency:BlockOrder              0.120         0.011        0.085
# Feedback:BlockOrder                          0.503         0.035        0.036
# BlockType:Feedback:BlockOrder                0.120         0.000        0.002
# Congruency:Feedback:BlockOrder               0.120         0.000        0.002
# BlockType:Congruency:Feedback:BlockOrder     0.006         0.000        0.000
#
# Inclusion BFs compared among all models.

# %%
IEdata <- read.csv('IE_Main.csv')
IEdata$IE <- as.numeric(as.character(IEdata$IE))

IEdata <- within(IEdata, {
  SubjectID <- factor(SubjectID)
  TrialType <- factor(TrialType)
  CueType <- factor(CueType)
  Feedback <- factor(Feedback)
    BlockOrder <- factor(BlockOrder)
})

SC_IE_runANOVA <- anovaBF(IE ~ CueType*TrialType*Feedback*BlockOrder + SubjectID,
                          data=IEdata,
                          whichRandom="SubjectID")

png(file="Bayes_SC_IE.png", width = 3000, height = 700, res = 60)
plot(SC_IE_runANOVA)
dev.off()
print(SC_IE_runANOVA)
print(inclusionBF(SC_IE_runANOVA))
# Out:
# png
#   2
# Bayes factor analysis
# --------------
# [1] Feedback + SubjectID                                                                                                                                                                                                                                                                                                                                                  : 0.2383596   ±0.51%
# [2] BlockOrder + SubjectID                                                                                                                                                                                                                                                                                                                                                : 0.6100308   ±1.01%
# [3] Feedback + BlockOrder + SubjectID                                                                                                                                                                                                                                                                                                                                     : 0.1442262   ±1.24%
# [4] Feedback + BlockOrder + Feedback:BlockOrder + SubjectID                                                                                                                                                                                                                                                                                                               : 0.05186654  ±1.05%
# [5] TrialType + SubjectID                                                                                                                                                                                                                                                                                                                                                 : 145630.6    ±1.25%
# [6] Feedback + TrialType + SubjectID                                                                                                                                                                                                                                                                                                                                      : 35532.36    ±2.23%
# [7] BlockOrder + TrialType + SubjectID                                                                                                                                                                                                                                                                                                                                    : 95288.44    ±3.71%
# [8] Feedback + BlockOrder + TrialType + SubjectID                                                                                                                                                                                                                                                                                                                         : 21785.87    ±2.57%
# [9] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + SubjectID                                                                                                                                                                                                                                                                                                   : 8184.684    ±2.92%
# [10] Feedback + TrialType + Feedback:TrialType + SubjectID                                                                                                                                                                                                                                                                                                                : 9370.249    ±2.35%
# [11] Feedback + BlockOrder + TrialType + Feedback:TrialType + SubjectID                                                                                                                                                                                                                                                                                                   : 6027.452    ±4.31%
# [12] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + SubjectID                                                                                                                                                                                                                                                                             : 2373.733    ±5.3%
# [13] BlockOrder + TrialType + BlockOrder:TrialType + SubjectID                                                                                                                                                                                                                                                                                                            : 13896.09    ±2.71%
# [14] Feedback + BlockOrder + TrialType + BlockOrder:TrialType + SubjectID                                                                                                                                                                                                                                                                                                 : 3252.037    ±2.06%
# [15] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + SubjectID                                                                                                                                                                                                                                                                           : 1311.171    ±4.19%
# [16] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + SubjectID                                                                                                                                                                                                                                                                            : 975.2677    ±3.55%
# [17] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + SubjectID                                                                                                                                                                                                                                                      : 335.9089    ±2.77%
# [18] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + SubjectID                                                                                                                                                                                                                      : 76.50377    ±4.16%
# [19] CueType + SubjectID                                                                                                                                                                                                                                                                                                                                                  : 0.3518687   ±0.97%
# [20] Feedback + CueType + SubjectID                                                                                                                                                                                                                                                                                                                                       : 0.08256355  ±1.17%
# [21] BlockOrder + CueType + SubjectID                                                                                                                                                                                                                                                                                                                                     : 0.2094154   ±1.27%
# [22] Feedback + BlockOrder + CueType + SubjectID                                                                                                                                                                                                                                                                                                                          : 0.05150422  ±2.42%
# [23] Feedback + BlockOrder + Feedback:BlockOrder + CueType + SubjectID                                                                                                                                                                                                                                                                                                    : 0.0199309   ±5.36%
# [24] TrialType + CueType + SubjectID                                                                                                                                                                                                                                                                                                                                      : 54755.55    ±1.29%
# [25] Feedback + TrialType + CueType + SubjectID                                                                                                                                                                                                                                                                                                                           : 13522.86    ±1.9%
# [26] BlockOrder + TrialType + CueType + SubjectID                                                                                                                                                                                                                                                                                                                         : 34466.28    ±1.75%
# [27] Feedback + BlockOrder + TrialType + CueType + SubjectID                                                                                                                                                                                                                                                                                                              : 8808.753    ±2.56%
# [28] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + CueType + SubjectID                                                                                                                                                                                                                                                                                        : 3195.013    ±2.79%
# [29] Feedback + TrialType + Feedback:TrialType + CueType + SubjectID                                                                                                                                                                                                                                                                                                      : 3779.195    ±3.36%
# [30] Feedback + BlockOrder + TrialType + Feedback:TrialType + CueType + SubjectID                                                                                                                                                                                                                                                                                         : 2629.107    ±5.5%
# [31] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + CueType + SubjectID                                                                                                                                                                                                                                                                   : 896.1907    ±4.79%
# [32] BlockOrder + TrialType + BlockOrder:TrialType + CueType + SubjectID                                                                                                                                                                                                                                                                                                  : 5229.761    ±2.55%
# [33] Feedback + BlockOrder + TrialType + BlockOrder:TrialType + CueType + SubjectID                                                                                                                                                                                                                                                                                       : 1352.427    ±2.68%
# [34] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + CueType + SubjectID                                                                                                                                                                                                                                                                 : 481.792     ±3.01%
# [35] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + SubjectID                                                                                                                                                                                                                                                                  : 388.7646    ±8.84%
# [36] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + SubjectID                                                                                                                                                                                                                                            : 202.9687    ±33.72%
# [37] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     SubjectID                                                                                                                                                                                                        : 51.14742    ±41.64%
# [38] Feedback + CueType + Feedback:CueType + SubjectID                                                                                                                                                                                                                                                                                                                    : 0.01390185  ±9.42%
# [39] Feedback + BlockOrder + CueType + Feedback:CueType + SubjectID                                                                                                                                                                                                                                                                                                       : 0.007645912 ±2.05%
# [40] Feedback + BlockOrder + Feedback:BlockOrder + CueType + Feedback:CueType + SubjectID                                                                                                                                                                                                                                                                                 : 0.002892194 ±4.49%
# [41] Feedback + TrialType + CueType + Feedback:CueType + SubjectID                                                                                                                                                                                                                                                                                                        : 2168.441    ±4.74%
# [42] Feedback + BlockOrder + TrialType + CueType + Feedback:CueType + SubjectID                                                                                                                                                                                                                                                                                           : 1318.956    ±2.65%
# [43] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + CueType + Feedback:CueType + SubjectID                                                                                                                                                                                                                                                                     : 516.1689    ±3.83%
# [44] Feedback + TrialType + Feedback:TrialType + CueType + Feedback:CueType + SubjectID                                                                                                                                                                                                                                                                                   : 560.7024    ±2.84%
# [45] Feedback + BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + SubjectID                                                                                                                                                                                                                                                                      : 410.97      ±12.42%
# [46] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + SubjectID                                                                                                                                                                                                                                                : 137.4319    ±3.44%
# [47] Feedback + BlockOrder + TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + SubjectID                                                                                                                                                                                                                                                                    : 201.6085    ±6.23%
# [48] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + SubjectID                                                                                                                                                                                                                                              : 81.67488    ±4.3%
# [49] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + SubjectID                                                                                                                                                                                                                                               : 60.21084    ±10.26%
# [50] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + SubjectID                                                                                                                                                                                                                         : 22.13177    ±9.26%
# [51] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     Feedback:CueType + SubjectID                                                                                                                                                                                     : 4.780912    ±5.41%
# [52] BlockOrder + CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                                                                                : 0.6001144   ±7.15%
# [53] Feedback + BlockOrder + CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                                                                     : 0.1303273   ±1.91%
# [54] Feedback + BlockOrder + Feedback:BlockOrder + CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                                               : 0.0490101   ±2.3%
# [55] BlockOrder + TrialType + CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                                                                    : 116210.6    ±3.21%
# [56] Feedback + BlockOrder + TrialType + CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                                                         : 31988.35    ±5.92%
# [57] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                                   : 11570.84    ±3.62%
# [58] Feedback + BlockOrder + TrialType + Feedback:TrialType + CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                                    : 7842.295    ±3.54%
# [59] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                              : 3645.342    ±8.92%
# [60] BlockOrder + TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                                             : 16961.25    ±2.81%
# [61] Feedback + BlockOrder + TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                                  : 4366.356    ±3.13%
# [62] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                            : 1832.522    ±6.5%
# [63] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                             : 1297.915    ±4.24%
# [64] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                       : 518.2774    ±7.34%
# [65] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     BlockOrder:CueType + SubjectID                                                                                                                                                                                   : 126.6966    ±10.29%
# [66] Feedback + BlockOrder + CueType + Feedback:CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                                                  : 0.02216259  ±6.96%
# [67] Feedback + BlockOrder + Feedback:BlockOrder + CueType + Feedback:CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                            : 0.008074486 ±3.99%
# [68] Feedback + BlockOrder + TrialType + CueType + Feedback:CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                                      : 4880.631    ±4.76%
# [69] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + CueType + Feedback:CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                : 1749.612    ±4.05%
# [70] Feedback + BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                 : 1694.228    ±8.88%
# [71] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                           : 505.7403    ±7.33%
# [72] Feedback + BlockOrder + TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                               : 759.8586    ±10.19%
# [73] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                         : 276.5495    ±4.82%
# [74] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                          : 190.3575    ±4.79%
# [75] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType +     SubjectID                                                                                                                                                                                                : 77.38209    ±7.86%
# [76] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     Feedback:CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                : 19.11504    ±7.19%
# [77] Feedback + BlockOrder + Feedback:BlockOrder + CueType + Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType + SubjectID                                                                                                                                                                                                                              : 0.001734516 ±4.34%
# [78] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + CueType + Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType +     SubjectID                                                                                                                                                                                                              : 343.0597    ±3.47%
# [79] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType +     SubjectID                                                                                                                                                                                         : 238.3589    ±43.73%
# [80] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType +     SubjectID                                                                                                                                                                                       : 63.86973    ±9.3%
# [81] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType +     Feedback:BlockOrder:CueType + SubjectID                                                                                                                                                                  : 14.26549    ±4.76%
# [82] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType +     SubjectID                                                                                                                              : 3.39511     ±4.26%
# [83] TrialType + CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                                                                                  : 373359369   ±2.43%
# [84] Feedback + TrialType + CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                                                                       : 97062966    ±3.25%
# [85] BlockOrder + TrialType + CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                                                                     : 238970840   ±3.68%
# [86] Feedback + BlockOrder + TrialType + CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                                                          : 65914245    ±5.02%
# [87] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                                    : 25439822    ±6.63%
# [88] Feedback + TrialType + Feedback:TrialType + CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                                                  : 26337679    ±3.36%
# [89] Feedback + BlockOrder + TrialType + Feedback:TrialType + CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                                     : 17569320    ±4.39%
# [90] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                               : 6731519     ±5.64%
# [91] BlockOrder + TrialType + BlockOrder:TrialType + CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                                              : 36922661    ±4%
# [92] Feedback + BlockOrder + TrialType + BlockOrder:TrialType + CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                                   : 9752790     ±3.69%
# [93] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                             : 3462736     ±4.3%
# [94] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                              : 2782804     ±7.82%
# [95] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                        : 1028367     ±4.36%
# [96] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     TrialType:CueType + SubjectID                                                                                                                                                                                    : 260298.2    ±10.34%
# [97] Feedback + TrialType + CueType + Feedback:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                                                    : 15108814    ±4.08%
# [98] Feedback + BlockOrder + TrialType + CueType + Feedback:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                                       : 10053690    ±4.4%
# [99] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + CueType + Feedback:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                 : 3472176     ±3.02%
# [100] Feedback + TrialType + Feedback:TrialType + CueType + Feedback:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                              : 4890759     ±9.36%
# [101] Feedback + BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                 : 2659376     ±3.43%
# [102] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                           : 1237953     ±18.09%
# [103] Feedback + BlockOrder + TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                               : 1512270     ±4.39%
# [104] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                         : 618375.1    ±6.47%
# [105] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                          : 410272.4    ±7.2%
# [106] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + TrialType:CueType +     SubjectID                                                                                                                                                                                                : 159024      ±5.69%
# [107] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     Feedback:CueType + TrialType:CueType + SubjectID                                                                                                                                                                : 33959.31    ±4.65%
# [108] BlockOrder + TrialType + CueType + BlockOrder:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                                               : 960527270   ±2.66%
# [109] Feedback + BlockOrder + TrialType + CueType + BlockOrder:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                                    : 284564780   ±11.34%
# [110] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + CueType + BlockOrder:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                              : 98236008    ±3.34%
# [111] Feedback + BlockOrder + TrialType + Feedback:TrialType + CueType + BlockOrder:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                               : 75058755    ±4.68%
# [112] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + CueType + BlockOrder:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                         : 28868075    ±5.96%
# [113] BlockOrder + TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                        : 178068098   ±13.87%
# [114] Feedback + BlockOrder + TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                             : 40436557    ±6.17%
# [115] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                       : 15655767    ±4.09%
# [116] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                        : 10662009    ±3.35%
# [117] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + TrialType:CueType +     SubjectID                                                                                                                                                                                              : 4084182     ±6.79%
# [118] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     BlockOrder:CueType + TrialType:CueType + SubjectID                                                                                                                                                              : 1204798     ±14.92%
# [119] Feedback + BlockOrder + TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                 : 40541149    ±4.76%
# [120] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     SubjectID                                                                                                                                                                                                                       : 15495989    ±4%
# [121] Feedback + BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     SubjectID                                                                                                                                                                                                                        : 17825116    ±32.17%
# [122] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     SubjectID                                                                                                                                                                                                  : 5634484     ±25.8%
# [123] Feedback + BlockOrder + TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     SubjectID                                                                                                                                                                                                                      : 8383358     ±24.73%
# [124] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     SubjectID                                                                                                                                                                                                : 3900793     ±36.24%
# [125] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     SubjectID                                                                                                                                                                                                 : 2042571     ±10.26%
# ...
# [129] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType +     TrialType:CueType + SubjectID                                                                                                                                                                    : 1009151     ±7.48%
# [130] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType +     TrialType:CueType + SubjectID                                                                                                                                                                  : 514381.9    ±5.4%
# [131] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType +     Feedback:BlockOrder:CueType + TrialType:CueType + SubjectID                                                                                                                                             : 192849.4    ±26.17%
# [132] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType +     TrialType:CueType + SubjectID                                                                                                         : 34821.35    ±8.21%
# [133] Feedback + TrialType + Feedback:TrialType + CueType + Feedback:CueType + TrialType:CueType + Feedback:TrialType:CueType + SubjectID                                                                                                                                                                                                                                 : 1239744     ±7.67%
# [134] Feedback + BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + TrialType:CueType + Feedback:TrialType:CueType +     SubjectID                                                                                                                                                                                                                : 725283.7    ±4.96%
# [135] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + TrialType:CueType + Feedback:TrialType:CueType +     SubjectID                                                                                                                                                                                          : 356988.7    ±15.52%
# [136] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + TrialType:CueType + Feedback:TrialType:CueType +     SubjectID                                                                                                                                                                                         : 127854.7    ±12.98%
# [137] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + TrialType:CueType +     Feedback:TrialType:CueType + SubjectID                                                                                                                                                                   : 41815.13    ±4.33%
# [138] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     Feedback:CueType + TrialType:CueType + Feedback:TrialType:CueType +     SubjectID                                                                                                                               : 11149.97    ±14.84%
# [139] Feedback + BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     Feedback:TrialType:CueType + SubjectID                                                                                                                                                                                           : 2881918     ±3.67%
# [140] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     Feedback:TrialType:CueType + SubjectID                                                                                                                                                                     : 1194241     ±5.67%
# [141] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     Feedback:TrialType:CueType + SubjectID                                                                                                                                                                    : 455230.2    ±5.34%
# [142] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType +     TrialType:CueType + Feedback:TrialType:CueType + SubjectID                                                                                                                                              : 175509.1    ±5.36%
# [143] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     Feedback:TrialType:CueType + SubjectID                                                                                                          : 49573.25    ±14.11%
# [144] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType +     TrialType:CueType + Feedback:TrialType:CueType + SubjectID                                                                                                                                       : 249595.3    ±5.77%
# [145] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType +     Feedback:BlockOrder:CueType + TrialType:CueType + Feedback:TrialType:CueType +     SubjectID                                                                                                            : 38194.55    ±6.27%
# [146] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType +     TrialType:CueType + Feedback:TrialType:CueType + SubjectID                                                                            : 9187.655    ±10.02%
# [147] BlockOrder + TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + TrialType:CueType + BlockOrder:TrialType:CueType + SubjectID                                                                                                                                                                                                                         : 62916887    ±12.7%
# [148] Feedback + BlockOrder + TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + TrialType:CueType + BlockOrder:TrialType:CueType +     SubjectID                                                                                                                                                                                                          : 13709588    ±6.41%
# [149] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + TrialType:CueType + BlockOrder:TrialType:CueType +     SubjectID                                                                                                                                                                                    : 4854548     ±5.34%
# [150] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + TrialType:CueType + BlockOrder:TrialType:CueType +     SubjectID                                                                                                                                                                                     : 4114430     ±7.58%
# [151] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + TrialType:CueType +     BlockOrder:TrialType:CueType + SubjectID                                                                                                                                                               : 1628014     ±9.17%
# [152] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     BlockOrder:CueType + TrialType:CueType + BlockOrder:TrialType:CueType +     SubjectID                                                                                                                           : 358447.2    ±9.17%
# [153] Feedback + BlockOrder + TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     BlockOrder:TrialType:CueType + SubjectID                                                                                                                                                                                       : 2034984     ±6.47%
# [154] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     BlockOrder:TrialType:CueType + SubjectID                                                                                                                                                                 : 958445.7    ±15.89%
# [155] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     BlockOrder:TrialType:CueType + SubjectID                                                                                                                                                                  : 700234.6    ±10.79%
# [156] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType +     TrialType:CueType + BlockOrder:TrialType:CueType + SubjectID                                                                                                                                            : 255853.3    ±10.83%
# [157] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     BlockOrder:TrialType:CueType + SubjectID                                                                                                        : 56590.15    ±11.28%
# [158] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType +     TrialType:CueType + BlockOrder:TrialType:CueType + SubjectID                                                                                                                                   : 146875.1    ±4.44%
# [159] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType +     Feedback:BlockOrder:CueType + TrialType:CueType + BlockOrder:TrialType:CueType +     SubjectID                                                                                                          : 53539.72    ±11.42%
# [160] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType +     TrialType:CueType + BlockOrder:TrialType:CueType + SubjectID                                                                          : 11064.82    ±8.48%
# [161] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     Feedback:TrialType:CueType + BlockOrder:TrialType:CueType +     SubjectID                                                                                                                                 : 245169.5    ±45.04%
# [162] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType +     TrialType:CueType + Feedback:TrialType:CueType + BlockOrder:TrialType:CueType +     SubjectID                                                                                                           : 95149.43    ±40.46%
# [163] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     Feedback:TrialType:CueType + BlockOrder:TrialType:CueType +     SubjectID                                                                       : 15280.02    ±7.56%
# [164] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType +     Feedback:BlockOrder:CueType + TrialType:CueType + Feedback:TrialType:CueType +     BlockOrder:TrialType:CueType + SubjectID                                                                             : 12430.06    ±5.59%
# [165] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType +     TrialType:CueType + Feedback:TrialType:CueType + BlockOrder:TrialType:CueType +     SubjectID                                         : 3291.036    ±7.94%
# [166] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType +     TrialType:CueType + Feedback:TrialType:CueType + BlockOrder:TrialType:CueType +     Feedback:BlockOrder:TrialType:CueType + SubjectID : 726.722     ±10.84%
#
# Against denominator:
#   IE ~ SubjectID
# ---
# Bayes factor type: BFlinearModel, JZS
#                                       Pr(prior) Pr(posterior) Inclusion BF
# Feedback                                  0.886         0.349 6.900000e-02
# BlockOrder                                0.886         0.818 5.760000e-01
# Feedback:BlockOrder                       0.503         0.082 8.800000e-02
# TrialType                                 0.886         1.000 1.015114e+08
# Feedback:TrialType                        0.503         0.080 8.600000e-02
# BlockOrder:TrialType                      0.503         0.146 1.690000e-01
# Feedback:BlockOrder:TrialType             0.120         0.001 6.000000e-03
# CueType                                   0.886         1.000 1.060780e+03
# Feedback:CueType                          0.503         0.053 5.600000e-02
# BlockOrder:CueType                        0.503         0.666 1.973000e+00
# Feedback:BlockOrder:CueType               0.120         0.002 1.400000e-02
# TrialType:CueType                         0.503         1.000 4.091422e+03
# Feedback:TrialType:CueType                0.120         0.003 2.100000e-02
# BlockOrder:TrialType:CueType              0.120         0.032 2.460000e-01
# Feedback:BlockOrder:TrialType:CueType     0.006         0.000 0.000000e+00
#
# Inclusion BFs compared among all models.

# %% [markdown]
# What about transfer?

# %%
rawRTData_T <- read.csv('SCT_ANOVA_RT.csv')
rawRTData_T$RT <- as.numeric(as.character(rawRTData_T$RT))

rawRTData_T <- within(rawRTData_T, {
  subject <- factor(subject)
  Congruency <- factor(Congruency)
  BlockType <- factor(BlockType)
   Feedback <- factor(Feedback)
    BlockOrder <- factor(BlockOrder)
})

SCT_RT_runANOVA <- anovaBF(RT ~ BlockType*Congruency*Feedback*BlockOrder + subject,
                                  data=rawRTData_T,
                                  whichRandom="subject")

png(file="Bayes_SCT_RT.png", width = 3000, height = 700, res = 60)
plot(SCT_RT_runANOVA)
dev.off()
print(SCT_RT_runANOVA)
print(inclusionBF(SCT_RT_runANOVA))
# Out:
# Warning message in doNwaySampling(method, y, X, rscale, iterations, gMap, incCont, :
# "Some NAs were removed from sampling results: 1 in total."
# png
#   2
# Bayes factor analysis
# --------------
# [1] BlockType + subject                                                                                                                                                                                                                                                                                                                                                                         : 16.76939     ±1%
# [2] Congruency + subject                                                                                                                                                                                                                                                                                                                                                                        : 1.765756e+15 ±2.73%
# [3] BlockType + Congruency + subject                                                                                                                                                                                                                                                                                                                                                            : 9.70153e+16  ±1.65%
# [4] BlockType + Congruency + BlockType:Congruency + subject                                                                                                                                                                                                                                                                                                                                     : 3.724731e+16 ±6.59%
# [5] Feedback + subject                                                                                                                                                                                                                                                                                                                                                                          : 0.5126877    ±4.06%
# [6] BlockType + Feedback + subject                                                                                                                                                                                                                                                                                                                                                              : 7.632139     ±5.05%
# [7] Congruency + Feedback + subject                                                                                                                                                                                                                                                                                                                                                             : 1.007456e+15 ±4.67%
# [8] BlockType + Congruency + Feedback + subject                                                                                                                                                                                                                                                                                                                                                 : 5.375725e+16 ±5.6%
# [9] BlockType + Congruency + BlockType:Congruency + Feedback + subject                                                                                                                                                                                                                                                                                                                          : 1.993067e+16 ±6.86%
# [10] BlockType + Feedback + BlockType:Feedback + subject                                                                                                                                                                                                                                                                                                                                        : 1.965724     ±6.23%
# [11] BlockType + Congruency + Feedback + BlockType:Feedback + subject                                                                                                                                                                                                                                                                                                                           : 1.55532e+16  ±6.96%
# [12] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + subject                                                                                                                                                                                                                                                                                                    : 5.540859e+15 ±9.2%
# [13] Congruency + Feedback + Congruency:Feedback + subject                                                                                                                                                                                                                                                                                                                                      : 1.655625e+14 ±6.07%
# [14] BlockType + Congruency + Feedback + Congruency:Feedback + subject                                                                                                                                                                                                                                                                                                                          : 9.996643e+15 ±7.44%
# [15] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + subject                                                                                                                                                                                                                                                                                                   : 3.750569e+15 ±8.64%
# [16] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + subject                                                                                                                                                                                                                                                                                                     : 2.827255e+15 ±9.92%
# [17] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + subject                                                                                                                                                                                                                                                                              : 1.035784e+15 ±9.05%
# [18] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + subject                                                                                                                                                                                                                                              : 4.651229e+14 ±14.8%
# [19] BlockOrder + subject                                                                                                                                                                                                                                                                                                                                                                       : 0.7348113    ±2%
# [20] BlockType + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                                           : 26.00661     ±34.87%
# [21] Congruency + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                                          : 1.324873e+15 ±6.33%
# [22] BlockType + Congruency + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                              : 8.056656e+16 ±5.44%
# [23] BlockType + Congruency + BlockType:Congruency + BlockOrder + subject                                                                                                                                                                                                                                                                                                                       : 2.523089e+16 ±5.47%
# [24] Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                                            : 0.4515407    ±4.29%
# [25] BlockType + Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                                : 7.290179     ±5.29%
# [26] Congruency + Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                               : 7.912262e+14 ±5.07%
# [27] BlockType + Congruency + Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                   : 5.042009e+16 ±5.73%
# [28] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                            : 1.537194e+16 ±7.51%
# [29] BlockType + Feedback + BlockType:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                                           : 1.849614     ±6.18%
# [30] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                              : 1.208282e+16 ±7.07%
# [31] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                       : 4.410687e+15 ±8.92%
# [32] Congruency + Feedback + Congruency:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                                         : 1.529563e+14 ±6.49%
# [33] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                             : 9.298311e+15 ±7.22%
# [34] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                      : 3.086269e+15 ±8.59%
# [35] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                        : 2.751359e+15 ±8.45%
# [36] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                 : 9.533704e+14 ±11.62%
# [37] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     subject                                                                                                                                                                                                                             : 4.419049e+14 ±10.45%
# [38] BlockType + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                                                                    : 788.532      ±7.69%
# [39] BlockType + Congruency + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                                                       : 2.261802e+19 ±9.9%
# [40] BlockType + Congruency + BlockType:Congruency + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                                : 9.758269e+18 ±7.15%
# [41] BlockType + Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                                                         : 462.3774     ±6.18%
# [42] BlockType + Congruency + Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                                            : 1.531232e+19 ±6.47%
# [43] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                     : 5.684173e+18 ±8.71%
# [44] BlockType + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                                    : 108.686      ±7.67%
# [45] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                       : 4.071872e+18 ±7.72%
# [46] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                : 1.30916e+18  ±9.28%
# [47] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                      : 2.479112e+18 ±8.4%
# [48] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                               : 1.09177e+18  ±10.38%
# [49] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                 : 7.320303e+17 ±11.46%
# [50] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     subject                                                                                                                                                                                                                                      : 2.66341e+17  ±16.88%
# [51] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + subject                                                                                                                                                                                                      : 1.065482e+17 ±12.5%
# [52] Congruency + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                                                                  : 1.748396e+14 ±4.27%
# [53] BlockType + Congruency + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                                                      : 1.048111e+16 ±6.85%
# [54] BlockType + Congruency + BlockType:Congruency + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                               : 4.758576e+15 ±21.33%
# [55] Congruency + Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                                                       : 1.242626e+14 ±6.28%
# [56] BlockType + Congruency + Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                                           : 6.543797e+15 ±7.35%
# [57] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                    : 2.305146e+15 ±10.82%
# [58] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                      : 1.39804e+15  ±8.46%
# [59] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                               : 6.651655e+14 ±11.77%
# [60] Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                                 : 2.208911e+13 ±7.7%
# [61] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                     : 1.193776e+15 ±8.23%
# [62] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                              : 4.575335e+14 ±10.11%
# [63] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                : 3.403129e+14 ±10.18%
# [64] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder +     subject                                                                                                                                                                                                                                     : 1.224299e+14 ±14.46%
# [65] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     Congruency:BlockOrder + subject                                                                                                                                                                                                     : 4.561653e+13 ±13.47%
# [66] BlockType + Congruency + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                               : 2.86233e+18  ±6.92%
# [67] BlockType + Congruency + BlockType:Congruency + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                        : 1.624721e+18 ±40.54%
# [68] BlockType + Congruency + Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                    : 2.148992e+18 ±9.09%
# [69] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                             : 7.245568e+17 ±10.16%
# [70] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                               : 5.844179e+17 ±13.61%
# [71] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     subject                                                                                                                                                                                                                                    : 2.492691e+17 ±11.14%
# [72] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                              : 3.383823e+17 ±11.06%
# [73] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     subject                                                                                                                                                                                                                                   : 1.55156e+17  ±11.99%
# [74] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     subject                                                                                                                                                                                                                                     : 9.303717e+16 ±11.46%
# [75] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + subject                                                                                                                                                                                                              : 4.302211e+16 ±14.35%
# [76] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                              : 1.96211e+16  ±16.72%
# [77] BlockType + Congruency + BlockType:Congruency + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     subject                                                                                                                                                                                                                                  : 1.92954e+17  ±10.45%
# [78] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     subject                                                                                                                                                                                                                       : 1.378164e+17 ±10.33%
# [79] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     BlockType:Congruency:BlockOrder + subject                                                                                                                                                                                                  : 4.748367e+16 ±13.63%
# [80] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     BlockType:Congruency:BlockOrder + subject                                                                                                                                                                                                 : 2.173207e+16 ±11.62%
# [81] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     subject                                                                                                                                                                        : 9.071387e+15 ±26.29%
# [82] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     subject                                                                                                                                        : 3.308103e+15 ±17.53%
# [83] Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                                                      : 0.2608081    ±4.83%
# [84] BlockType + Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                                          : 4.906041     ±5.67%
# [85] Congruency + Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                                         : 4.954889e+14 ±5.5%
# [86] BlockType + Congruency + Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                             : 2.748458e+16 ±6.46%
# [87] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                      : 1.210043e+16 ±7.91%
# [88] BlockType + Feedback + BlockType:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                     : 1.239579     ±7.33%
# [89] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                        : 8.969345e+15 ±7.57%
# [90] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                 : 3.453796e+15 ±9.53%
# [91] Congruency + Feedback + Congruency:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                   : 8.923994e+13 ±6.82%
# [92] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                       : 5.507789e+15 ±7.99%
# [93] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                : 2.176604e+15 ±10.48%
# [94] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                  : 1.604623e+15 ±9.8%
# [95] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                       : 5.537627e+14 ±13.59%
# [96] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     Feedback:BlockOrder + subject                                                                                                                                                                                                       : 2.810946e+14 ±18.71%
# [97] BlockType + Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                   : 304.1709     ±6.54%
# [98] BlockType + Congruency + Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                      : 1.050777e+19 ±6.94%
# [99] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                               : 2.96956e+18  ±9.29%
# [100] BlockType + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                             : 89.66862     ±8.45%
# [101] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                : 2.327449e+18 ±9%
# [102] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                     : 8.227623e+17 ±10.2%
# [103] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                               : 1.911242e+18 ±8.56%
# [104] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                    : 7.461166e+17 ±16.66%
# [105] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                      : 5.007006e+17 ±13.17%
# [106] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Feedback:BlockOrder + subject                                                                                                                                                                                                               : 2.512586e+17 ±13.69%
# [107] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                               : 6.865862e+16 ±11.31%
# [108] Congruency + Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                : 7.153521e+13 ±7.65%
# [109] BlockType + Congruency + Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                    : 4.818505e+15 ±8.37%
# [110] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                             : 1.422502e+15 ±8.98%
# [111] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                               : 1.238203e+15 ±12.35%
# [112] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                    : 4.267948e+14 ±12.26%
# [113] Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                          : 1.471261e+13 ±8.2%
# [114] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                              : 7.428025e+14 ±9.2%
# [115] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                   : 3.029025e+14 ±11.92%
# [116] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                     : 2.812391e+14 ±11.7%
# [117] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + subject                                                                                                                                                                                                              : 6.193159e+13 ±10.36%
# ...
# [132] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + subject                                                                                                                 : 2.146143e+15 ±19.08%
# [133] BlockType + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + BlockType:Feedback:BlockOrder + subject                                                                                                                                                                                                                                             : 14.96592     ±9.26%
# [134] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + BlockType:Feedback:BlockOrder +     subject                                                                                                                                                                                                                            : 6.691091e+17 ±10.23%
# [135] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder +     BlockType:Feedback:BlockOrder + subject                                                                                                                                                                                                     : 2.070432e+17 ±13.33%
# [136] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder +     BlockType:Feedback:BlockOrder + subject                                                                                                                                                                                                      : 1.267616e+17 ±17.41%
# [137] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + subject                                                                                                                                                                               : 3.175367e+16 ±12.65%
# [138] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Feedback:BlockOrder + BlockType:Feedback:BlockOrder +     subject                                                                                                                                           : 1.71766e+16  ±15.7%
# [139] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     BlockType:Feedback:BlockOrder + subject                                                                                                                                                                                                    : 7.453383e+16 ±10.44%
# [140] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + subject                                                                                                                                                                             : 2.996969e+16 ±17.44%
# [141] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + subject                                                                                                                                                                              : 1.499044e+16 ±15.62%
# [142] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + Feedback:BlockOrder + BlockType:Feedback:BlockOrder +     subject                                                                                                                                                   : 6.548272e+15 ±15.94%
# [143] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     BlockType:Feedback:BlockOrder + subject                                                                                                                   : 2.155424e+15 ±16.48%
# [144] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     BlockType:Congruency:BlockOrder + Feedback:BlockOrder + BlockType:Feedback:BlockOrder +     subject                                                                                                                                       : 3.993685e+15 ±12.1%
# [145] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + subject                                                                                                                 : 9.824239e+14 ±18.37%
# [146] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + subject                                                                                 : 4.989261e+14 ±16.43%
# [147] Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + Congruency:Feedback:BlockOrder + subject                                                                                                                                                                                                                                         : 2.730808e+12 ±9%
# [148] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                                                                                                                                                                         : 1.53077e+14  ±10.43%
# [149] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     Congruency:Feedback:BlockOrder + subject                                                                                                                                                                                                  : 5.1336e+13   ±16.21%
# [150] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     Congruency:Feedback:BlockOrder + subject                                                                                                                                                                                                    : 4.304032e+13 ±13.12%
# [151] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + Congruency:Feedback:BlockOrder + subject                                                                                                                                                                             : 1.360386e+13 ±12.15%
# [152] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     Congruency:BlockOrder + Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                                                                                         : 7.022022e+12 ±15.78%
# [153] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     Congruency:Feedback:BlockOrder + subject                                                                                                                                                                                                  : 4.613408e+16 ±10.7%
# [154] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + Congruency:Feedback:BlockOrder + subject                                                                                                                                                                           : 1.629096e+16 ±12.84%
# [155] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + Congruency:Feedback:BlockOrder + subject                                                                                                                                                                             : 1.271703e+16 ±11.92%
# [156] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                                                                                                  : 4.545558e+15 ±16.7%
# [157] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     Congruency:Feedback:BlockOrder + subject                                                                                                                  : 2.229481e+15 ±17.17%
# [158] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     BlockType:Congruency:BlockOrder + Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                                                                                     : 3.383307e+15 ±12.56%
# [159] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + Congruency:Feedback:BlockOrder + subject                                                                                                                : 8.230428e+14 ±18.98%
# [160] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + Congruency:Feedback:BlockOrder + subject                                                                                : 6.084232e+14 ±25.53%
# [161] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                                                                                         : 3.40165e+15  ±19.52%
# [162] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + Feedback:BlockOrder + BlockType:Feedback:BlockOrder +     Congruency:Feedback:BlockOrder + subject                                                                                                                  : 8.960828e+14 ±13.16%
# [163] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     BlockType:Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                              : 3.925529e+14 ±17.09%
# [164] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                            : 1.702203e+14 ±16.44%
# [165] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                            : 7.860439e+13 ±16.3%
# [166] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     BlockType:Congruency:Feedback:BlockOrder + subject : 2.388432e+13 ±28.09%
#
# Against denominator:
#   RT ~ subject
# ---
# Bayes factor type: BFlinearModel, JZS
#                                          Pr(prior) Pr(posterior) Inclusion BF
# BlockType                                    0.886         1.000 2.020416e+03
# Congruency                                   0.886         1.000 6.814980e+15
# BlockType:Congruency                         0.503         0.285 3.930000e-01
# Feedback                                     0.886         0.618 2.070000e-01
# BlockType:Feedback                           0.503         0.138 1.580000e-01
# Congruency:Feedback                          0.503         0.099 1.090000e-01
# BlockType:Congruency:Feedback                0.120         0.002 1.800000e-02
# BlockOrder                                   0.886         0.997 4.999100e+01
# BlockType:BlockOrder                         0.503         0.994 1.718840e+02
# Congruency:BlockOrder                        0.503         0.128 1.450000e-01
# BlockType:Congruency:BlockOrder              0.120         0.006 4.600000e-02
# Feedback:BlockOrder                          0.503         0.250 3.300000e-01
# BlockType:Feedback:BlockOrder                0.120         0.012 9.100000e-02
# Congruency:Feedback:BlockOrder               0.120         0.001 7.000000e-03
# BlockType:Congruency:Feedback:BlockOrder     0.006         0.000 0.000000e+00
#
# Inclusion BFs compared among all models.

# %%
rawACCData_T <- read.csv('SCT_ANOVA_ACC.csv')
rawACCData_T$Accuracy <- as.numeric(as.character(rawACCData_T$Accuracy))

rawACCData_T <- within(rawACCData_T, {
  subject <- factor(subject)
  Congruency <- factor(Congruency)
  BlockType <- factor(BlockType)
    Feedback <- factor(Feedback)
    BlockOrder <- factor(BlockOrder)
})

SCT_ACC_runANOVA <- anovaBF(Accuracy ~ BlockType*Congruency*Feedback*BlockOrder + subject,
                                  data=rawACCData_T,
                                  whichRandom="subject")

png(file="Bayes_SCT_ACC.png", width = 3000, height = 700, res = 60)
plot(SCT_ACC_runANOVA)
dev.off()
print(SCT_ACC_runANOVA)
print(inclusionBF(SCT_ACC_runANOVA))
# Out:
# png
#   2
# Bayes factor analysis
# --------------
# [1] BlockType + subject                                                                                                                                                                                                                                                                                                                                                                         : 0.1880604    ±0.93%
# [2] Congruency + subject                                                                                                                                                                                                                                                                                                                                                                        : 24.31327     ±1.01%
# [3] BlockType + Congruency + subject                                                                                                                                                                                                                                                                                                                                                            : 4.655532     ±1.65%
# [4] BlockType + Congruency + BlockType:Congruency + subject                                                                                                                                                                                                                                                                                                                                     : 0.695148     ±3.72%
# [5] Feedback + subject                                                                                                                                                                                                                                                                                                                                                                          : 0.2138391    ±0.54%
# [6] BlockType + Feedback + subject                                                                                                                                                                                                                                                                                                                                                              : 0.0399023    ±1.18%
# [7] Congruency + Feedback + subject                                                                                                                                                                                                                                                                                                                                                             : 5.262339     ±1.87%
# [8] BlockType + Congruency + Feedback + subject                                                                                                                                                                                                                                                                                                                                                 : 1.011914     ±1.78%
# [9] BlockType + Congruency + BlockType:Congruency + Feedback + subject                                                                                                                                                                                                                                                                                                                          : 0.1450331    ±2.03%
# [10] BlockType + Feedback + BlockType:Feedback + subject                                                                                                                                                                                                                                                                                                                                        : 0.04176254   ±4.78%
# [11] BlockType + Congruency + Feedback + BlockType:Feedback + subject                                                                                                                                                                                                                                                                                                                           : 1.013091     ±1.73%
# [12] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + subject                                                                                                                                                                                                                                                                                                    : 0.1542626    ±4.47%
# [13] Congruency + Feedback + Congruency:Feedback + subject                                                                                                                                                                                                                                                                                                                                      : 0.8375834    ±6.37%
# [14] BlockType + Congruency + Feedback + Congruency:Feedback + subject                                                                                                                                                                                                                                                                                                                          : 0.1552314    ±6.18%
# [15] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + subject                                                                                                                                                                                                                                                                                                   : 0.03642999   ±41.04%
# [16] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + subject                                                                                                                                                                                                                                                                                                     : 0.1579869    ±4.06%
# [17] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + subject                                                                                                                                                                                                                                                                              : 0.02152013   ±2.74%
# [18] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + subject                                                                                                                                                                                                                                              : 0.004644942  ±6.28%
# [19] BlockOrder + subject                                                                                                                                                                                                                                                                                                                                                                       : 1.138871     ±2.27%
# [20] BlockType + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                                           : 0.2021376    ±1.38%
# [21] Congruency + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                                          : 27.10271     ±1.71%
# [22] BlockType + Congruency + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                              : 5.272955     ±2.01%
# [23] BlockType + Congruency + BlockType:Congruency + BlockOrder + subject                                                                                                                                                                                                                                                                                                                       : 0.7870304    ±5.14%
# [24] Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                                            : 0.2348835    ±1.63%
# [25] BlockType + Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                                : 0.04379946   ±4.17%
# [26] Congruency + Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                               : 6.069787     ±2.84%
# [27] BlockType + Congruency + Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                   : 1.186383     ±4.47%
# [28] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                            : 0.1555525    ±2.6%
# [29] BlockType + Feedback + BlockType:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                                           : 0.05592021   ±25.6%
# [30] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                              : 1.185943     ±3.49%
# [31] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                       : 0.1657489    ±4.9%
# [32] Congruency + Feedback + Congruency:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                                         : 0.8636202    ±2.78%
# [33] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                             : 0.1691344    ±4.6%
# [34] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                      : 0.0227331    ±2.98%
# [35] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                        : 0.1678327    ±3.53%
# [36] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                 : 0.0259099    ±6.95%
# [37] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     subject                                                                                                                                                                                                                             : 0.005113703  ±6.39%
# [38] BlockType + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                                                                    : 2.008132     ±2.33%
# [39] BlockType + Congruency + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                                                       : 56.12556     ±3.3%
# [40] BlockType + Congruency + BlockType:Congruency + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                                : 8.043491     ±3.4%
# [41] BlockType + Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                                                         : 0.4191221    ±3.91%
# [42] BlockType + Congruency + Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                                            : 13.28653     ±5.91%
# [43] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                     : 1.739526     ±4.57%
# [44] BlockType + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                                    : 0.4286183    ±2.75%
# [45] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                       : 15.46983     ±9.75%
# [46] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                : 1.892634     ±3.91%
# [47] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                      : 1.965218     ±6.32%
# [48] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                               : 0.4256025    ±36.12%
# [49] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                 : 2.111431     ±7.64%
# [50] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     subject                                                                                                                                                                                                                                      : 0.2786946    ±4.05%
# [51] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + subject                                                                                                                                                                                                      : 0.05882441   ±7.76%
# [52] Congruency + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                                                                  : 4.222165     ±6.3%
# [53] BlockType + Congruency + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                                                      : 0.7539954    ±3.3%
# [54] BlockType + Congruency + BlockType:Congruency + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                               : 0.1147633    ±3.64%
# [55] Congruency + Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                                                       : 0.8855493    ±2.72%
# [56] BlockType + Congruency + Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                                           : 0.1653376    ±4.43%
# [57] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                    : 0.02653261   ±11.24%
# [58] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                      : 0.1819666    ±7.4%
# [59] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                               : 0.02343951   ±6.67%
# [60] Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                                 : 0.1270259    ±2.91%
# [61] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                     : 0.0277019    ±12.14%
# [62] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                              : 0.003299604  ±3.03%
# [63] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                : 0.02431667   ±2.84%
# [64] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder +     subject                                                                                                                                                                                                                                     : 0.005414576  ±37.07%
# [65] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     Congruency:BlockOrder + subject                                                                                                                                                                                                     : 0.0008032056 ±7.33%
# [66] BlockType + Congruency + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                               : 8.675754     ±4.81%
# [67] BlockType + Congruency + BlockType:Congruency + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                        : 1.345296     ±7.4%
# [68] BlockType + Congruency + Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                    : 1.734515     ±3.06%
# [69] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                             : 0.2686079    ±4.95%
# [70] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                               : 1.931856     ±4.14%
# [71] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     subject                                                                                                                                                                                                                                    : 0.3711643    ±15.45%
# [72] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                              : 0.3320193    ±14.21%
# [73] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     subject                                                                                                                                                                                                                                   : 0.0385171    ±5.02%
# [74] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     subject                                                                                                                                                                                                                                     : 0.270512     ±3.23%
# [75] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + subject                                                                                                                                                                                                              : 0.04026061   ±4.62%
# [76] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                              : 0.009010848  ±6.45%
# [77] BlockType + Congruency + BlockType:Congruency + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     subject                                                                                                                                                                                                                                  : 0.6192044    ±4.32%
# [78] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     subject                                                                                                                                                                                                                       : 0.1470166    ±8.03%
# [79] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     BlockType:Congruency:BlockOrder + subject                                                                                                                                                                                                  : 0.1555098    ±5.92%
# [80] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     BlockType:Congruency:BlockOrder + subject                                                                                                                                                                                                 : 0.02102321   ±6.56%
# [81] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     subject                                                                                                                                                                        : 0.0272607    ±20.43%
# [82] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     subject                                                                                                                                        : 0.006146133  ±31.26%
# [83] Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                                                      : 0.06561017   ±1.63%
# [84] BlockType + Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                                          : 0.01264306   ±3.89%
# [85] Congruency + Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                                         : 1.64953      ±2.42%
# [86] BlockType + Congruency + Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                             : 0.3486877    ±5.3%
# [87] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                      : 0.04901014   ±7.62%
# [88] BlockType + Feedback + BlockType:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                     : 0.014215     ±9.47%
# [89] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                        : 0.317659     ±2.47%
# [90] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                 : 0.0444238    ±4.4%
# [91] Congruency + Feedback + Congruency:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                   : 0.2412601    ±3.22%
# [92] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                       : 0.04773605   ±4.41%
# [93] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                : 0.006667956  ±3.52%
# [94] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                  : 0.059654     ±14.23%
# [95] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                       : 0.006881221  ±3.66%
# [96] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     Feedback:BlockOrder + subject                                                                                                                                                                                                       : 0.001367929  ±5.05%
# [97] BlockType + Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                   : 0.1179883    ±2.7%
# [98] BlockType + Congruency + Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                      : 3.410462     ±2.86%
# [99] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                               : 0.4788936    ±3.24%
# [100] BlockType + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                             : 0.1241751    ±4.12%
# [101] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                : 3.769797     ±4.57%
# [102] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                     : 0.5442502    ±4.16%
# [103] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                               : 0.5513437    ±5.61%
# [104] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                    : 0.07224424   ±3.9%
# [105] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                      : 0.5547472    ±3.55%
# [106] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Feedback:BlockOrder + subject                                                                                                                                                                                                               : 0.07844699   ±4.71%
# [107] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                               : 0.01620383   ±8.18%
# [108] Congruency + Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                : 0.2286923    ±2.04%
# [109] BlockType + Congruency + Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                    : 0.04504848   ±3.79%
# [110] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                             : 0.006757019  ±5.12%
# [111] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                               : 0.0496601    ±4.33%
# [112] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                    : 0.00717606   ±5.38%
# [113] Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                          : 0.03701768   ±5.42%
# [114] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                              : 0.006542154  ±3.75%
# [115] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                   : 0.001018537  ±8.32%
# [116] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                     : 0.008304682  ±10.21%
# [117] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + subject                                                                                                                                                                                                              : 0.001123909  ±10.89%
# [118] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     Congruency:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                              : 0.0001927137 ±5.02%
# ...
# [131] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + subject                                                                                                                                                 : 0.006807059  ±7.7%
# [132] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + subject                                                                                                                 : 0.001223771  ±6.94%
# [133] BlockType + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + BlockType:Feedback:BlockOrder + subject                                                                                                                                                                                                                                             : 0.1281446    ±3.9%
# [134] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + BlockType:Feedback:BlockOrder +     subject                                                                                                                                                                                                                            : 4.854843     ±12.32%
# [135] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder +     BlockType:Feedback:BlockOrder + subject                                                                                                                                                                                                     : 0.6632032    ±8.47%
# [136] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder +     BlockType:Feedback:BlockOrder + subject                                                                                                                                                                                                      : 0.6376887    ±6.11%
# [137] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + subject                                                                                                                                                                               : 0.08788475   ±4.48%
# [138] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Feedback:BlockOrder + BlockType:Feedback:BlockOrder +     subject                                                                                                                                           : 0.02072701   ±7.55%
# [139] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     BlockType:Feedback:BlockOrder + subject                                                                                                                                                                                                    : 0.6453658    ±6.86%
# [140] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + subject                                                                                                                                                                             : 0.08919232   ±4.75%
# [141] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + subject                                                                                                                                                                              : 0.09316306   ±5.26%
# [142] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + Feedback:BlockOrder + BlockType:Feedback:BlockOrder +     subject                                                                                                                                                   : 0.01251841   ±5.61%
# [143] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     BlockType:Feedback:BlockOrder + subject                                                                                                                   : 0.002680795  ±6.34%
# [144] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     BlockType:Congruency:BlockOrder + Feedback:BlockOrder + BlockType:Feedback:BlockOrder +     subject                                                                                                                                       : 0.05015494   ±6.87%
# [145] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + subject                                                                                                                 : 0.00703371   ±8.67%
# [146] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + subject                                                                                 : 0.001611034  ±13.94%
# [147] Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + Congruency:Feedback:BlockOrder + subject                                                                                                                                                                                                                                         : 0.006918471  ±2.88%
# [148] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                                                                                                                                                                         : 0.001283379  ±3.46%
# [149] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     Congruency:Feedback:BlockOrder + subject                                                                                                                                                                                                  : 0.000195306  ±4.98%
# [150] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     Congruency:Feedback:BlockOrder + subject                                                                                                                                                                                                    : 0.001596258  ±7.65%
# [151] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + Congruency:Feedback:BlockOrder + subject                                                                                                                                                                             : 0.000205076  ±6.8%
# [152] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     Congruency:BlockOrder + Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                                                                                         : 5.156467e-05 ±18.41%
# [153] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     Congruency:Feedback:BlockOrder + subject                                                                                                                                                                                                  : 0.01685974   ±9.55%
# [154] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + Congruency:Feedback:BlockOrder + subject                                                                                                                                                                           : 0.002191636  ±6.92%
# [155] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + Congruency:Feedback:BlockOrder + subject                                                                                                                                                                             : 0.01838947   ±7.52%
# [156] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                                                                                                  : 0.00243705   ±8.52%
# [157] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     Congruency:Feedback:BlockOrder + subject                                                                                                                  : 0.0004881124 ±7.84%
# [158] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     BlockType:Congruency:BlockOrder + Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                                                                                     : 0.001444316  ±14.3%
# [159] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + Congruency:Feedback:BlockOrder + subject                                                                                                                : 0.00131868   ±8.21%
# [160] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + Congruency:Feedback:BlockOrder + subject                                                                                : 0.0002992353 ±8.96%
# [161] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                                                                                         : 0.03119686   ±40.3%
# [162] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + Feedback:BlockOrder + BlockType:Feedback:BlockOrder +     Congruency:Feedback:BlockOrder + subject                                                                                                                  : 0.002756331  ±6.66%
# [163] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     BlockType:Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                              : 0.0006664945 ±14.17%
# [164] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                            : 0.00147771   ±7.88%
# [165] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                            : 0.0003152949 ±10.42%
# [166] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     BlockType:Congruency:Feedback:BlockOrder + subject : 8.451902e-05 ±16.29%
#
# Against denominator:
#   Accuracy ~ subject
# ---
# Bayes factor type: BFlinearModel, JZS
#                                          Pr(prior) Pr(posterior) Inclusion BF
# BlockType                                    0.886         0.681        0.274
# Congruency                                   0.886         0.972        4.500
# BlockType:Congruency                         0.503         0.087        0.095
# Feedback                                     0.886         0.369        0.075
# BlockType:Feedback                           0.503         0.172        0.205
# Congruency:Feedback                          0.503         0.048        0.049
# BlockType:Congruency:Feedback                0.120         0.001        0.004
# BlockOrder                                   0.886         0.829        0.622
# BlockType:BlockOrder                         0.503         0.595        1.450
# Congruency:BlockOrder                        0.503         0.109        0.121
# BlockType:Congruency:BlockOrder              0.120         0.005        0.036
# Feedback:BlockOrder                          0.503         0.094        0.102
# BlockType:Feedback:BlockOrder                0.120         0.031        0.238
# Congruency:Feedback:BlockOrder               0.120         0.000        0.003
# BlockType:Congruency:Feedback:BlockOrder     0.006         0.000        0.000
#
# Inclusion BFs compared among all models.

# %%
IEdata_T <- read.csv('IE_transfer.csv')
IEdata_T$IE <- as.numeric(as.character(IEdata_T$IE))

IEdata_T <- within(IEdata_T, {
  SubjectID <- factor(SubjectID)
  CueType <- factor(CueType)
  TrialType <- factor(TrialType)
  Feedback <- factor(Feedback)
  BlockOrder <- factor(BlockOrder)
})

SC_IET_runANOVA <- anovaBF(IE ~ CueType*TrialType*Feedback*BlockOrder + SubjectID,
                           data=IEdata_T,
                           whichRandom="SubjectID")

png(file="Bayes_SC_IE_T.png", width = 3000, height = 700, res = 60)
plot(SC_IET_runANOVA)
dev.off()
print(SC_IET_runANOVA)
print(inclusionBF(SC_IET_runANOVA))
# Out:
# png
#   2
# Bayes factor analysis
# --------------
# [1] Feedback + SubjectID                                                                                                                                                                                                                                                                                                                                                  : 0.3146924  ±3.09%
# [2] BlockOrder + SubjectID                                                                                                                                                                                                                                                                                                                                                : 1.441577   ±0.85%
# [3] Feedback + BlockOrder + SubjectID                                                                                                                                                                                                                                                                                                                                     : 0.4775882  ±3.45%
# [4] Feedback + BlockOrder + Feedback:BlockOrder + SubjectID                                                                                                                                                                                                                                                                                                               : 0.188896   ±4.18%
# [5] TrialType + SubjectID                                                                                                                                                                                                                                                                                                                                                 : 5244.624   ±1.31%
# [6] Feedback + TrialType + SubjectID                                                                                                                                                                                                                                                                                                                                      : 1669.75    ±3.66%
# [7] BlockOrder + TrialType + SubjectID                                                                                                                                                                                                                                                                                                                                    : 7960.218   ±3.34%
# [8] Feedback + BlockOrder + TrialType + SubjectID                                                                                                                                                                                                                                                                                                                         : 2437.985   ±4.17%
# [9] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + SubjectID                                                                                                                                                                                                                                                                                                   : 1100.062   ±4.71%
# [10] Feedback + TrialType + Feedback:TrialType + SubjectID                                                                                                                                                                                                                                                                                                                : 258.871    ±4.52%
# [11] Feedback + BlockOrder + TrialType + Feedback:TrialType + SubjectID                                                                                                                                                                                                                                                                                                   : 372.9821   ±5.19%
# [12] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + SubjectID                                                                                                                                                                                                                                                                             : 159.9373   ±5.7%
# [13] BlockOrder + TrialType + BlockOrder:TrialType + SubjectID                                                                                                                                                                                                                                                                                                            : 1312.519   ±14.78%
# [14] Feedback + BlockOrder + TrialType + BlockOrder:TrialType + SubjectID                                                                                                                                                                                                                                                                                                 : 362.3062   ±4.77%
# [15] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + SubjectID                                                                                                                                                                                                                                                                           : 153.7976   ±6.03%
# [16] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + SubjectID                                                                                                                                                                                                                                                                            : 52.2002    ±7.53%
# [17] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + SubjectID                                                                                                                                                                                                                                                      : 21.18486   ±7.36%
# [18] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + SubjectID                                                                                                                                                                                                                      : 4.51644    ±7.38%
# [19] CueType + SubjectID                                                                                                                                                                                                                                                                                                                                                  : 0.3271143  ±3.25%
# [20] Feedback + CueType + SubjectID                                                                                                                                                                                                                                                                                                                                       : 0.09729083 ±3.82%
# [21] BlockOrder + CueType + SubjectID                                                                                                                                                                                                                                                                                                                                     : 0.4623805  ±2.17%
# [22] Feedback + BlockOrder + CueType + SubjectID                                                                                                                                                                                                                                                                                                                          : 0.1480133  ±4.46%
# [23] Feedback + BlockOrder + Feedback:BlockOrder + CueType + SubjectID                                                                                                                                                                                                                                                                                                    : 0.05879936 ±5.25%
# [24] TrialType + CueType + SubjectID                                                                                                                                                                                                                                                                                                                                      : 1775.142   ±2.32%
# [25] Feedback + TrialType + CueType + SubjectID                                                                                                                                                                                                                                                                                                                           : 547.629    ±4.72%
# [26] BlockOrder + TrialType + CueType + SubjectID                                                                                                                                                                                                                                                                                                                         : 2670.836   ±2.86%
# [27] Feedback + BlockOrder + TrialType + CueType + SubjectID                                                                                                                                                                                                                                                                                                              : 901.7224   ±5.44%
# [28] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + CueType + SubjectID                                                                                                                                                                                                                                                                                        : 340.7633   ±5.55%
# [29] Feedback + TrialType + Feedback:TrialType + CueType + SubjectID                                                                                                                                                                                                                                                                                                      : 95.83571   ±6.24%
# [30] Feedback + BlockOrder + TrialType + Feedback:TrialType + CueType + SubjectID                                                                                                                                                                                                                                                                                         : 119.8335   ±5.62%
# [31] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + CueType + SubjectID                                                                                                                                                                                                                                                                   : 49.481     ±6.63%
# [32] BlockOrder + TrialType + BlockOrder:TrialType + CueType + SubjectID                                                                                                                                                                                                                                                                                                  : 735.9396   ±50.58%
# [33] Feedback + BlockOrder + TrialType + BlockOrder:TrialType + CueType + SubjectID                                                                                                                                                                                                                                                                                       : 135.6558   ±6.69%
# [34] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + CueType + SubjectID                                                                                                                                                                                                                                                                 : 48.65111   ±6.68%
# [35] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + SubjectID                                                                                                                                                                                                                                                                  : 19.34403   ±7.55%
# [36] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + SubjectID                                                                                                                                                                                                                                            : 6.603465   ±7.82%
# [37] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     SubjectID                                                                                                                                                                                                        : 1.636761   ±7.97%
# [38] Feedback + CueType + Feedback:CueType + SubjectID                                                                                                                                                                                                                                                                                                                    : 0.1373611  ±4.59%
# [39] Feedback + BlockOrder + CueType + Feedback:CueType + SubjectID                                                                                                                                                                                                                                                                                                       : 0.223493   ±5.34%
# [40] Feedback + BlockOrder + Feedback:BlockOrder + CueType + Feedback:CueType + SubjectID                                                                                                                                                                                                                                                                                 : 0.09310936 ±6.22%
# [41] Feedback + TrialType + CueType + Feedback:CueType + SubjectID                                                                                                                                                                                                                                                                                                        : 949.4426   ±5.54%
# [42] Feedback + BlockOrder + TrialType + CueType + Feedback:CueType + SubjectID                                                                                                                                                                                                                                                                                           : 1258.63    ±5.64%
# [43] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + CueType + Feedback:CueType + SubjectID                                                                                                                                                                                                                                                                     : 592.2932   ±7.04%
# [44] Feedback + TrialType + Feedback:TrialType + CueType + Feedback:CueType + SubjectID                                                                                                                                                                                                                                                                                   : 134.587    ±6.25%
# [45] Feedback + BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + SubjectID                                                                                                                                                                                                                                                                      : 222.5682   ±7.34%
# [46] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + SubjectID                                                                                                                                                                                                                                                : 84.54402   ±7.74%
# [47] Feedback + BlockOrder + TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + SubjectID                                                                                                                                                                                                                                                                    : 201.977    ±7.74%
# [48] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + SubjectID                                                                                                                                                                                                                                              : 85.92156   ±7.54%
# [49] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + SubjectID                                                                                                                                                                                                                                               : 28.18587   ±11.17%
# [50] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + SubjectID                                                                                                                                                                                                                         : 13.56842   ±9.84%
# [51] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     Feedback:CueType + SubjectID                                                                                                                                                                                     : 2.68826    ±9.5%
# [52] BlockOrder + CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                                                                                : 7.677115   ±7.83%
# [53] Feedback + BlockOrder + CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                                                                     : 2.247784   ±5.01%
# [54] Feedback + BlockOrder + Feedback:BlockOrder + CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                                               : 0.7889132  ±5.41%
# [55] BlockOrder + TrialType + CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                                                                    : 49276.44   ±3.02%
# [56] Feedback + BlockOrder + TrialType + CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                                                         : 15199.08   ±5.67%
# [57] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                                   : 7187.297   ±6.76%
# [58] Feedback + BlockOrder + TrialType + Feedback:TrialType + CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                                    : 2700.374   ±7.44%
# [59] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                              : 1012.889   ±7.53%
# [60] BlockOrder + TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                                             : 7204.594   ±4.45%
# [61] Feedback + BlockOrder + TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                                  : 2722.985   ±6.63%
# [62] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                            : 1103.139   ±8.75%
# [63] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                             : 379.1833   ±8.4%
# [64] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                       : 139.6713   ±9.55%
# [65] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     BlockOrder:CueType + SubjectID                                                                                                                                                                                   : 32.4737    ±9.7%
# [66] Feedback + BlockOrder + CueType + Feedback:CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                                                  : 3.185564   ±5.87%
# [67] Feedback + BlockOrder + Feedback:BlockOrder + CueType + Feedback:CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                            : 1.275628   ±7.07%
# [68] Feedback + BlockOrder + TrialType + CueType + Feedback:CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                                      : 30671.65   ±6.49%
# [69] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + CueType + Feedback:CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                : 12709.07   ±8.17%
# [70] Feedback + BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                 : 5075.398   ±7.59%
# [71] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                           : 2143.364   ±8.39%
# [72] Feedback + BlockOrder + TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                               : 4243.887   ±8.48%
# [73] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                         : 1810.008   ±9.05%
# [74] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                          : 611.2985   ±10.65%
# [75] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType +     SubjectID                                                                                                                                                                                                : 220.5031   ±9.18%
# [76] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     Feedback:CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                : 52.30515   ±13.85%
# [77] Feedback + BlockOrder + Feedback:BlockOrder + CueType + Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType + SubjectID                                                                                                                                                                                                                              : 0.6606371  ±7.12%
# [78] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + CueType + Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType +     SubjectID                                                                                                                                                                                                              : 6017.545   ±8.55%
# [79] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType +     SubjectID                                                                                                                                                                                         : 1322.833   ±11%
# [80] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType +     SubjectID                                                                                                                                                                                       : 1215.434   ±10.68%
# [81] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType +     Feedback:BlockOrder:CueType + SubjectID                                                                                                                                                                  : 164.9307   ±9.87%
# [82] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType +     SubjectID                                                                                                                              : 41.7565    ±20.08%
# [83] TrialType + CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                                                                                  : 248.6113   ±2.84%
# [84] Feedback + TrialType + CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                                                                       : 72.00786   ±5.69%
# [85] BlockOrder + TrialType + CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                                                                     : 339.5829   ±1.96%
# [86] Feedback + BlockOrder + TrialType + CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                                                          : 112.5093   ±5.72%
# [87] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                                    : 49.14946   ±7.17%
# [88] Feedback + TrialType + Feedback:TrialType + CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                                                  : 10.72017   ±5.81%
# [89] Feedback + BlockOrder + TrialType + Feedback:TrialType + CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                                     : 16.82249   ±7.73%
# [90] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                               : 9.058317   ±8.75%
# [91] BlockOrder + TrialType + BlockOrder:TrialType + CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                                              : 48.36494   ±2.42%
# [92] Feedback + BlockOrder + TrialType + BlockOrder:TrialType + CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                                   : 18.53088   ±8.3%
# [93] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                             : 7.449846   ±7.66%
# [94] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                              : 2.556853   ±8.05%
# [95] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                        : 1.117269   ±11.12%
# [96] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     TrialType:CueType + SubjectID                                                                                                                                                                                    : 0.2288971  ±12.75%
# [97] Feedback + TrialType + CueType + Feedback:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                                                    : 130.0432   ±6.35%
# [98] Feedback + BlockOrder + TrialType + CueType + Feedback:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                                       : 179.7413   ±7.14%
# [99] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + CueType + Feedback:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                 : 75.24485   ±8.03%
# [100] Feedback + TrialType + Feedback:TrialType + CueType + Feedback:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                              : 18.11439   ±8.52%
# [101] Feedback + BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                 : 30.6656    ±7.98%
# [102] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                           : 11.90194   ±12.25%
# [103] Feedback + BlockOrder + TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                               : 23.41658   ±7.81%
# [104] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                         : 11.39501   ±9.97%
# [105] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                          : 3.630715   ±9.78%
# [106] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + TrialType:CueType +     SubjectID                                                                                                                                                                                                : 1.592332   ±10.25%
# [107] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     Feedback:CueType + TrialType:CueType + SubjectID                                                                                                                                                                : 0.2956546  ±11.87%
# [108] BlockOrder + TrialType + CueType + BlockOrder:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                                               : 6797.973   ±2.52%
# [109] Feedback + BlockOrder + TrialType + CueType + BlockOrder:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                                    : 2548.844   ±8.28%
# [110] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + CueType + BlockOrder:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                              : 987.081    ±8.16%
# [111] Feedback + BlockOrder + TrialType + Feedback:TrialType + CueType + BlockOrder:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                               : 304.2511   ±10.07%
# [112] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + CueType + BlockOrder:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                         : 168.9021   ±8.82%
# [113] BlockOrder + TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                        : 1090.248   ±10.1%
# [114] Feedback + BlockOrder + TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                             : 310.9243   ±9.54%
# [115] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                       : 110.3944   ±7.31%
# [116] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                        : 48.43943   ±8.46%
# [117] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + TrialType:CueType +     SubjectID                                                                                                                                                                                              : 20.11973   ±10.2%
# [118] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     BlockOrder:CueType + TrialType:CueType + SubjectID                                                                                                                                                              : 4.659021   ±14.73%
# [119] Feedback + BlockOrder + TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                 : 3715.677   ±7.43%
# [120] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     SubjectID                                                                                                                                                                                                                       : 1537.618   ±7.94%
# [121] Feedback + BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     SubjectID                                                                                                                                                                                                                        : 652.9486   ±15.84%
# [122] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     SubjectID                                                                                                                                                                                                  : 235.5973   ±10.62%
# [123] Feedback + BlockOrder + TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     SubjectID                                                                                                                                                                                                                      : 592.9761   ±10.68%
# [124] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     SubjectID                                                                                                                                                                                                : 286.8783   ±13.26%
# [125] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     SubjectID                                                                                                                                                                                                 : 88.41227   ±10.05%
# ...
# [129] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType +     TrialType:CueType + SubjectID                                                                                                                                                                    : 147.1667   ±12.85%
# [130] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType +     TrialType:CueType + SubjectID                                                                                                                                                                  : 133.8088   ±11.64%
# [131] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType +     Feedback:BlockOrder:CueType + TrialType:CueType + SubjectID                                                                                                                                             : 22.06904   ±12.81%
# [132] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType +     TrialType:CueType + SubjectID                                                                                                         : 4.637513   ±12.26%
# [133] Feedback + TrialType + Feedback:TrialType + CueType + Feedback:CueType + TrialType:CueType + Feedback:TrialType:CueType + SubjectID                                                                                                                                                                                                                                 : 5.057517   ±10.99%
# [134] Feedback + BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + TrialType:CueType + Feedback:TrialType:CueType +     SubjectID                                                                                                                                                                                                                : 7.896148   ±10.24%
# [135] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + TrialType:CueType + Feedback:TrialType:CueType +     SubjectID                                                                                                                                                                                          : 3.197829   ±9.64%
# [136] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + TrialType:CueType + Feedback:TrialType:CueType +     SubjectID                                                                                                                                                                                         : 1.184604   ±13.39%
# [137] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + TrialType:CueType +     Feedback:TrialType:CueType + SubjectID                                                                                                                                                                   : 0.5897092  ±17.25%
# [138] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     Feedback:CueType + TrialType:CueType + Feedback:TrialType:CueType +     SubjectID                                                                                                                               : 0.1036147  ±12.13%
# [139] Feedback + BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     Feedback:TrialType:CueType + SubjectID                                                                                                                                                                                           : 156.1382   ±10.33%
# [140] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     Feedback:TrialType:CueType + SubjectID                                                                                                                                                                     : 83.14753   ±10.96%
# [141] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     Feedback:TrialType:CueType + SubjectID                                                                                                                                                                    : 23.16835   ±15.58%
# [142] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType +     TrialType:CueType + Feedback:TrialType:CueType + SubjectID                                                                                                                                              : 9.095947   ±14.74%
# [143] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     Feedback:TrialType:CueType + SubjectID                                                                                                          : 3.674822   ±21.72%
# [144] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType +     TrialType:CueType + Feedback:TrialType:CueType + SubjectID                                                                                                                                       : 61.31393   ±16.82%
# [145] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType +     Feedback:BlockOrder:CueType + TrialType:CueType + Feedback:TrialType:CueType +     SubjectID                                                                                                            : 5.271983   ±14.71%
# [146] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType +     TrialType:CueType + Feedback:TrialType:CueType + SubjectID                                                                            : 1.870059   ±22.54%
# [147] BlockOrder + TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + TrialType:CueType + BlockOrder:TrialType:CueType + SubjectID                                                                                                                                                                                                                         : 544.2752   ±10.12%
# [148] Feedback + BlockOrder + TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + TrialType:CueType + BlockOrder:TrialType:CueType +     SubjectID                                                                                                                                                                                                          : 149.7019   ±9.15%
# [149] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + TrialType:CueType + BlockOrder:TrialType:CueType +     SubjectID                                                                                                                                                                                    : 68.21162   ±9%
# [150] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + TrialType:CueType + BlockOrder:TrialType:CueType +     SubjectID                                                                                                                                                                                     : 24.32646   ±11.76%
# [151] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + TrialType:CueType +     BlockOrder:TrialType:CueType + SubjectID                                                                                                                                                               : 8.828717   ±11.46%
# [152] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     BlockOrder:CueType + TrialType:CueType + BlockOrder:TrialType:CueType +     SubjectID                                                                                                                           : 2.253006   ±12.6%
# [153] Feedback + BlockOrder + TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     BlockOrder:TrialType:CueType + SubjectID                                                                                                                                                                                       : 310.2639   ±12.1%
# [154] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     BlockOrder:TrialType:CueType + SubjectID                                                                                                                                                                 : 131.1271   ±10.97%
# [155] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     BlockOrder:TrialType:CueType + SubjectID                                                                                                                                                                  : 42.64698   ±16.28%
# [156] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType +     TrialType:CueType + BlockOrder:TrialType:CueType + SubjectID                                                                                                                                            : 18.81806   ±18.29%
# [157] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     BlockOrder:TrialType:CueType + SubjectID                                                                                                        : 3.518395   ±23.62%
# [158] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType +     TrialType:CueType + BlockOrder:TrialType:CueType + SubjectID                                                                                                                                   : 66.01841   ±15.04%
# [159] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType +     Feedback:BlockOrder:CueType + TrialType:CueType + BlockOrder:TrialType:CueType +     SubjectID                                                                                                          : 10.40828   ±20.59%
# [160] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType +     TrialType:CueType + BlockOrder:TrialType:CueType + SubjectID                                                                          : 1.997626   ±16.81%
# [161] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     Feedback:TrialType:CueType + BlockOrder:TrialType:CueType +     SubjectID                                                                                                                                 : 10.98064   ±19.25%
# [162] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType +     TrialType:CueType + Feedback:TrialType:CueType + BlockOrder:TrialType:CueType +     SubjectID                                                                                                           : 4.123645   ±12.39%
# [163] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     Feedback:TrialType:CueType + BlockOrder:TrialType:CueType +     SubjectID                                                                       : 0.9404696  ±16.83%
# [164] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType +     Feedback:BlockOrder:CueType + TrialType:CueType + Feedback:TrialType:CueType +     BlockOrder:TrialType:CueType + SubjectID                                                                             : 4.109982   ±24.55%
# [165] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType +     TrialType:CueType + Feedback:TrialType:CueType + BlockOrder:TrialType:CueType +     SubjectID                                         : 0.6127189  ±19.34%
# [166] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType +     TrialType:CueType + Feedback:TrialType:CueType + BlockOrder:TrialType:CueType +     Feedback:BlockOrder:TrialType:CueType + SubjectID : 0.111102   ±14.62%
#
# Against denominator:
#   IE ~ SubjectID
# ---
# Bayes factor type: BFlinearModel, JZS
#                                       Pr(prior) Pr(posterior) Inclusion BF
# Feedback                                  0.886         0.593        0.187
# BlockOrder                                0.886         0.947        2.280
# Feedback:BlockOrder                       0.503         0.206        0.257
# TrialType                                 0.886         1.000     1292.178
# Feedback:TrialType                        0.503         0.085        0.092
# BlockOrder:TrialType                      0.503         0.131        0.149
# Feedback:BlockOrder:TrialType             0.120         0.001        0.006
# CueType                                   0.886         0.899        1.145
# Feedback:CueType                          0.503         0.381        0.608
# BlockOrder:CueType                        0.503         0.840        5.175
# Feedback:BlockOrder:CueType               0.120         0.049        0.376
# TrialType:CueType                         0.503         0.115        0.128
# Feedback:TrialType:CueType                0.120         0.002        0.013
# BlockOrder:TrialType:CueType              0.120         0.007        0.050
# Feedback:BlockOrder:TrialType:CueType     0.006         0.000        0.000
#
# Inclusion BFs compared among all models.
