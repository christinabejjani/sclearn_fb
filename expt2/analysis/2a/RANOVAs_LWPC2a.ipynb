# %% [markdown]
# For some reason, the jupyter magic used to call the R script in the Python Jupyter notebook is calling R version 3.4.3, which I do not even have installed on my computer. So, in the meantime, I will run these R scripts in an actual 3.5.1 notebook...

# %%
setwd("C:/Users/cb383/Desktop/YearThree/controllearning/fbproject/LWPCfb/data/csvdata")

# %%
library(afex)

# %%
rawRTData <- read.csv('SC_ANOVA_RT.csv')
aov_car(RT ~ Feedback * BlockOrder + Error(subject/(Congruency*BlockType)), data = rawRTData, anova_table = list(es = "pes"))
# Out:
# Contrasts set to contr.sum for the following variables: Feedback, BlockOrder
# Anova Table (Type 3 tests)
#
# Response: RT
#                                      Effect    df      MSE         F   pes
# 1                                  Feedback 1, 56 14893.06      0.01 .0002
# 2                                BlockOrder 1, 56 14893.06      0.11  .002
# 3                       Feedback:BlockOrder 1, 56 14893.06      0.13  .002
# 4                                Congruency 1, 56   482.65 37.15 ***   .40
# 5                       Feedback:Congruency 1, 56   482.65      0.95   .02
# 6                     BlockOrder:Congruency 1, 56   482.65      0.32  .006
# 7            Feedback:BlockOrder:Congruency 1, 56   482.65      0.88   .02
# 8                                 BlockType 1, 56   946.91      1.85   .03
# 9                        Feedback:BlockType 1, 56   946.91      0.02 .0004
# 10                     BlockOrder:BlockType 1, 56   946.91    4.03 *   .07
# 11            Feedback:BlockOrder:BlockType 1, 56   946.91      1.55   .03
# 12                     Congruency:BlockType 1, 56   345.20   8.15 **   .13
# 13            Feedback:Congruency:BlockType 1, 56   345.20      0.05 .0009
# 14          BlockOrder:Congruency:BlockType 1, 56   345.20    4.26 *   .07
# 15 Feedback:BlockOrder:Congruency:BlockType 1, 56   345.20      0.74   .01
#    p.value
# 1      .91
# 2      .75
# 3      .72
# 4   <.0001
# 5      .33
# 6      .57
# 7      .35
# 8      .18
# 9      .88
# 10     .05
# 11     .22
# 12    .006
# 13     .83
# 14     .04
# 15     .39
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '+' 0.1 ' ' 1

# %%
rawACCData <- read.csv('SC_ANOVA_ACC.csv')
aov_car(Accuracy ~ Feedback * BlockOrder + Error(subject/(Congruency*BlockType)), data = rawACCData, anova_table = list(es = "pes"))
# Out:
# Contrasts set to contr.sum for the following variables: Feedback, BlockOrder
# Anova Table (Type 3 tests)
#
# Response: Accuracy
#                                      Effect    df  MSE         F   pes p.value
# 1                                  Feedback 1, 56 0.02      0.70   .01     .41
# 2                                BlockOrder 1, 56 0.02      1.60   .03     .21
# 3                       Feedback:BlockOrder 1, 56 0.02      0.89   .02     .35
# 4                                Congruency 1, 56 0.00 27.33 ***   .33  <.0001
# 5                       Feedback:Congruency 1, 56 0.00    3.41 +   .06     .07
# 6                     BlockOrder:Congruency 1, 56 0.00      0.61   .01     .44
# 7            Feedback:BlockOrder:Congruency 1, 56 0.00      0.49  .009     .49
# 8                                 BlockType 1, 56 0.01    2.97 +   .05     .09
# 9                        Feedback:BlockType 1, 56 0.01      0.03 .0006     .86
# 10                     BlockOrder:BlockType 1, 56 0.01    6.08 *   .10     .02
# 11            Feedback:BlockOrder:BlockType 1, 56 0.01      1.34   .02     .25
# 12                     Congruency:BlockType 1, 56 0.00 14.18 ***   .20   .0004
# 13            Feedback:Congruency:BlockType 1, 56 0.00      0.62   .01     .43
# 14          BlockOrder:Congruency:BlockType 1, 56 0.00    5.20 *   .08     .03
# 15 Feedback:BlockOrder:Congruency:BlockType 1, 56 0.00      0.17  .003     .68
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '+' 0.1 ' ' 1

# %%
rawIEData <- read.csv('IE_Main.csv')
aov_car(IE ~ Feedback * BlockOrder + Error(SubjectID/(TrialType*CueType)), data = rawIEData, anova_table = list(es = "pes"))
# Out:
# Contrasts set to contr.sum for the following variables: Feedback, BlockOrder
# Anova Table (Type 3 tests)
#
# Response: IE
#                                   Effect    df      MSE         F    pes
# 1                               Feedback 1, 56 74103.85      0.38   .007
# 2                             BlockOrder 1, 56 74103.85      0.43   .008
# 3                    Feedback:BlockOrder 1, 56 74103.85      0.08   .002
# 4                              TrialType 1, 56  8284.93 32.41 ***    .37
# 5                     Feedback:TrialType 1, 56  8284.93    2.84 +    .05
# 6                   BlockOrder:TrialType 1, 56  8284.93      0.34   .006
# 7          Feedback:BlockOrder:TrialType 1, 56  8284.93      0.02  .0003
# 8                                CueType 1, 56 18022.13      2.31    .04
# 9                       Feedback:CueType 1, 56 18022.13      0.02  .0003
# 10                    BlockOrder:CueType 1, 56 18022.13   8.25 **    .13
# 11           Feedback:BlockOrder:CueType 1, 56 18022.13    3.04 +    .05
# 12                     TrialType:CueType 1, 56 10295.01   9.56 **    .15
# 13            Feedback:TrialType:CueType 1, 56 10295.01      0.00 <.0001
# 14          BlockOrder:TrialType:CueType 1, 56 10295.01    6.62 *    .11
# 15 Feedback:BlockOrder:TrialType:CueType 1, 56 10295.01      0.76    .01
#    p.value
# 1      .54
# 2      .52
# 3      .77
# 4   <.0001
# 5      .10
# 6      .56
# 7      .90
# 8      .13
# 9      .89
# 10    .006
# 11     .09
# 12    .003
# 13     .97
# 14     .01
# 15     .39
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '+' 0.1 ' ' 1

# %% [markdown]
# What about transfer?

# %%
rawRTData_T <- read.csv('SCT_ANOVA_RT.csv')
aov_car(RT ~ Feedback * BlockOrder + Error(subject/(Congruency*BlockType)), data = rawRTData_T, anova_table = list(es = "pes"))
# Out:
# Contrasts set to contr.sum for the following variables: Feedback, BlockOrder
# Anova Table (Type 3 tests)
#
# Response: RT
#                                      Effect    df      MSE         F    pes
# 1                                  Feedback 1, 56 17536.97      0.12   .002
# 2                                BlockOrder 1, 56 17536.97      0.03  .0006
# 3                       Feedback:BlockOrder 1, 56 17536.97      0.10   .002
# 4                                Congruency 1, 56   334.80 49.17 ***    .47
# 5                       Feedback:Congruency 1, 56   334.80      1.22    .02
# 6                     BlockOrder:Congruency 1, 56   334.80      0.19   .003
# 7            Feedback:BlockOrder:Congruency 1, 56   334.80      1.13    .02
# 8                                 BlockType 1, 56   676.28      0.54   .009
# 9                        Feedback:BlockType 1, 56   676.28    4.80 *    .08
# 10                     BlockOrder:BlockType 1, 56   676.28    3.65 +    .06
# 11            Feedback:BlockOrder:BlockType 1, 56   676.28      0.98    .02
# 12                     Congruency:BlockType 1, 56   166.55      1.61    .03
# 13            Feedback:Congruency:BlockType 1, 56   166.55      0.28   .005
# 14          BlockOrder:Congruency:BlockType 1, 56   166.55      0.00 <.0001
# 15 Feedback:BlockOrder:Congruency:BlockType 1, 56   166.55      2.30    .04
#    p.value
# 1      .73
# 2      .85
# 3      .75
# 4   <.0001
# 5      .27
# 6      .66
# 7      .29
# 8      .47
# 9      .03
# 10     .06
# 11     .33
# 12     .21
# 13     .60
# 14     .99
# 15     .14
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '+' 0.1 ' ' 1

# %%
rawACCData_T <- read.csv('SCT_ANOVA_ACC.csv')
aov_car(Accuracy ~ Feedback * BlockOrder + Error(subject/(Congruency*BlockType)), data = rawACCData_T, anova_table = list(es = "pes"))
# Out:
# Contrasts set to contr.sum for the following variables: Feedback, BlockOrder
# Anova Table (Type 3 tests)
#
# Response: Accuracy
#                                      Effect    df  MSE      F   pes p.value
# 1                                  Feedback 1, 56 0.04   0.40  .007     .53
# 2                                BlockOrder 1, 56 0.04   1.19   .02     .28
# 3                       Feedback:BlockOrder 1, 56 0.04   0.04 .0008     .84
# 4                                Congruency 1, 56 0.00 3.55 +   .06     .06
# 5                       Feedback:Congruency 1, 56 0.00   2.45   .04     .12
# 6                     BlockOrder:Congruency 1, 56 0.00   1.32   .02     .26
# 7            Feedback:BlockOrder:Congruency 1, 56 0.00   0.89   .02     .35
# 8                                 BlockType 1, 56 0.01 3.12 +   .05     .08
# 9                        Feedback:BlockType 1, 56 0.01   0.13  .002     .72
# 10                     BlockOrder:BlockType 1, 56 0.01 4.00 +   .07     .05
# 11            Feedback:BlockOrder:BlockType 1, 56 0.01   0.09  .002     .76
# 12                     Congruency:BlockType 1, 56 0.00   0.92   .02     .34
# 13            Feedback:Congruency:BlockType 1, 56 0.00 5.85 *   .09     .02
# 14          BlockOrder:Congruency:BlockType 1, 56 0.00 2.85 +   .05     .10
# 15 Feedback:BlockOrder:Congruency:BlockType 1, 56 0.00   0.11  .002     .74
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '+' 0.1 ' ' 1

# %%
rawIEData_T <- read.csv('IE_transfer.csv')
aov_car(IE ~ Feedback * BlockOrder + Error(SubjectID/(TrialType*CueType)), data = rawIEData_T, anova_table = list(es = "pes"))
# Out:
# Contrasts set to contr.sum for the following variables: Feedback, BlockOrder
# Anova Table (Type 3 tests)
#
# Response: IE
#                                   Effect    df       MSE         F    pes
# 1                               Feedback 1, 56 143823.38      0.14   .003
# 2                             BlockOrder 1, 56 143823.38      0.59    .01
# 3                    Feedback:BlockOrder 1, 56 143823.38      0.03  .0005
# 4                              TrialType 1, 56   8231.42 13.10 ***    .19
# 5                     Feedback:TrialType 1, 56   8231.42      2.46    .04
# 6                   BlockOrder:TrialType 1, 56   8231.42      0.14   .003
# 7          Feedback:BlockOrder:TrialType 1, 56   8231.42    3.19 +    .05
# 8                                CueType 1, 56  38510.73    2.88 +    .05
# 9                       Feedback:CueType 1, 56  38510.73      0.14   .002
# 10                    BlockOrder:CueType 1, 56  38510.73    5.87 *    .09
# 11           Feedback:BlockOrder:CueType 1, 56  38510.73      0.09   .002
# 12                     TrialType:CueType 1, 56   7302.78      1.18    .02
# 13            Feedback:TrialType:CueType 1, 56   7302.78    5.20 *    .08
# 14          BlockOrder:TrialType:CueType 1, 56   7302.78    3.13 +    .05
# 15 Feedback:BlockOrder:TrialType:CueType 1, 56   7302.78      0.00 <.0001
#    p.value
# 1      .71
# 2      .45
# 3      .87
# 4    .0006
# 5      .12
# 6      .71
# 7      .08
# 8      .10
# 9      .71
# 10     .02
# 11     .77
# 12     .28
# 13     .03
# 14     .08
# 15     .96
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '+' 0.1 ' ' 1

# %% [markdown]
# The exploratory ANOVAs on the CSE at the end of the Jupyter notebook..

# %%
CSE_RT <- read.csv('CSE_ANOVA_RT.csv')
aov_car(RT ~ Feedback + Error(subject/(PrevCong*Congruency)), data = CSE_RT, anova_table = list(es = "pes"))
# Out:
# Contrasts set to contr.sum for the following variables: Feedback
# Anova Table (Type 3 tests)
#
# Response: RT
#                         Effect    df      MSE         F    pes p.value
# 1                     Feedback 1, 58 14444.02      0.01  .0002     .92
# 2                     PrevCong 1, 58   188.12      0.11   .002     .74
# 3            Feedback:PrevCong 1, 58   188.12      0.68    .01     .41
# 4                   Congruency 1, 58   397.28 25.24 ***    .30  <.0001
# 5          Feedback:Congruency 1, 58   397.28      0.30   .005     .58
# 6          PrevCong:Congruency 1, 58   252.22      0.42   .007     .52
# 7 Feedback:PrevCong:Congruency 1, 58   252.22      0.00 <.0001    >.99
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '+' 0.1 ' ' 1

# %%
CSE_ACC <- read.csv('CSE_ANOVA_ACC.csv')
aov_car(Accuracy ~ Feedback + Error(subject/(PrevCong*Congruency)), data = CSE_ACC, anova_table = list(es = "pes"))
# Out:
# Contrasts set to contr.sum for the following variables: Feedback
# Anova Table (Type 3 tests)
#
# Response: Accuracy
#                         Effect    df  MSE         F  pes p.value
# 1                     Feedback 1, 58 0.02      0.49 .008     .49
# 2                     PrevCong 1, 58 0.00    3.22 +  .05     .08
# 3            Feedback:PrevCong 1, 58 0.00      0.25 .004     .62
# 4                   Congruency 1, 58 0.01   7.13 **  .11    .010
# 5          Feedback:Congruency 1, 58 0.01      1.88  .03     .18
# 6          PrevCong:Congruency 1, 58 0.00 20.11 ***  .26  <.0001
# 7 Feedback:PrevCong:Congruency 1, 58 0.00      0.12 .002     .73
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '+' 0.1 ' ' 1

# %% [markdown]
# ### Bayesian ANOVAs

# %%
library(methods)
library(BayesFactor)
library(BFEffects)
# Out:
# Loading required package: coda
# Warning message:
# "package 'coda' was built under R version 3.5.2"************
# Welcome to BayesFactor 0.9.12-4.2. If you have questions, please contact Richard Morey (richarddmorey@gmail.com).
#
# Type BFManual() to open the manual.
# ************
# Warning message:
# "replacing previous import 'magrittr::set_names' by 'purrr::set_names' when loading 'BFEffects'"

# %%
rawRTData <- read.csv('SC_ANOVA_RT.csv')
rawRTData$RT <- as.numeric(as.character(rawRTData$RT))

rawRTData <- within(rawRTData, {
  subject <- factor(subject)
  Congruency <- factor(Congruency)
  BlockType <- factor(BlockType)
   Feedback <- factor(Feedback)
    BlockOrder <- factor(BlockOrder)
})

SC_RT_runANOVA <- anovaBF(RT ~ BlockType*Congruency*Feedback*BlockOrder + subject,
                                  data=rawRTData,
                                  whichRandom="subject")

png(file="Bayes_SC_RT.png", width = 3000, height = 700, res = 60)
plot(SC_RT_runANOVA)
dev.off()
print(SC_RT_runANOVA)
print(inclusionBF(SC_RT_runANOVA))
# Out:
# png
#   2
# Bayes factor analysis
# --------------
# [1] BlockType + subject                                                                                                                                                                                                                                                                                                                                                                         : 0.4315345  ±0.81%
# [2] Congruency + subject                                                                                                                                                                                                                                                                                                                                                                        : 45283.58   ±1.52%
# [3] BlockType + Congruency + subject                                                                                                                                                                                                                                                                                                                                                            : 23840.55   ±4.56%
# [4] BlockType + Congruency + BlockType:Congruency + subject                                                                                                                                                                                                                                                                                                                                     : 40817.89   ±8.14%
# [5] Feedback + subject                                                                                                                                                                                                                                                                                                                                                                          : 0.4737149  ±2.93%
# [6] BlockType + Feedback + subject                                                                                                                                                                                                                                                                                                                                                              : 0.2031373  ±3.71%
# [7] Congruency + Feedback + subject                                                                                                                                                                                                                                                                                                                                                             : 21731.38   ±3.38%
# [8] BlockType + Congruency + Feedback + subject                                                                                                                                                                                                                                                                                                                                                 : 11325.65   ±4.18%
# [9] BlockType + Congruency + BlockType:Congruency + Feedback + subject                                                                                                                                                                                                                                                                                                                          : 17889.67   ±4.64%
# [10] BlockType + Feedback + BlockType:Feedback + subject                                                                                                                                                                                                                                                                                                                                        : 0.03847342 ±4.42%
# [11] BlockType + Congruency + Feedback + BlockType:Feedback + subject                                                                                                                                                                                                                                                                                                                           : 2440.882   ±4.96%
# [12] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + subject                                                                                                                                                                                                                                                                                                    : 4022.645   ±5.9%
# [13] Congruency + Feedback + Congruency:Feedback + subject                                                                                                                                                                                                                                                                                                                                      : 6349.84    ±4.11%
# [14] BlockType + Congruency + Feedback + Congruency:Feedback + subject                                                                                                                                                                                                                                                                                                                          : 3256.767   ±4.98%
# [15] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + subject                                                                                                                                                                                                                                                                                                   : 4887.938   ±5.73%
# [16] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + subject                                                                                                                                                                                                                                                                                                     : 673.2765   ±6%
# [17] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + subject                                                                                                                                                                                                                                                                              : 845.0635   ±5.94%
# [18] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + subject                                                                                                                                                                                                                                              : 274.6948   ±9.33%
# [19] BlockOrder + subject                                                                                                                                                                                                                                                                                                                                                                       : 0.4452694  ±3.07%
# [20] BlockType + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                                           : 0.2068383  ±3.64%
# [21] Congruency + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                                          : 22634.14   ±3.32%
# [22] BlockType + Congruency + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                              : 11881.05   ±4%
# [23] BlockType + Congruency + BlockType:Congruency + BlockOrder + subject                                                                                                                                                                                                                                                                                                                       : 18096.74   ±4.76%
# [24] Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                                            : 0.2287255  ±3.36%
# [25] BlockType + Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                                : 0.09910272 ±4.04%
# [26] Congruency + Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                               : 10780.68   ±3.86%
# [27] BlockType + Congruency + Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                   : 5602.226   ±4.6%
# [28] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                            : 8915.806   ±5.32%
# [29] BlockType + Feedback + BlockType:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                                           : 0.02068256 ±4.78%
# [30] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                              : 1212.012   ±5.65%
# [31] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                       : 1565.003   ±6.59%
# [32] Congruency + Feedback + Congruency:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                                         : 3025.366   ±4.62%
# [33] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                             : 1619.769   ±5.92%
# [34] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                      : 2455.151   ±6.54%
# [35] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                        : 297.5787   ±7%
# [36] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                 : 469.9541   ±6.79%
# [37] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     subject                                                                                                                                                                                                                             : 134.6806   ±9.31%
# [38] BlockType + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                                                                    : 0.506786   ±4.19%
# [39] BlockType + Congruency + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                                                       : 38450.04   ±4.81%
# [40] BlockType + Congruency + BlockType:Congruency + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                                : 77918.44   ±5.25%
# [41] BlockType + Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                                                         : 0.2308272  ±4.75%
# [42] BlockType + Congruency + Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                                            : 19433.06   ±5.16%
# [43] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                     : 33800.02   ±5.79%
# [44] BlockType + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                                    : 0.04352395 ±5.7%
# [45] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                       : 3733.109   ±5.94%
# [46] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                : 7179.626   ±7.57%
# [47] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                      : 5389.895   ±6.61%
# [48] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                               : 8333.211   ±7.05%
# [49] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                 : 1069.136   ±8.59%
# [50] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     subject                                                                                                                                                                                                                                      : 1790.474   ±8.08%
# [51] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + subject                                                                                                                                                                                                      : 442.6398   ±10.5%
# [52] Congruency + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                                                                  : 4792.232   ±4.27%
# [53] BlockType + Congruency + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                                                      : 2498.511   ±5.04%
# [54] BlockType + Congruency + BlockType:Congruency + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                               : 4300.994   ±6.2%
# [55] Congruency + Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                                                       : 2444.967   ±4.98%
# [56] BlockType + Congruency + Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                                           : 1195.336   ±5.77%
# [57] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                    : 2087.166   ±6.15%
# [58] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                      : 232.5276   ±6.54%
# [59] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                               : 350.3614   ±7.23%
# [60] Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                                 : 580.9027   ±5.66%
# [61] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                     : 359.3304   ±7.03%
# [62] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                              : 523.778    ±7.55%
# [63] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                : 67.58805   ±7.61%
# [64] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder +     subject                                                                                                                                                                                                                                     : 93.35396   ±9.58%
# [65] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     Congruency:BlockOrder + subject                                                                                                                                                                                                     : 29.1464    ±10.12%
# [66] BlockType + Congruency + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                               : 8239.283   ±5.4%
# [67] BlockType + Congruency + BlockType:Congruency + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                        : 14441.04   ±6.6%
# [68] BlockType + Congruency + Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                    : 4430.166   ±6.43%
# [69] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                             : 6989.45    ±6.36%
# [70] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                               : 750.9326   ±7.51%
# [71] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     subject                                                                                                                                                                                                                                    : 1473.997   ±8.66%
# [72] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                              : 1179.073   ±6.99%
# [73] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     subject                                                                                                                                                                                                                                   : 1879.712   ±8.09%
# [74] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     subject                                                                                                                                                                                                                                     : 225.8599   ±9.12%
# [75] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + subject                                                                                                                                                                                                              : 418.0444   ±11.6%
# [76] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                              : 107.2238   ±12.47%
# [77] BlockType + Congruency + BlockType:Congruency + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     subject                                                                                                                                                                                                                                  : 11993.64   ±7.1%
# [78] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     subject                                                                                                                                                                                                                       : 5804.813   ±8.95%
# [79] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     BlockType:Congruency:BlockOrder + subject                                                                                                                                                                                                  : 1097.767   ±10.9%
# [80] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     BlockType:Congruency:BlockOrder + subject                                                                                                                                                                                                 : 1579.261   ±9.09%
# [81] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     subject                                                                                                                                                                        : 263.6659   ±10.03%
# [82] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     subject                                                                                                                                        : 75.17441   ±11%
# [83] Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                                                      : 0.1252861  ±3.86%
# [84] BlockType + Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                                          : 0.06155897 ±4.61%
# [85] Congruency + Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                                         : 6243.816   ±4.23%
# [86] BlockType + Congruency + Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                             : 3273.479   ±5.22%
# [87] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                      : 5747.737   ±5.83%
# [88] BlockType + Feedback + BlockType:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                     : 0.01079568 ±5.95%
# [89] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                        : 682.1198   ±6.24%
# [90] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                 : 1094.964   ±7.41%
# [91] Congruency + Feedback + Congruency:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                   : 1934.584   ±5.4%
# [92] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                       : 927.4154   ±6.12%
# [93] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                : 1458.663   ±6.95%
# [94] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                  : 175.327    ±7.92%
# [95] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                       : 303.0993   ±7.98%
# [96] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     Feedback:BlockOrder + subject                                                                                                                                                                                                       : 73.18201   ±10.23%
# [97] BlockType + Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                   : 0.1470522  ±5.1%
# [98] BlockType + Congruency + Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                      : 11445.27   ±5.44%
# [99] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                               : 20033.32   ±6.79%
# [100] BlockType + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                             : 0.0276559  ±6%
# [101] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                : 2579.109   ±6.83%
# [102] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                     : 4104.195   ±8.51%
# [103] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                               : 3611.481   ±6.83%
# [104] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                    : 5885.251   ±7.61%
# [105] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                      : 580.7822   ±8.76%
# [106] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Feedback:BlockOrder + subject                                                                                                                                                                                                               : 1385.426   ±11.71%
# [107] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                               : 272.6964   ±10.1%
# [108] Congruency + Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                : 1483.274   ±5.16%
# [109] BlockType + Congruency + Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                    : 784.5348   ±6.39%
# [110] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                             : 1271.185   ±6.9%
# [111] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                               : 158.3511   ±8.52%
# [112] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                    : 267.532    ±14.49%
# [113] Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                          : 388.2258   ±6.23%
# [114] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                              : 192.7294   ±6.83%
# [115] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                   : 313.9973   ±8.55%
# [116] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                     : 51.34546   ±9.24%
# [117] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + subject                                                                                                                                                                                                              : 64.52316   ±10.61%
# [118] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     Congruency:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                              : 15.96276   ±10.29%
# ...
# [131] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + subject                                                                                                                                                 : 186.908    ±12.07%
# [132] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + subject                                                                                                                 : 51.69847   ±13.14%
# [133] BlockType + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + BlockType:Feedback:BlockOrder + subject                                                                                                                                                                                                                                             : 0.01707683 ±6.7%
# [134] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + BlockType:Feedback:BlockOrder +     subject                                                                                                                                                                                                                            : 1919.26    ±10.4%
# [135] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder +     BlockType:Feedback:BlockOrder + subject                                                                                                                                                                                                     : 3111.701   ±9.53%
# [136] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder +     BlockType:Feedback:BlockOrder + subject                                                                                                                                                                                                      : 445.89     ±9.32%
# [137] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + subject                                                                                                                                                                               : 898.9987   ±12.33%
# [138] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Feedback:BlockOrder + BlockType:Feedback:BlockOrder +     subject                                                                                                                                           : 186.2689   ±9.59%
# [139] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     BlockType:Feedback:BlockOrder + subject                                                                                                                                                                                                    : 422.9776   ±9.34%
# [140] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + subject                                                                                                                                                                             : 826.2146   ±11.08%
# [141] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + subject                                                                                                                                                                              : 99.83861   ±8.86%
# [142] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + Feedback:BlockOrder + BlockType:Feedback:BlockOrder +     subject                                                                                                                                                   : 232.4689   ±18.33%
# [143] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     BlockType:Feedback:BlockOrder + subject                                                                                                                   : 42.59051   ±12.1%
# [144] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     BlockType:Congruency:BlockOrder + Feedback:BlockOrder + BlockType:Feedback:BlockOrder +     subject                                                                                                                                       : 429.2493   ±9.77%
# [145] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + subject                                                                                                                 : 165.2922   ±11.85%
# [146] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + subject                                                                                 : 45.42528   ±23.15%
# [147] Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + Congruency:Feedback:BlockOrder + subject                                                                                                                                                                                                                                         : 133.3301   ±9.47%
# [148] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                                                                                                                                                                         : 78.13685   ±8.27%
# [149] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     Congruency:Feedback:BlockOrder + subject                                                                                                                                                                                                  : 107.2526   ±10.82%
# [150] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     Congruency:Feedback:BlockOrder + subject                                                                                                                                                                                                    : 16.69001   ±11.54%
# [151] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + Congruency:Feedback:BlockOrder + subject                                                                                                                                                                             : 22.49101   ±10.23%
# [152] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     Congruency:BlockOrder + Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                                                                                         : 8.750478   ±20.02%
# [153] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     Congruency:Feedback:BlockOrder + subject                                                                                                                                                                                                  : 208.368    ±8.72%
# [154] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + Congruency:Feedback:BlockOrder + subject                                                                                                                                                                           : 536.8923   ±10.47%
# [155] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + Congruency:Feedback:BlockOrder + subject                                                                                                                                                                             : 57.38472   ±20.75%
# [156] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                                                                                                  : 74.85734   ±10.91%
# [157] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     Congruency:Feedback:BlockOrder + subject                                                                                                                  : 17.16648   ±11.29%
# [158] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     BlockType:Congruency:BlockOrder + Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                                                                                     : 394.0987   ±15.42%
# [159] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + Congruency:Feedback:BlockOrder + subject                                                                                                                : 61.51634   ±10.87%
# [160] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + Congruency:Feedback:BlockOrder + subject                                                                                : 26.95236   ±29.87%
# [161] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                                                                                         : 45.03588   ±12.81%
# [162] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + Feedback:BlockOrder + BlockType:Feedback:BlockOrder +     Congruency:Feedback:BlockOrder + subject                                                                                                                  : 78.15002   ±14.26%
# [163] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     BlockType:Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                              : 14.83595   ±12.98%
# [164] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                            : 45.99181   ±15.29%
# [165] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                            : 9.957002   ±11.78%
# [166] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     BlockType:Congruency:Feedback:BlockOrder + subject : 6.147227   ±24.28%
#
# Against denominator:
#   RT ~ subject
# ---
# Bayes factor type: BFlinearModel, JZS
#                                          Pr(prior) Pr(posterior) Inclusion BF
# BlockType                                    0.886         0.804        0.528
# Congruency                                   0.886         1.000    19426.604
# BlockType:Congruency                         0.503         0.527        1.103
# Feedback                                     0.886         0.502        0.130
# BlockType:Feedback                           0.503         0.084        0.091
# Congruency:Feedback                          0.503         0.113        0.126
# BlockType:Congruency:Feedback                0.120         0.003        0.021
# BlockOrder                                   0.886         0.719        0.328
# BlockType:BlockOrder                         0.503         0.512        1.035
# Congruency:BlockOrder                        0.503         0.161        0.190
# BlockType:Congruency:BlockOrder              0.120         0.042        0.319
# Feedback:BlockOrder                          0.503         0.158        0.185
# BlockType:Feedback:BlockOrder                0.120         0.014        0.103
# Congruency:Feedback:BlockOrder               0.120         0.003        0.022
# BlockType:Congruency:Feedback:BlockOrder     0.006         0.000        0.002
#
# Inclusion BFs compared among all models.

# %%
rawACCData <- read.csv('SC_ANOVA_ACC.csv')
rawACCData$Accuracy <- as.numeric(as.character(rawACCData$Accuracy))

rawACCData <- within(rawACCData, {
  subject <- factor(subject)
  Congruency <- factor(Congruency)
  BlockType <- factor(BlockType)
    Feedback <- factor(Feedback)
    BlockOrder <- factor(BlockOrder)
})

SC_ACC_runANOVA <- anovaBF(Accuracy ~ BlockType*Congruency*Feedback*BlockOrder + subject,
                                  data=rawACCData,
                                  whichRandom="subject")

png(file="Bayes_SC_ACC.png", width = 3000, height = 700, res = 60)
plot(SC_ACC_runANOVA)
dev.off()
print(SC_ACC_runANOVA)
print(inclusionBF(SC_ACC_runANOVA))
# Out:
# png
#   2
# Bayes factor analysis
# --------------
# [1] BlockType + subject                                                                                                                                                                                                                                                                                                                                                                         : 0.86623    ±1.31%
# [2] Congruency + subject                                                                                                                                                                                                                                                                                                                                                                        : 137.8023   ±1.52%
# [3] BlockType + Congruency + subject                                                                                                                                                                                                                                                                                                                                                            : 140.0136   ±3.37%
# [4] BlockType + Congruency + BlockType:Congruency + subject                                                                                                                                                                                                                                                                                                                                     : 3129.528   ±1.87%
# [5] Feedback + subject                                                                                                                                                                                                                                                                                                                                                                          : 0.3451719  ±2.71%
# [6] BlockType + Feedback + subject                                                                                                                                                                                                                                                                                                                                                              : 0.3093997  ±2.77%
# [7] Congruency + Feedback + subject                                                                                                                                                                                                                                                                                                                                                             : 47.90484   ±1.35%
# [8] BlockType + Congruency + Feedback + subject                                                                                                                                                                                                                                                                                                                                                 : 51.22222   ±5.61%
# [9] BlockType + Congruency + BlockType:Congruency + Feedback + subject                                                                                                                                                                                                                                                                                                                          : 1157.613   ±2.91%
# [10] BlockType + Feedback + BlockType:Feedback + subject                                                                                                                                                                                                                                                                                                                                        : 0.05507101 ±1.65%
# [11] BlockType + Congruency + Feedback + BlockType:Feedback + subject                                                                                                                                                                                                                                                                                                                           : 9.682561   ±4.5%
# [12] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + subject                                                                                                                                                                                                                                                                                                    : 250.8922   ±6.23%
# [13] Congruency + Feedback + Congruency:Feedback + subject                                                                                                                                                                                                                                                                                                                                      : 23.43087   ±7.95%
# [14] BlockType + Congruency + Feedback + Congruency:Feedback + subject                                                                                                                                                                                                                                                                                                                          : 22.12649   ±3.43%
# [15] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + subject                                                                                                                                                                                                                                                                                                   : 545.5803   ±2.93%
# [16] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + subject                                                                                                                                                                                                                                                                                                     : 4.097334   ±2.98%
# [17] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + subject                                                                                                                                                                                                                                                                              : 110.1336   ±5.01%
# [18] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + subject                                                                                                                                                                                                                                              : 34.01687   ±5.44%
# [19] BlockOrder + subject                                                                                                                                                                                                                                                                                                                                                                       : 0.4987885  ±1.27%
# [20] BlockType + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                                           : 0.4274811  ±2.95%
# [21] Congruency + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                                          : 69.45986   ±1.68%
# [22] BlockType + Congruency + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                              : 71.09222   ±2.95%
# [23] BlockType + Congruency + BlockType:Congruency + BlockOrder + subject                                                                                                                                                                                                                                                                                                                       : 1679.56    ±2.31%
# [24] Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                                            : 0.162931   ±1.05%
# [25] BlockType + Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                                : 0.1516363  ±2.01%
# [26] Congruency + Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                               : 24.73357   ±2.25%
# [27] BlockType + Congruency + Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                   : 25.78928   ±5.07%
# [28] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                            : 608.7246   ±4.02%
# [29] BlockType + Feedback + BlockType:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                                           : 0.0299581  ±4.22%
# [30] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                              : 4.751207   ±4.26%
# [31] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                       : 124.9943   ±6.11%
# [32] Congruency + Feedback + Congruency:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                                         : 11.71592   ±6.46%
# [33] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                             : 11.20189   ±3.79%
# [34] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                      : 333.8609   ±5.06%
# [35] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                        : 2.237053   ±3.32%
# [36] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                 : 63.88978   ±5.68%
# [37] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     subject                                                                                                                                                                                                                             : 21.4258    ±7.81%
# [38] BlockType + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                                                                    : 3.39853    ±1.88%
# [39] BlockType + Congruency + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                                                       : 726.5852   ±2%
# [40] BlockType + Congruency + BlockType:Congruency + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                                : 25367.09   ±9.28%
# [41] BlockType + Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                                                         : 1.238309   ±3.27%
# [42] BlockType + Congruency + Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                                            : 288.4826   ±6.3%
# [43] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                     : 7995.483   ±3.65%
# [44] BlockType + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                                    : 0.2239147  ±2.6%
# [45] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                       : 52.60657   ±2.67%
# [46] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                : 1518.96    ±3.12%
# [47] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                      : 264.7562   ±51.01%
# [48] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                               : 3946.103   ±2.51%
# [49] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                 : 26.75718   ±7.95%
# [50] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     subject                                                                                                                                                                                                                                      : 805.039    ±4.34%
# [51] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + subject                                                                                                                                                                                                      : 250.3269   ±4.46%
# [52] Congruency + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                                                                  : 15.36408   ±1.75%
# [53] BlockType + Congruency + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                                                      : 16.61143   ±3.75%
# [54] BlockType + Congruency + BlockType:Congruency + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                               : 402.7113   ±4.52%
# [55] Congruency + Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                                                       : 5.336746   ±2.16%
# [56] BlockType + Congruency + Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                                           : 5.399866   ±2.58%
# [57] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                    : 129.4935   ±3.07%
# [58] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                      : 1.34024    ±13.18%
# [59] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                               : 30.81477   ±6.21%
# [60] Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                                 : 2.49818    ±5.92%
# [61] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                     : 2.715444   ±6.03%
# [62] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                              : 75.07153   ±6.11%
# [63] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                : 0.4940045  ±5%
# [64] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder +     subject                                                                                                                                                                                                                                     : 12.44698   ±4.71%
# [65] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     Congruency:BlockOrder + subject                                                                                                                                                                                                     : 4.595186   ±10.79%
# [66] BlockType + Congruency + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                               : 165.5889   ±3.15%
# [67] BlockType + Congruency + BlockType:Congruency + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                        : 5305.548   ±8.2%
# [68] BlockType + Congruency + Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                    : 66.40077   ±4.84%
# [69] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                             : 1895.474   ±6.77%
# [70] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                               : 12.98747   ±8.03%
# [71] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     subject                                                                                                                                                                                                                                    : 432.89     ±9.93%
# [72] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                              : 41.35756   ±20.81%
# [73] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     subject                                                                                                                                                                                                                                   : 1009.536   ±7.25%
# [74] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     subject                                                                                                                                                                                                                                     : 6.438072   ±7.5%
# [75] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + subject                                                                                                                                                                                                              : 197.9129   ±13.31%
# [76] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                              : 72.79371   ±13.82%
# [77] BlockType + Congruency + BlockType:Congruency + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     subject                                                                                                                                                                                                                                  : 9010.194   ±8.75%
# [78] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     subject                                                                                                                                                                                                                       : 2900.951   ±6.76%
# [79] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     BlockType:Congruency:BlockOrder + subject                                                                                                                                                                                                  : 674.6532   ±11.65%
# [80] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     BlockType:Congruency:BlockOrder + subject                                                                                                                                                                                                 : 1596.237   ±9.18%
# [81] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     subject                                                                                                                                                                        : 345.7713   ±17.61%
# [82] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     subject                                                                                                                                        : 84.2411    ±4.74%
# [83] Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                                                      : 0.08013371 ±4.36%
# [84] BlockType + Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                                          : 0.0770112  ±10.51%
# [85] Congruency + Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                                         : 11.73102   ±3.26%
# [86] BlockType + Congruency + Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                             : 12.11577   ±2.8%
# [87] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                      : 286.8879   ±2.59%
# [88] BlockType + Feedback + BlockType:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                     : 0.01337734 ±2.54%
# [89] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                        : 2.475696   ±5.7%
# [90] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                 : 62.88901   ±8.95%
# [91] Congruency + Feedback + Congruency:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                   : 5.109205   ±2.55%
# [92] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                       : 5.651286   ±3.2%
# [93] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                : 147.048    ±5.28%
# [94] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                  : 1.350405   ±16.38%
# [95] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                       : 29.94093   ±8.24%
# [96] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     Feedback:BlockOrder + subject                                                                                                                                                                                                       : 9.453591   ±7.93%
# [97] BlockType + Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                   : 0.567896   ±5.42%
# [98] BlockType + Congruency + Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                      : 141.089    ±7.58%
# [99] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                               : 4351.559   ±3.78%
# [100] BlockType + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                             : 0.1660436  ±33.27%
# [101] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                : 26.73459   ±4.38%
# [102] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                     : 877.3192   ±6.57%
# [103] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                               : 66.37871   ±5.04%
# [104] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                    : 1981.363   ±4.41%
# [105] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                      : 12.54293   ±7.57%
# [106] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Feedback:BlockOrder + subject                                                                                                                                                                                                               : 449.5959   ±9.78%
# [107] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                               : 121.0562   ±5.38%
# [108] Congruency + Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                : 2.610124   ±3.01%
# [109] BlockType + Congruency + Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                    : 3.535446   ±25.93%
# [110] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                             : 61.36858   ±2.67%
# [111] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                               : 0.5157887  ±4.36%
# [112] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                    : 15.0479    ±7.6%
# [113] Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                          : 1.136428   ±3.01%
# [114] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                              : 1.305587   ±4.25%
# [115] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                   : 33.17382   ±5.79%
# [116] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                     : 0.2633819  ±5.13%
# [117] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + subject                                                                                                                                                                                                              : 6.742196   ±10.67%
# [118] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     Congruency:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                              : 2.437162   ±7.1%
# ...
# [131] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + subject                                                                                                                                                 : 155.8088   ±9.55%
# [132] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + subject                                                                                                                 : 65.90115   ±27.48%
# [133] BlockType + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + BlockType:Feedback:BlockOrder + subject                                                                                                                                                                                                                                             : 0.05833099 ±3.67%
# [134] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + BlockType:Feedback:BlockOrder +     subject                                                                                                                                                                                                                            : 16.58351   ±5.89%
# [135] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder +     BlockType:Feedback:BlockOrder + subject                                                                                                                                                                                                     : 530.285    ±6.32%
# [136] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder +     BlockType:Feedback:BlockOrder + subject                                                                                                                                                                                                      : 8.213342   ±6.51%
# [137] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + subject                                                                                                                                                                               : 259.808    ±4.95%
# [138] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Feedback:BlockOrder + BlockType:Feedback:BlockOrder +     subject                                                                                                                                           : 103.9581   ±9.53%
# [139] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     BlockType:Feedback:BlockOrder + subject                                                                                                                                                                                                    : 3.435199   ±5.25%
# [140] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + subject                                                                                                                                                                             : 117.7313   ±6.83%
# [141] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + subject                                                                                                                                                                              : 1.836856   ±8.32%
# [142] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + Feedback:BlockOrder + BlockType:Feedback:BlockOrder +     subject                                                                                                                                                   : 66.5223    ±13.7%
# [143] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     BlockType:Feedback:BlockOrder + subject                                                                                                                   : 85.39746   ±77.34%
# [144] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     BlockType:Congruency:BlockOrder + Feedback:BlockOrder + BlockType:Feedback:BlockOrder +     subject                                                                                                                                       : 200.4014   ±9.74%
# [145] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + subject                                                                                                                 : 108.7213   ±14.24%
# [146] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + subject                                                                                 : 33.47373   ±13.59%
# [147] Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + Congruency:Feedback:BlockOrder + subject                                                                                                                                                                                                                                         : 0.3813023  ±6.65%
# [148] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                                                                                                                                                                         : 0.3536448  ±3.98%
# [149] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     Congruency:Feedback:BlockOrder + subject                                                                                                                                                                                                  : 8.851727   ±4.05%
# [150] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     Congruency:Feedback:BlockOrder + subject                                                                                                                                                                                                    : 0.07134127 ±4.2%
# [151] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + Congruency:Feedback:BlockOrder + subject                                                                                                                                                                             : 2.391696   ±23.9%
# [152] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     Congruency:BlockOrder + Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                                                                                         : 0.5788363  ±8.42%
# [153] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     Congruency:Feedback:BlockOrder + subject                                                                                                                                                                                                  : 4.057942   ±4.35%
# [154] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + Congruency:Feedback:BlockOrder + subject                                                                                                                                                                           : 146.5708   ±7.27%
# [155] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + Congruency:Feedback:BlockOrder + subject                                                                                                                                                                             : 1.043035   ±26.87%
# [156] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                                                                                                  : 30.78928   ±8.28%
# [157] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     Congruency:Feedback:BlockOrder + subject                                                                                                                  : 7.99864    ±5.92%
# [158] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     BlockType:Congruency:BlockOrder + Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                                                                                     : 218.3796   ±4.77%
# [159] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + Congruency:Feedback:BlockOrder + subject                                                                                                                : 40.00801   ±4.54%
# [160] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + Congruency:Feedback:BlockOrder + subject                                                                                : 15.54364   ±14.97%
# [161] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                                                                                         : 0.5332178  ±9.11%
# [162] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + Feedback:BlockOrder + BlockType:Feedback:BlockOrder +     Congruency:Feedback:BlockOrder + subject                                                                                                                  : 17.06183   ±5.31%
# [163] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     BlockType:Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                              : 5.844987   ±8.12%
# [164] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                            : 27.60181   ±9.29%
# [165] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                            : 10.15979   ±10.83%
# [166] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     BlockType:Congruency:Feedback:BlockOrder + subject : 2.758976   ±6.78%
#
# Against denominator:
#   Accuracy ~ subject
# ---
# Bayes factor type: BFlinearModel, JZS
#                                          Pr(prior) Pr(posterior) Inclusion BF
# BlockType                                    0.886         0.996       31.784
# Congruency                                   0.886         1.000     1192.203
# BlockType:Congruency                         0.503         0.969       31.251
# Feedback                                     0.886         0.485        0.121
# BlockType:Feedback                           0.503         0.104        0.115
# Congruency:Feedback                          0.503         0.174        0.209
# BlockType:Congruency:Feedback                0.120         0.011        0.079
# BlockOrder                                   0.886         0.937        1.906
# BlockType:BlockOrder                         0.503         0.887        7.762
# Congruency:BlockOrder                        0.503         0.338        0.504
# BlockType:Congruency:BlockOrder              0.120         0.201        1.852
# Feedback:BlockOrder                          0.503         0.171        0.203
# BlockType:Feedback:BlockOrder                0.120         0.018        0.133
# Congruency:Feedback:BlockOrder               0.120         0.006        0.045
# BlockType:Congruency:Feedback:BlockOrder     0.006         0.000        0.005
#
# Inclusion BFs compared among all models.

# %%
IEdata <- read.csv('IE_Main.csv')
IEdata$IE <- as.numeric(as.character(IEdata$IE))

IEdata <- within(IEdata, {
  SubjectID <- factor(SubjectID)
  TrialType <- factor(TrialType)
  CueType <- factor(CueType)
  Feedback <- factor(Feedback)
    BlockOrder <- factor(BlockOrder)
})

SC_IE_runANOVA <- anovaBF(IE ~ CueType*TrialType*Feedback*BlockOrder + SubjectID,
                          data=IEdata,
                          whichRandom="SubjectID")

png(file="Bayes_SC_IE.png", width = 3000, height = 700, res = 60)
plot(SC_IE_runANOVA)
dev.off()
print(SC_IE_runANOVA)
print(inclusionBF(SC_IE_runANOVA))
# Out:
# png
#   2
# Bayes factor analysis
# --------------
# [1] Feedback + SubjectID                                                                                                                                                                                                                                                                                                                                                  : 0.3298637   ±1.1%
# [2] BlockOrder + SubjectID                                                                                                                                                                                                                                                                                                                                                : 0.33678     ±1.03%
# [3] Feedback + BlockOrder + SubjectID                                                                                                                                                                                                                                                                                                                                     : 0.1094988   ±1.03%
# [4] Feedback + BlockOrder + Feedback:BlockOrder + SubjectID                                                                                                                                                                                                                                                                                                               : 0.04174166  ±2.02%
# [5] TrialType + SubjectID                                                                                                                                                                                                                                                                                                                                                 : 848.9267    ±0.84%
# [6] Feedback + TrialType + SubjectID                                                                                                                                                                                                                                                                                                                                      : 302.0111    ±2.39%
# [7] BlockOrder + TrialType + SubjectID                                                                                                                                                                                                                                                                                                                                    : 297.4832    ±2.04%
# [8] Feedback + BlockOrder + TrialType + SubjectID                                                                                                                                                                                                                                                                                                                         : 100.6208    ±1.82%
# [9] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + SubjectID                                                                                                                                                                                                                                                                                                   : 40.5949     ±2.5%
# [10] Feedback + TrialType + Feedback:TrialType + SubjectID                                                                                                                                                                                                                                                                                                                : 114.7523    ±1.67%
# [11] Feedback + BlockOrder + TrialType + Feedback:TrialType + SubjectID                                                                                                                                                                                                                                                                                                   : 40.77903    ±2.01%
# [12] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + SubjectID                                                                                                                                                                                                                                                                             : 16.40673    ±2.14%
# [13] BlockOrder + TrialType + BlockOrder:TrialType + SubjectID                                                                                                                                                                                                                                                                                                            : 64.03087    ±2.3%
# [14] Feedback + BlockOrder + TrialType + BlockOrder:TrialType + SubjectID                                                                                                                                                                                                                                                                                                 : 22.1379     ±5.22%
# [15] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + SubjectID                                                                                                                                                                                                                                                                           : 8.17708     ±2.15%
# [16] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + SubjectID                                                                                                                                                                                                                                                                            : 8.984485    ±4.32%
# [17] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + SubjectID                                                                                                                                                                                                                                                      : 3.581033    ±3.45%
# [18] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + SubjectID                                                                                                                                                                                                                      : 0.8428569   ±2.86%
# [19] CueType + SubjectID                                                                                                                                                                                                                                                                                                                                                  : 0.5028105   ±2.4%
# [20] Feedback + CueType + SubjectID                                                                                                                                                                                                                                                                                                                                       : 0.1682047   ±2.84%
# [21] BlockOrder + CueType + SubjectID                                                                                                                                                                                                                                                                                                                                     : 0.1744048   ±2.94%
# [22] Feedback + BlockOrder + CueType + SubjectID                                                                                                                                                                                                                                                                                                                          : 0.05456256  ±1.42%
# [23] Feedback + BlockOrder + Feedback:BlockOrder + CueType + SubjectID                                                                                                                                                                                                                                                                                                    : 0.02126382  ±2.09%
# [24] TrialType + CueType + SubjectID                                                                                                                                                                                                                                                                                                                                      : 497.4532    ±1.83%
# [25] Feedback + TrialType + CueType + SubjectID                                                                                                                                                                                                                                                                                                                           : 167.1807    ±2.48%
# [26] BlockOrder + TrialType + CueType + SubjectID                                                                                                                                                                                                                                                                                                                         : 166.69      ±1.64%
# [27] Feedback + BlockOrder + TrialType + CueType + SubjectID                                                                                                                                                                                                                                                                                                              : 63.47801    ±7.39%
# [28] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + CueType + SubjectID                                                                                                                                                                                                                                                                                        : 23.9686     ±7.34%
# [29] Feedback + TrialType + Feedback:TrialType + CueType + SubjectID                                                                                                                                                                                                                                                                                                      : 73.27967    ±3.77%
# [30] Feedback + BlockOrder + TrialType + Feedback:TrialType + CueType + SubjectID                                                                                                                                                                                                                                                                                         : 24.35771    ±2.7%
# [31] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + CueType + SubjectID                                                                                                                                                                                                                                                                   : 9.474243    ±2.67%
# [32] BlockOrder + TrialType + BlockOrder:TrialType + CueType + SubjectID                                                                                                                                                                                                                                                                                                  : 39.5573     ±6.85%
# [33] Feedback + BlockOrder + TrialType + BlockOrder:TrialType + CueType + SubjectID                                                                                                                                                                                                                                                                                       : 11.77984    ±2.49%
# [34] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + CueType + SubjectID                                                                                                                                                                                                                                                                 : 4.959556    ±3.9%
# [35] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + SubjectID                                                                                                                                                                                                                                                                  : 5.950193    ±13.91%
# [36] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + SubjectID                                                                                                                                                                                                                                            : 1.971666    ±4.26%
# [37] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     SubjectID                                                                                                                                                                                                        : 0.6380622   ±10.87%
# [38] Feedback + CueType + Feedback:CueType + SubjectID                                                                                                                                                                                                                                                                                                                    : 0.03312669  ±2.83%
# [39] Feedback + BlockOrder + CueType + Feedback:CueType + SubjectID                                                                                                                                                                                                                                                                                                       : 0.01186832  ±6.03%
# [40] Feedback + BlockOrder + Feedback:BlockOrder + CueType + Feedback:CueType + SubjectID                                                                                                                                                                                                                                                                                 : 0.004138381 ±2.95%
# [41] Feedback + TrialType + CueType + Feedback:CueType + SubjectID                                                                                                                                                                                                                                                                                                        : 33.36492    ±4.17%
# [42] Feedback + BlockOrder + TrialType + CueType + Feedback:CueType + SubjectID                                                                                                                                                                                                                                                                                           : 11.17584    ±2.99%
# [43] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + CueType + Feedback:CueType + SubjectID                                                                                                                                                                                                                                                                     : 4.451474    ±2.53%
# [44] Feedback + TrialType + Feedback:TrialType + CueType + Feedback:CueType + SubjectID                                                                                                                                                                                                                                                                                   : 14.37937    ±8.47%
# [45] Feedback + BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + SubjectID                                                                                                                                                                                                                                                                      : 4.875401    ±4.63%
# [46] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + SubjectID                                                                                                                                                                                                                                                : 1.836052    ±3.2%
# [47] Feedback + BlockOrder + TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + SubjectID                                                                                                                                                                                                                                                                    : 2.449186    ±3.08%
# [48] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + SubjectID                                                                                                                                                                                                                                              : 0.9434314   ±4.03%
# [49] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + SubjectID                                                                                                                                                                                                                                               : 1.015578    ±5.94%
# [50] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + SubjectID                                                                                                                                                                                                                         : 0.3867936   ±7.08%
# [51] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     Feedback:CueType + SubjectID                                                                                                                                                                                     : 0.1150415   ±8.04%
# [52] BlockOrder + CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                                                                                : 3.243982    ±1.95%
# [53] Feedback + BlockOrder + CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                                                                     : 1.06333     ±1.86%
# [54] Feedback + BlockOrder + Feedback:BlockOrder + CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                                               : 0.4405761   ±3.36%
# [55] BlockOrder + TrialType + CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                                                                    : 5816.302    ±3.33%
# [56] Feedback + BlockOrder + TrialType + CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                                                         : 1896.506    ±2.62%
# [57] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                                   : 729.3949    ±2.35%
# [58] Feedback + BlockOrder + TrialType + Feedback:TrialType + CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                                    : 796.3683    ±3.23%
# [59] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                              : 398.6908    ±11.15%
# [60] BlockOrder + TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                                             : 1191.656    ±3.46%
# [61] Feedback + BlockOrder + TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                                  : 450.246     ±4.99%
# [62] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                            : 157.5961    ±3.44%
# [63] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                             : 170.4282    ±3.92%
# [64] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                       : 70.91421    ±7.59%
# [65] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     BlockOrder:CueType + SubjectID                                                                                                                                                                                   : 19.05971    ±5.16%
# [66] Feedback + BlockOrder + CueType + Feedback:CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                                                  : 0.2056522   ±2.35%
# [67] Feedback + BlockOrder + Feedback:BlockOrder + CueType + Feedback:CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                            : 0.07993654  ±2.57%
# [68] Feedback + BlockOrder + TrialType + CueType + Feedback:CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                                      : 383.4857    ±4.83%
# [69] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + CueType + Feedback:CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                : 138.2552    ±2.72%
# [70] Feedback + BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                 : 187.3062    ±5.51%
# [71] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                           : 68.48793    ±8.64%
# [72] Feedback + BlockOrder + TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                               : 74.45699    ±3.26%
# [73] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                         : 30.40043    ±4.1%
# [74] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                          : 39.50369    ±7.34%
# [75] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType +     SubjectID                                                                                                                                                                                                : 25.27162    ±34.56%
# [76] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     Feedback:CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                : 4.116821    ±9.65%
# [77] Feedback + BlockOrder + Feedback:BlockOrder + CueType + Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType + SubjectID                                                                                                                                                                                                                              : 0.1066917   ±3.54%
# [78] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + CueType + Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType +     SubjectID                                                                                                                                                                                                              : 227.9659    ±4.03%
# [79] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType +     SubjectID                                                                                                                                                                                         : 97.20223    ±4.33%
# [80] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType +     SubjectID                                                                                                                                                                                       : 51.36568    ±7.06%
# [81] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType +     Feedback:BlockOrder:CueType + SubjectID                                                                                                                                                                  : 21.22888    ±7.14%
# [82] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType +     SubjectID                                                                                                                              : 5.311247    ±5.31%
# [83] TrialType + CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                                                                                  : 2659.128    ±3.02%
# [84] Feedback + TrialType + CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                                                                       : 955.2859    ±3.55%
# [85] BlockOrder + TrialType + CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                                                                     : 940.018     ±3.52%
# [86] Feedback + BlockOrder + TrialType + CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                                                          : 315.8595    ±6.66%
# [87] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                                    : 130.2167    ±6.21%
# [88] Feedback + TrialType + Feedback:TrialType + CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                                                  : 362.1057    ±2.1%
# [89] Feedback + BlockOrder + TrialType + Feedback:TrialType + CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                                     : 127.1643    ±2.89%
# [90] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                               : 60.24052    ±7.49%
# [91] BlockOrder + TrialType + BlockOrder:TrialType + CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                                              : 197.7079    ±4.91%
# [92] Feedback + BlockOrder + TrialType + BlockOrder:TrialType + CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                                   : 61.11662    ±2.05%
# [93] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                             : 26.58653    ±3.18%
# [94] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                              : 28.80704    ±6.92%
# [95] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                        : 11.41537    ±3.61%
# [96] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     TrialType:CueType + SubjectID                                                                                                                                                                                    : 2.839776    ±4.1%
# [97] Feedback + TrialType + CueType + Feedback:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                                                    : 171.6783    ±3.99%
# [98] Feedback + BlockOrder + TrialType + CueType + Feedback:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                                       : 65.45349    ±5.79%
# [99] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + CueType + Feedback:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                 : 24.95099    ±3.71%
# [100] Feedback + TrialType + Feedback:TrialType + CueType + Feedback:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                              : 71.68714    ±2.61%
# [101] Feedback + BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                 : 27.6188     ±6.34%
# [102] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                           : 10.10232    ±4.07%
# [103] Feedback + BlockOrder + TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                               : 13.94223    ±7.57%
# [104] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                         : 6.147857    ±8.94%
# [105] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                          : 5.105028    ±3.45%
# [106] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + TrialType:CueType +     SubjectID                                                                                                                                                                                                : 2.149909    ±3.99%
# [107] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     Feedback:CueType + TrialType:CueType + SubjectID                                                                                                                                                                : 0.5985594   ±5.76%
# [108] BlockOrder + TrialType + CueType + BlockOrder:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                                               : 37074.78    ±4.26%
# [109] Feedback + BlockOrder + TrialType + CueType + BlockOrder:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                                    : 13099.25    ±3.95%
# [110] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + CueType + BlockOrder:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                              : 5648.97     ±9.62%
# [111] Feedback + BlockOrder + TrialType + Feedback:TrialType + CueType + BlockOrder:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                               : 6140.956    ±5.84%
# [112] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + CueType + BlockOrder:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                         : 2146.208    ±3.12%
# [113] BlockOrder + TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                        : 6945.963    ±2.47%
# [114] Feedback + BlockOrder + TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                             : 2906.927    ±6.25%
# [115] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                       : 1054.739    ±7.17%
# [116] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                        : 1291.468    ±8.29%
# [117] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + TrialType:CueType +     SubjectID                                                                                                                                                                                              : 480.2351    ±5.09%
# [118] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     BlockOrder:CueType + TrialType:CueType + SubjectID                                                                                                                                                              : 146.3104    ±10.65%
# [119] Feedback + BlockOrder + TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                 : 2602.442    ±6.79%
# [120] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     SubjectID                                                                                                                                                                                                                       : 993.206     ±6.09%
# [121] Feedback + BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     SubjectID                                                                                                                                                                                                                        : 1120.253    ±5.25%
# [122] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     SubjectID                                                                                                                                                                                                  : 532.9993    ±15.56%
# [123] Feedback + BlockOrder + TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     SubjectID                                                                                                                                                                                                                      : 529.8281    ±6.28%
# [124] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     SubjectID                                                                                                                                                                                                : 202.5078    ±4.13%
# [125] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     SubjectID                                                                                                                                                                                                 : 245.3864    ±7.03%
# ...
# [129] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType +     TrialType:CueType + SubjectID                                                                                                                                                                    : 736.15      ±9.15%
# [130] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType +     TrialType:CueType + SubjectID                                                                                                                                                                  : 358.2478    ±5.57%
# [131] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType +     Feedback:BlockOrder:CueType + TrialType:CueType + SubjectID                                                                                                                                             : 191.8074    ±12.49%
# [132] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType +     TrialType:CueType + SubjectID                                                                                                         : 57.42026    ±24.75%
# [133] Feedback + TrialType + Feedback:TrialType + CueType + Feedback:CueType + TrialType:CueType + Feedback:TrialType:CueType + SubjectID                                                                                                                                                                                                                                 : 18.5877     ±4.46%
# [134] Feedback + BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + TrialType:CueType + Feedback:TrialType:CueType +     SubjectID                                                                                                                                                                                                                : 8.115916    ±19.43%
# [135] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + TrialType:CueType + Feedback:TrialType:CueType +     SubjectID                                                                                                                                                                                          : 2.522367    ±3.87%
# [136] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + TrialType:CueType + Feedback:TrialType:CueType +     SubjectID                                                                                                                                                                                         : 1.557917    ±15.68%
# [137] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + TrialType:CueType +     Feedback:TrialType:CueType + SubjectID                                                                                                                                                                   : 0.5905222   ±6.46%
# [138] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     Feedback:CueType + TrialType:CueType + Feedback:TrialType:CueType +     SubjectID                                                                                                                               : 0.144474    ±4.81%
# [139] Feedback + BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     Feedback:TrialType:CueType + SubjectID                                                                                                                                                                                           : 299.6003    ±5.89%
# [140] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     Feedback:TrialType:CueType + SubjectID                                                                                                                                                                     : 116.427     ±5.12%
# [141] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     Feedback:TrialType:CueType + SubjectID                                                                                                                                                                    : 58.30632    ±4.57%
# [142] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType +     TrialType:CueType + Feedback:TrialType:CueType + SubjectID                                                                                                                                              : 27.04488    ±7.69%
# [143] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     Feedback:TrialType:CueType + SubjectID                                                                                                          : 6.079755    ±6.38%
# [144] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType +     TrialType:CueType + Feedback:TrialType:CueType + SubjectID                                                                                                                                       : 216.8025    ±8.34%
# [145] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType +     Feedback:BlockOrder:CueType + TrialType:CueType + Feedback:TrialType:CueType +     SubjectID                                                                                                            : 62.43294    ±36.54%
# [146] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType +     TrialType:CueType + Feedback:TrialType:CueType + SubjectID                                                                            : 11.60032    ±9.06%
# [147] BlockOrder + TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + TrialType:CueType + BlockOrder:TrialType:CueType + SubjectID                                                                                                                                                                                                                         : 19241.93    ±3.54%
# [148] Feedback + BlockOrder + TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + TrialType:CueType + BlockOrder:TrialType:CueType +     SubjectID                                                                                                                                                                                                          : 8226.666    ±6.06%
# [149] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + TrialType:CueType + BlockOrder:TrialType:CueType +     SubjectID                                                                                                                                                                                    : 3081.222    ±5.29%
# [150] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + TrialType:CueType + BlockOrder:TrialType:CueType +     SubjectID                                                                                                                                                                                     : 3166.637    ±4.72%
# [151] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + TrialType:CueType +     BlockOrder:TrialType:CueType + SubjectID                                                                                                                                                               : 1355.05     ±4.77%
# [152] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     BlockOrder:CueType + TrialType:CueType + BlockOrder:TrialType:CueType +     SubjectID                                                                                                                           : 348.4646    ±6.11%
# [153] Feedback + BlockOrder + TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     BlockOrder:TrialType:CueType + SubjectID                                                                                                                                                                                       : 1437.476    ±5.52%
# [154] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     BlockOrder:TrialType:CueType + SubjectID                                                                                                                                                                 : 624.3576    ±7.92%
# [155] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     BlockOrder:TrialType:CueType + SubjectID                                                                                                                                                                  : 696.8821    ±8.95%
# [156] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType +     TrialType:CueType + BlockOrder:TrialType:CueType + SubjectID                                                                                                                                            : 283.9375    ±13.24%
# [157] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     BlockOrder:TrialType:CueType + SubjectID                                                                                                        : 72.26339    ±8.07%
# [158] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType +     TrialType:CueType + BlockOrder:TrialType:CueType + SubjectID                                                                                                                                   : 1101.063    ±7.95%
# [159] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType +     Feedback:BlockOrder:CueType + TrialType:CueType + BlockOrder:TrialType:CueType +     SubjectID                                                                                                          : 534.4995    ±9.82%
# [160] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType +     TrialType:CueType + BlockOrder:TrialType:CueType + SubjectID                                                                          : 125.0596    ±7.25%
# [161] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     Feedback:TrialType:CueType + BlockOrder:TrialType:CueType +     SubjectID                                                                                                                                 : 219.5346    ±20.52%
# [162] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType +     TrialType:CueType + Feedback:TrialType:CueType + BlockOrder:TrialType:CueType +     SubjectID                                                                                                           : 67.21435    ±6.59%
# [163] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     Feedback:TrialType:CueType + BlockOrder:TrialType:CueType +     SubjectID                                                                       : 15.42276    ±5.19%
# [164] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType +     Feedback:BlockOrder:CueType + TrialType:CueType + Feedback:TrialType:CueType +     BlockOrder:TrialType:CueType + SubjectID                                                                             : 169.3014    ±12.01%
# [165] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType +     TrialType:CueType + Feedback:TrialType:CueType + BlockOrder:TrialType:CueType +     SubjectID                                         : 27.26979    ±5.04%
# [166] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType +     TrialType:CueType + Feedback:TrialType:CueType + BlockOrder:TrialType:CueType +     Feedback:BlockOrder:TrialType:CueType + SubjectID : 15.46824    ±9.79%
#
# Against denominator:
#   IE ~ SubjectID
# ---
# Bayes factor type: BFlinearModel, JZS
#                                       Pr(prior) Pr(posterior) Inclusion BF
# Feedback                                  0.886         0.496        0.126
# BlockOrder                                0.886         0.958        2.945
# Feedback:BlockOrder                       0.503         0.168        0.200
# TrialType                                 0.886         1.000     2438.909
# Feedback:TrialType                        0.503         0.160        0.188
# BlockOrder:TrialType                      0.503         0.387        0.625
# Feedback:BlockOrder:TrialType             0.120         0.006        0.043
# CueType                                   0.886         0.988       10.206
# Feedback:CueType                          0.503         0.118        0.132
# BlockOrder:CueType                        0.503         0.938       14.935
# Feedback:BlockOrder:CueType               0.120         0.040        0.304
# TrialType:CueType                         0.503         0.893        8.260
# Feedback:TrialType:CueType                0.120         0.009        0.066
# BlockOrder:TrialType:CueType              0.120         0.271        2.731
# Feedback:BlockOrder:TrialType:CueType     0.006         0.000        0.017
#
# Inclusion BFs compared among all models.

# %% [markdown]
# What about transfer?

# %%
rawRTData_T <- read.csv('SCT_ANOVA_RT.csv')
rawRTData_T$RT <- as.numeric(as.character(rawRTData_T$RT))

rawRTData_T <- within(rawRTData_T, {
  subject <- factor(subject)
  Congruency <- factor(Congruency)
  BlockType <- factor(BlockType)
   Feedback <- factor(Feedback)
    BlockOrder <- factor(BlockOrder)
})

SCT_RT_runANOVA <- anovaBF(RT ~ BlockType*Congruency*Feedback*BlockOrder + subject,
                                  data=rawRTData_T,
                                  whichRandom="subject")

png(file="Bayes_SCT_RT.png", width = 3000, height = 700, res = 60)
plot(SCT_RT_runANOVA)
dev.off()
print(SCT_RT_runANOVA)
print(inclusionBF(SCT_RT_runANOVA))
# Out:
# png
#   2
# Bayes factor analysis
# --------------
# [1] BlockType + subject                                                                                                                                                                                                                                                                                                                                                                         : 0.1942652  ±1.37%
# [2] Congruency + subject                                                                                                                                                                                                                                                                                                                                                                        : 3849167    ±1.16%
# [3] BlockType + Congruency + subject                                                                                                                                                                                                                                                                                                                                                            : 796584.5   ±1.32%
# [4] BlockType + Congruency + BlockType:Congruency + subject                                                                                                                                                                                                                                                                                                                                     : 218467.7   ±3.41%
# [5] Feedback + subject                                                                                                                                                                                                                                                                                                                                                                          : 0.5353727  ±3.39%
# [6] BlockType + Feedback + subject                                                                                                                                                                                                                                                                                                                                                              : 0.1192588  ±3.96%
# [7] Congruency + Feedback + subject                                                                                                                                                                                                                                                                                                                                                             : 2037630    ±3.95%
# [8] BlockType + Congruency + Feedback + subject                                                                                                                                                                                                                                                                                                                                                 : 506770.6   ±4.84%
# [9] BlockType + Congruency + BlockType:Congruency + Feedback + subject                                                                                                                                                                                                                                                                                                                          : 123002.8   ±5.86%
# [10] BlockType + Feedback + BlockType:Feedback + subject                                                                                                                                                                                                                                                                                                                                        : 0.4361028  ±4.74%
# [11] BlockType + Congruency + Feedback + BlockType:Feedback + subject                                                                                                                                                                                                                                                                                                                           : 3790150    ±5.19%
# [12] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + subject                                                                                                                                                                                                                                                                                                    : 995260.2   ±6.24%
# [13] Congruency + Feedback + Congruency:Feedback + subject                                                                                                                                                                                                                                                                                                                                      : 725583.6   ±4.62%
# [14] BlockType + Congruency + Feedback + Congruency:Feedback + subject                                                                                                                                                                                                                                                                                                                          : 148421.7   ±5.59%
# [15] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + subject                                                                                                                                                                                                                                                                                                   : 36221.7    ±7.18%
# [16] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + subject                                                                                                                                                                                                                                                                                                     : 1065218    ±5.75%
# [17] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + subject                                                                                                                                                                                                                                                                              : 286862.6   ±7.74%
# [18] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + subject                                                                                                                                                                                                                                              : 78249.66   ±10.96%
# [19] BlockOrder + subject                                                                                                                                                                                                                                                                                                                                                                       : 0.5368904  ±3.33%
# [20] BlockType + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                                           : 0.1032653  ±4.2%
# [21] Congruency + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                                          : 2036724    ±4%
# [22] BlockType + Congruency + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                              : 445143.2   ±4.97%
# [23] BlockType + Congruency + BlockType:Congruency + BlockOrder + subject                                                                                                                                                                                                                                                                                                                       : 114129.2   ±5.73%
# [24] Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                                            : 0.3221837  ±3.68%
# [25] BlockType + Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                                : 0.05533732 ±4.78%
# [26] Congruency + Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                               : 1259001    ±4.35%
# [27] BlockType + Congruency + Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                   : 264882.4   ±5.39%
# [28] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                            : 77228.95   ±6.39%
# [29] BlockType + Feedback + BlockType:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                                           : 0.2387699  ±5.38%
# [30] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                              : 1998318    ±5.88%
# [31] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                       : 584199.5   ±7.14%
# [32] Congruency + Feedback + Congruency:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                                         : 436357.7   ±5.09%
# [33] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                             : 81455.32   ±6.17%
# [34] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                      : 23311.36   ±8.08%
# [35] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                        : 644891     ±7.03%
# [36] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                 : 150756.5   ±8.17%
# [37] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     subject                                                                                                                                                                                                                             : 51317.47   ±9.86%
# [38] BlockType + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                                                                    : 0.1939778  ±4.81%
# [39] BlockType + Congruency + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                                                       : 1462089    ±5.19%
# [40] BlockType + Congruency + BlockType:Congruency + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                                : 365950     ±7.31%
# [41] BlockType + Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                                                         : 0.1146335  ±5.52%
# [42] BlockType + Congruency + Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                                            : 788768.7   ±6.1%
# [43] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                     : 240797     ±7.72%
# [44] BlockType + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                                    : 0.4656674  ±5.89%
# [45] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                       : 7295158    ±6.5%
# [46] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                : 2251551    ±8.85%
# [47] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                      : 264747.5   ±8.14%
# [48] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                               : 71247.99   ±8.19%
# [49] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                 : 2111154    ±8.17%
# [50] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     subject                                                                                                                                                                                                                                      : 434705.7   ±9.36%
# [51] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + subject                                                                                                                                                                                                      : 161071.9   ±9.98%
# [52] Congruency + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                                                                  : 478404.3   ±4.8%
# [53] BlockType + Congruency + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                                                      : 98116.64   ±6.14%
# [54] BlockType + Congruency + BlockType:Congruency + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                               : 30352.55   ±6.98%
# [55] Congruency + Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                                                       : 263436.8   ±5.57%
# [56] BlockType + Congruency + Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                                           : 62411.53   ±6.07%
# [57] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                    : 15547.33   ±7.41%
# [58] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                      : 446743.8   ±7.67%
# [59] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                               : 122341.6   ±7.98%
# [60] Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                                 : 87105.57   ±6.72%
# [61] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                     : 16346.47   ±9.1%
# [62] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                              : 3962.482   ±8.73%
# [63] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                : 116937.4   ±8.34%
# [64] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder +     subject                                                                                                                                                                                                                                     : 30465.04   ±9.83%
# [65] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     Congruency:BlockOrder + subject                                                                                                                                                                                                     : 10651.13   ±11.69%
# [66] BlockType + Congruency + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                               : 305509.8   ±6.33%
# [67] BlockType + Congruency + BlockType:Congruency + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                        : 94137.59   ±8.58%
# [68] BlockType + Congruency + Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                    : 176899.2   ±8.38%
# [69] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                             : 44567.4    ±8.22%
# [70] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                               : 1331528    ±7.35%
# [71] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     subject                                                                                                                                                                                                                                    : 393494.1   ±9.18%
# [72] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                              : 56486.99   ±8.9%
# [73] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     subject                                                                                                                                                                                                                                   : 14478.88   ±9.08%
# [74] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     subject                                                                                                                                                                                                                                     : 490885.9   ±11.32%
# [75] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + subject                                                                                                                                                                                                              : 129530.6   ±13.44%
# [76] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                              : 41764.57   ±17.52%
# [77] BlockType + Congruency + BlockType:Congruency + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     subject                                                                                                                                                                                                                                  : 19401.47   ±9.16%
# [78] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     subject                                                                                                                                                                                                                       : 12951.41   ±10.39%
# [79] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     BlockType:Congruency:BlockOrder + subject                                                                                                                                                                                                  : 117636.3   ±10.95%
# [80] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     BlockType:Congruency:BlockOrder + subject                                                                                                                                                                                                 : 3258.282   ±9.43%
# [81] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     subject                                                                                                                                                                        : 28497.45   ±11.94%
# [82] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     subject                                                                                                                                        : 9902.081   ±12.98%
# [83] Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                                                      : 0.1998614  ±4.1%
# [84] BlockType + Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                                          : 0.04017296 ±5.01%
# [85] Congruency + Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                                         : 840008.8   ±4.76%
# [86] BlockType + Congruency + Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                             : 189006.7   ±5.29%
# [87] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                      : 48884.15   ±6.79%
# [88] BlockType + Feedback + BlockType:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                     : 0.1607457  ±5.96%
# [89] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                        : 1367900    ±7.07%
# [90] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                 : 313810.9   ±7.75%
# [91] Congruency + Feedback + Congruency:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                   : 243255     ±6.03%
# [92] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                       : 54593.12   ±6.79%
# [93] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                : 16889.37   ±10.02%
# [94] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                  : 368555.1   ±7.54%
# [95] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                       : 114391     ±9.84%
# [96] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     Feedback:BlockOrder + subject                                                                                                                                                                                                       : 29120.63   ±9.1%
# [97] BlockType + Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                   : 0.07444704 ±5.68%
# [98] BlockType + Congruency + Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                      : 510116.9   ±6.15%
# [99] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                               : 144320.8   ±6.8%
# [100] BlockType + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                             : 0.2868014  ±6.4%
# [101] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                : 5132223    ±7.83%
# [102] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                     : 1223282    ±8.24%
# [103] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                               : 149721.4   ±7.68%
# [104] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                    : 47578.54   ±9.63%
# [105] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                      : 1356528    ±7.77%
# [106] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Feedback:BlockOrder + subject                                                                                                                                                                                                               : 359117.6   ±8.96%
# [107] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                               : 142419.6   ±11.58%
# [108] Congruency + Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                : 174461.3   ±5.42%
# [109] BlockType + Congruency + Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                    : 39335.8    ±6.95%
# [110] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                             : 11307.57   ±8.07%
# [111] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                               : 297236.5   ±7.6%
# [112] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                    : 82452.38   ±10.15%
# [113] Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                          : 53641.26   ±6.24%
# [114] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                              : 11009.96   ±7.43%
# [115] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                   : 3248.589   ±9.91%
# [116] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                     : 84946.8    ±8.31%
# [117] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + subject                                                                                                                                                                                                              : 27306.09   ±21.43%
# [118] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     Congruency:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                              : 6360.134   ±12.02%
# ...
# [131] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + subject                                                                                                                                                 : 19165.42   ±12.06%
# [132] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + subject                                                                                                                 : 6475.035   ±14.21%
# [133] BlockType + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + BlockType:Feedback:BlockOrder + subject                                                                                                                                                                                                                                             : 0.1386111  ±7.38%
# [134] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + BlockType:Feedback:BlockOrder +     subject                                                                                                                                                                                                                            : 2331822    ±7.44%
# [135] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder +     BlockType:Feedback:BlockOrder + subject                                                                                                                                                                                                     : 683469.3   ±10.99%
# [136] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder +     BlockType:Feedback:BlockOrder + subject                                                                                                                                                                                                      : 652988.2   ±9.11%
# [137] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + subject                                                                                                                                                                               : 177354.8   ±9.47%
# [138] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Feedback:BlockOrder + BlockType:Feedback:BlockOrder +     subject                                                                                                                                           : 68187.3    ±16.53%
# [139] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     BlockType:Feedback:BlockOrder + subject                                                                                                                                                                                                    : 510302.7   ±9.7%
# [140] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + subject                                                                                                                                                                             : 113278.3   ±10.96%
# [141] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + subject                                                                                                                                                                              : 189291.5   ±9.79%
# [142] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + Feedback:BlockOrder + BlockType:Feedback:BlockOrder +     subject                                                                                                                                                   : 33548.38   ±11.99%
# [143] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     BlockType:Feedback:BlockOrder + subject                                                                                                                   : 11802.13   ±12.11%
# [144] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     BlockType:Congruency:BlockOrder + Feedback:BlockOrder + BlockType:Feedback:BlockOrder +     subject                                                                                                                                       : 32685.53   ±10.24%
# [145] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + subject                                                                                                                 : 10772.18   ±14.53%
# [146] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + subject                                                                                 : 2656.186   ±15.32%
# [147] Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + Congruency:Feedback:BlockOrder + subject                                                                                                                                                                                                                                         : 23970.99   ±7.47%
# [148] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                                                                                                                                                                         : 4338.433   ±9.75%
# [149] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     Congruency:Feedback:BlockOrder + subject                                                                                                                                                                                                  : 1171.608   ±10.61%
# [150] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     Congruency:Feedback:BlockOrder + subject                                                                                                                                                                                                    : 38092.87   ±10.36%
# [151] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + Congruency:Feedback:BlockOrder + subject                                                                                                                                                                             : 9033.102   ±11.66%
# [152] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     Congruency:BlockOrder + Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                                                                                         : 2503.627   ±12.57%
# [153] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     Congruency:Feedback:BlockOrder + subject                                                                                                                                                                                                  : 13868.57   ±11.92%
# [154] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + Congruency:Feedback:BlockOrder + subject                                                                                                                                                                           : 4247.783   ±14.35%
# [155] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + Congruency:Feedback:BlockOrder + subject                                                                                                                                                                             : 106998.5   ±12.17%
# [156] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                                                                                                  : 29289.22   ±15.96%
# [157] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     Congruency:Feedback:BlockOrder + subject                                                                                                                  : 8936.608   ±12.24%
# [158] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     BlockType:Congruency:BlockOrder + Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                                                                                     : 1025.062   ±20.55%
# [159] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + Congruency:Feedback:BlockOrder + subject                                                                                                                : 11709.79   ±27.01%
# [160] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + Congruency:Feedback:BlockOrder + subject                                                                                : 2672.507   ±21.36%
# [161] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                                                                                         : 72481.5    ±15.18%
# [162] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + Feedback:BlockOrder + BlockType:Feedback:BlockOrder +     Congruency:Feedback:BlockOrder + subject                                                                                                                  : 15412.54   ±15.04%
# [163] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     BlockType:Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                              : 5449.929   ±15.96%
# [164] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                            : 5888.991   ±30.73%
# [165] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                            : 1516.657   ±22.7%
# [166] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     BlockType:Congruency:Feedback:BlockOrder + subject : 580.8589   ±20.33%
#
# Against denominator:
#   RT ~ subject
# ---
# Bayes factor type: BFlinearModel, JZS
#                                          Pr(prior) Pr(posterior) Inclusion BF
# BlockType                                    0.886         0.804        0.528
# Congruency                                   0.886         1.000  1572803.991
# BlockType:Congruency                         0.503         0.184        0.223
# Feedback                                     0.886         0.839        0.667
# BlockType:Feedback                           0.503         0.672        2.025
# Congruency:Feedback                          0.503         0.201        0.249
# BlockType:Congruency:Feedback                0.120         0.010        0.078
# BlockOrder                                   0.886         0.771        0.431
# BlockType:BlockOrder                         0.503         0.545        1.185
# Congruency:BlockOrder                        0.503         0.142        0.163
# BlockType:Congruency:BlockOrder              0.120         0.006        0.043
# Feedback:BlockOrder                          0.503         0.322        0.469
# BlockType:Feedback:BlockOrder                0.120         0.077        0.613
# Congruency:Feedback:BlockOrder               0.120         0.006        0.042
# BlockType:Congruency:Feedback:BlockOrder     0.006         0.000        0.002
#
# Inclusion BFs compared among all models.

# %%
rawACCData_T <- read.csv('SCT_ANOVA_ACC.csv')
rawACCData_T$Accuracy <- as.numeric(as.character(rawACCData_T$Accuracy))

rawACCData_T <- within(rawACCData_T, {
  subject <- factor(subject)
  Congruency <- factor(Congruency)
  BlockType <- factor(BlockType)
    Feedback <- factor(Feedback)
    BlockOrder <- factor(BlockOrder)
})

SCT_ACC_runANOVA <- anovaBF(Accuracy ~ BlockType*Congruency*Feedback*BlockOrder + subject,
                                  data=rawACCData_T,
                                  whichRandom="subject")

png(file="Bayes_SCT_ACC.png", width = 3000, height = 700, res = 60)
plot(SCT_ACC_runANOVA)
dev.off()
print(SCT_ACC_runANOVA)
print(inclusionBF(SCT_ACC_runANOVA))
# Out:
# png
#   2
# Bayes factor analysis
# --------------
# [1] BlockType + subject                                                                                                                                                                                                                                                                                                                                                                         : 1.858416     ±1.53%
# [2] Congruency + subject                                                                                                                                                                                                                                                                                                                                                                        : 0.3552891    ±3.29%
# [3] BlockType + Congruency + subject                                                                                                                                                                                                                                                                                                                                                            : 0.6524576    ±2.09%
# [4] BlockType + Congruency + BlockType:Congruency + subject                                                                                                                                                                                                                                                                                                                                     : 0.1620217    ±3.58%
# [5] Feedback + subject                                                                                                                                                                                                                                                                                                                                                                          : 0.3479237    ±0.55%
# [6] BlockType + Feedback + subject                                                                                                                                                                                                                                                                                                                                                              : 0.6507957    ±1.36%
# [7] Congruency + Feedback + subject                                                                                                                                                                                                                                                                                                                                                             : 0.1202723    ±1.33%
# [8] BlockType + Congruency + Feedback + subject                                                                                                                                                                                                                                                                                                                                                 : 0.2205713    ±1.52%
# [9] BlockType + Congruency + BlockType:Congruency + Feedback + subject                                                                                                                                                                                                                                                                                                                          : 0.05469401   ±2.52%
# [10] BlockType + Feedback + BlockType:Feedback + subject                                                                                                                                                                                                                                                                                                                                        : 0.135311     ±1.54%
# [11] BlockType + Congruency + Feedback + BlockType:Feedback + subject                                                                                                                                                                                                                                                                                                                           : 0.04993448   ±3.01%
# [12] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + subject                                                                                                                                                                                                                                                                                                    : 0.01131871   ±2.63%
# [13] Congruency + Feedback + Congruency:Feedback + subject                                                                                                                                                                                                                                                                                                                                      : 0.04176329   ±1.59%
# [14] BlockType + Congruency + Feedback + Congruency:Feedback + subject                                                                                                                                                                                                                                                                                                                          : 0.08751704   ±4.48%
# [15] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + subject                                                                                                                                                                                                                                                                                                   : 0.01929115   ±2.81%
# [16] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + subject                                                                                                                                                                                                                                                                                                     : 0.01614274   ±1.91%
# [17] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + subject                                                                                                                                                                                                                                                                              : 0.004652956  ±5.5%
# [18] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + subject                                                                                                                                                                                                                                              : 0.004681671  ±6.46%
# [19] BlockOrder + subject                                                                                                                                                                                                                                                                                                                                                                       : 0.4971207    ±3.25%
# [20] BlockType + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                                           : 0.9873611    ±6.79%
# [21] Congruency + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                                          : 0.1626508    ±1.13%
# [22] BlockType + Congruency + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                              : 0.3197204    ±2.49%
# [23] BlockType + Congruency + BlockType:Congruency + BlockOrder + subject                                                                                                                                                                                                                                                                                                                       : 0.2496822    ±67.64%
# [24] Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                                            : 0.1653788    ±0.8%
# [25] BlockType + Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                                : 0.3233268    ±2.29%
# [26] Congruency + Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                               : 0.0602075    ±2.42%
# [27] BlockType + Congruency + Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                                                   : 0.1177014    ±4.2%
# [28] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                            : 0.02665441   ±2.42%
# [29] BlockType + Feedback + BlockType:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                                           : 0.1052822    ±34.07%
# [30] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                              : 0.02370093   ±2.75%
# [31] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                       : 0.005556747  ±3.01%
# [32] Congruency + Feedback + Congruency:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                                         : 0.02222618   ±6.44%
# [33] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                                             : 0.04048438   ±4.12%
# [34] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                      : 0.01078902   ±8.76%
# [35] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                                        : 0.008654115  ±3.82%
# [36] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + subject                                                                                                                                                                                                                                                                 : 0.002142022  ±4.94%
# [37] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     subject                                                                                                                                                                                                                             : 0.002072411  ±3.27%
# [38] BlockType + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                                                                    : 4.588581     ±1.91%
# [39] BlockType + Congruency + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                                                       : 1.775853     ±4.7%
# [40] BlockType + Congruency + BlockType:Congruency + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                                : 0.4453406    ±5.06%
# [41] BlockType + Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                                                         : 1.63767      ±2.56%
# [42] BlockType + Congruency + Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                                            : 0.5954893    ±2.12%
# [43] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                     : 0.1669927    ±6.22%
# [44] BlockType + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                                    : 0.3535014    ±2.82%
# [45] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                       : 0.1324379    ±3.73%
# [46] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                : 0.0344006    ±6.61%
# [47] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                                      : 0.2152183    ±2.44%
# [48] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                               : 0.05319852   ±3.77%
# [49] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + subject                                                                                                                                                                                                                                                                 : 0.05278949   ±6.34%
# [50] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     subject                                                                                                                                                                                                                                      : 0.01297315   ±9.73%
# [51] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + subject                                                                                                                                                                                                      : 0.01254768   ±4.2%
# [52] Congruency + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                                                                  : 0.04389902   ±1.8%
# [53] BlockType + Congruency + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                                                      : 0.08488935   ±2.38%
# [54] BlockType + Congruency + BlockType:Congruency + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                               : 0.02042101   ±3.29%
# [55] Congruency + Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                                                       : 0.01575674   ±2.25%
# [56] BlockType + Congruency + Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                                           : 0.02969238   ±2.67%
# [57] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                    : 0.008781452  ±17.31%
# [58] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                      : 0.006675927  ±4.75%
# [59] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                               : 0.001474154  ±4.53%
# [60] Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                                 : 0.005532156  ±2.84%
# [61] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                     : 0.01195376   ±5.9%
# [62] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                              : 0.002757398  ±7.07%
# [63] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                : 0.002466189  ±4.2%
# [64] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder +     subject                                                                                                                                                                                                                                     : 0.0005647172 ±4.53%
# [65] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     Congruency:BlockOrder + subject                                                                                                                                                                                                     : 0.0005677174 ±5.14%
# [66] BlockType + Congruency + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                               : 0.4513774    ±4.28%
# [67] BlockType + Congruency + BlockType:Congruency + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                        : 0.1210823    ±5.68%
# [68] BlockType + Congruency + Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                                                    : 0.1707484    ±4.44%
# [69] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                             : 0.04421706   ±8.08%
# [70] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                               : 0.0346873    ±4.33%
# [71] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     subject                                                                                                                                                                                                                                    : 0.009053466  ±7.37%
# [72] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                                                                                                              : 0.05786985   ±4.07%
# [73] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     subject                                                                                                                                                                                                                                   : 0.0143949    ±5.36%
# [74] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     subject                                                                                                                                                                                                                                     : 0.01540512   ±20.04%
# [75] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + subject                                                                                                                                                                                                              : 0.003777887  ±11.96%
# [76] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + subject                                                                                                                                                                              : 0.004371301  ±25.34%
# [77] BlockType + Congruency + BlockType:Congruency + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     subject                                                                                                                                                                                                                                  : 0.08622569   ±15.01%
# [78] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     subject                                                                                                                                                                                                                       : 0.02200607   ±6.11%
# [79] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     BlockType:Congruency:BlockOrder + subject                                                                                                                                                                                                  : 0.004179571  ±4.04%
# [80] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     BlockType:Congruency:BlockOrder + subject                                                                                                                                                                                                 : 0.007338432  ±3.98%
# [81] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     subject                                                                                                                                                                        : 0.001979871  ±11.97%
# [82] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     subject                                                                                                                                        : 0.00199197   ±8.08%
# [83] Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                                                      : 0.06656778   ±1.47%
# [84] BlockType + Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                                          : 0.1220986    ±1.57%
# [85] Congruency + Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                                         : 0.0247312    ±4.23%
# [86] BlockType + Congruency + Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                             : 0.04524801   ±3.53%
# [87] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                      : 0.01127539   ±6.82%
# [88] BlockType + Feedback + BlockType:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                     : 0.02758866   ±3.44%
# [89] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                        : 0.009394835  ±2.92%
# [90] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                 : 0.00225624   ±3.69%
# [91] Congruency + Feedback + Congruency:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                   : 0.009388479  ±11.97%
# [92] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                       : 0.01640806   ±4.38%
# [93] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                : 0.003776796  ±4.12%
# [94] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                  : 0.00353646   ±7.01%
# [95] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                       : 0.0007680885 ±3.46%
# [96] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     Feedback:BlockOrder + subject                                                                                                                                                                                                       : 0.001108219  ±14.97%
# [97] BlockType + Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                   : 0.6827094    ±2.72%
# [98] BlockType + Congruency + Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                      : 0.2373291    ±2.82%
# [99] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                               : 0.05845468   ±3.12%
# [100] BlockType + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                             : 0.1464814    ±5.38%
# [101] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                : 0.05548997   ±9.76%
# [102] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                     : 0.01251707   ±4.69%
# [103] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                               : 0.08968693   ±3.82%
# [104] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                    : 0.02286388   ±5.07%
# [105] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                      : 0.0241425    ±7.53%
# [106] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Feedback:BlockOrder + subject                                                                                                                                                                                                               : 0.004650045  ±4.54%
# [107] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                               : 0.004960556  ±5.26%
# [108] Congruency + Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                                : 0.006091579  ±3.3%
# [109] BlockType + Congruency + Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                                    : 0.01198247   ±3.6%
# [110] BlockType + Congruency + BlockType:Congruency + Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                             : 0.002867552  ±4.51%
# [111] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                               : 0.002733556  ±6.27%
# [112] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                    : 0.0007185203 ±8.2%
# [113] Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                                          : 0.002075762  ±2.88%
# [114] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                                                                                                              : 0.004425937  ±5.25%
# [115] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                   : 0.000998069  ±3.64%
# [116] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     subject                                                                                                                                                                                                                                     : 0.0008781038 ±8.58%
# [117] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + subject                                                                                                                                                                                                              : 0.0002316785 ±6.66%
# [118] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     Congruency:BlockOrder + Feedback:BlockOrder + subject                                                                                                                                                                              : 0.0002241257 ±5.48%
# ...
# [132] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + subject                                                                                                                 : 0.0008162615 ±11.06%
# [133] BlockType + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + BlockType:Feedback:BlockOrder + subject                                                                                                                                                                                                                                             : 0.03919839   ±4.52%
# [134] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder + BlockType:Feedback:BlockOrder +     subject                                                                                                                                                                                                                            : 0.01554088   ±5.98%
# [135] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder +     BlockType:Feedback:BlockOrder + subject                                                                                                                                                                                                     : 0.003546487  ±7.38%
# [136] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Feedback:BlockOrder +     BlockType:Feedback:BlockOrder + subject                                                                                                                                                                                                      : 0.005406882  ±4.98%
# [137] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + subject                                                                                                                                                                               : 0.001215646  ±4.46%
# [138] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Feedback:BlockOrder + BlockType:Feedback:BlockOrder +     subject                                                                                                                                           : 0.001539312  ±10.96%
# [139] BlockType + Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     BlockType:Feedback:BlockOrder + subject                                                                                                                                                                                                    : 0.004168343  ±7.92%
# [140] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + subject                                                                                                                                                                             : 0.001000688  ±10.13%
# [141] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + subject                                                                                                                                                                              : 0.001505624  ±7.13%
# [142] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + Feedback:BlockOrder + BlockType:Feedback:BlockOrder +     subject                                                                                                                                                   : 0.000356258  ±6.49%
# [143] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     BlockType:Feedback:BlockOrder + subject                                                                                                                   : 0.0006679812 ±17.25%
# [144] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     BlockType:Congruency:BlockOrder + Feedback:BlockOrder + BlockType:Feedback:BlockOrder +     subject                                                                                                                                       : 0.000546244  ±14.19%
# [145] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + subject                                                                                                                 : 0.0002194455 ±20.75%
# [146] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + subject                                                                                 : 0.0002552324 ±14.73%
# [147] Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + Congruency:Feedback:BlockOrder + subject                                                                                                                                                                                                                                         : 0.001521633  ±54.39%
# [148] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                                                                                                                                                                         : 0.001349894  ±4.05%
# [149] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     Congruency:Feedback:BlockOrder + subject                                                                                                                                                                                                  : 0.0003375924 ±5.3%
# [150] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     Congruency:Feedback:BlockOrder + subject                                                                                                                                                                                                    : 0.0003409188 ±9.25%
# [151] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + Congruency:Feedback:BlockOrder + subject                                                                                                                                                                             : 6.843648e-05 ±6.31%
# [152] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     Congruency:BlockOrder + Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                                                                                         : 6.809222e-05 ±5.15%
# [153] BlockType + Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     Congruency:Feedback:BlockOrder + subject                                                                                                                                                                                                  : 0.008534843  ±9.15%
# [154] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + Congruency:Feedback:BlockOrder + subject                                                                                                                                                                           : 0.00200562   ±5.55%
# [155] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + Congruency:Feedback:BlockOrder + subject                                                                                                                                                                             : 0.001538018  ±5.7%
# [156] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                                                                                                  : 0.0004236562 ±8.65%
# [157] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     Congruency:Feedback:BlockOrder + subject                                                                                                                  : 0.0004655869 ±6.89%
# [158] BlockType + Congruency + BlockType:Congruency + Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     BlockType:Congruency:BlockOrder + Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                                                                                     : 0.001128715  ±14.82%
# [159] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + Congruency:Feedback:BlockOrder + subject                                                                                                                : 0.0001882495 ±5.16%
# [160] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + Congruency:Feedback:BlockOrder + subject                                                                                : 0.0002723962 ±12.65%
# [161] BlockType + Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder + Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                                                                                         : 0.0004643054 ±6.15%
# [162] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + Feedback:BlockOrder + BlockType:Feedback:BlockOrder +     Congruency:Feedback:BlockOrder + subject                                                                                                                  : 0.0001006694 ±7.58%
# [163] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + Feedback:BlockOrder +     BlockType:Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                              : 0.0001129727 ±6.34%
# [164] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockOrder + BlockType:BlockOrder +     Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                                                            : 6.145938e-05 ±10.84%
# [165] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     subject                                            : 6.791964e-05 ±6.14%
# [166] BlockType + Congruency + BlockType:Congruency + Feedback + BlockType:Feedback + Congruency:Feedback + BlockType:Congruency:Feedback + BlockOrder +     BlockType:BlockOrder + Congruency:BlockOrder + BlockType:Congruency:BlockOrder +     Feedback:BlockOrder + BlockType:Feedback:BlockOrder + Congruency:Feedback:BlockOrder +     BlockType:Congruency:Feedback:BlockOrder + subject : 2.589887e-05 ±13.89%
#
# Against denominator:
#   Accuracy ~ subject
# ---
# Bayes factor type: BFlinearModel, JZS
#                                          Pr(prior) Pr(posterior) Inclusion BF
# BlockType                                    0.886         0.867        0.840
# Congruency                                   0.886         0.383        0.080
# BlockType:Congruency                         0.503         0.082        0.088
# Feedback                                     0.886         0.377        0.078
# BlockType:Feedback                           0.503         0.066        0.069
# Congruency:Feedback                          0.503         0.045        0.047
# BlockType:Congruency:Feedback                0.120         0.002        0.013
# BlockOrder                                   0.886         0.740        0.365
# BlockType:BlockOrder                         0.503         0.571        1.316
# Congruency:BlockOrder                        0.503         0.067        0.071
# BlockType:Congruency:BlockOrder              0.120         0.006        0.047
# Feedback:BlockOrder                          0.503         0.088        0.096
# BlockType:Feedback:BlockOrder                0.120         0.003        0.025
# Congruency:Feedback:BlockOrder               0.120         0.001        0.006
# BlockType:Congruency:Feedback:BlockOrder     0.006         0.000        0.000
#
# Inclusion BFs compared among all models.

# %%
IEdata_T <- read.csv('IE_transfer.csv')
IEdata_T$IE <- as.numeric(as.character(IEdata_T$IE))

IEdata_T <- within(IEdata_T, {
  SubjectID <- factor(SubjectID)
  CueType <- factor(CueType)
  TrialType <- factor(TrialType)
  Feedback <- factor(Feedback)
  BlockOrder <- factor(BlockOrder)
})

SC_IET_runANOVA <- anovaBF(IE ~ CueType*TrialType*Feedback*BlockOrder + SubjectID,
                           data=IEdata_T,
                           whichRandom="SubjectID")

png(file="Bayes_SC_IE_T.png", width = 3000, height = 700, res = 60)
plot(SC_IET_runANOVA)
dev.off()
print(SC_IET_runANOVA)
print(inclusionBF(SC_IET_runANOVA))
# Out:
# png
#   2
# Bayes factor analysis
# --------------
# [1] Feedback + SubjectID                                                                                                                                                                                                                                                                                                                                                  : 0.3461633    ±0.82%
# [2] BlockOrder + SubjectID                                                                                                                                                                                                                                                                                                                                                : 0.4146024    ±0.51%
# [3] Feedback + BlockOrder + SubjectID                                                                                                                                                                                                                                                                                                                                     : 0.1409354    ±1.11%
# [4] Feedback + BlockOrder + Feedback:BlockOrder + SubjectID                                                                                                                                                                                                                                                                                                               : 0.06104195   ±3.34%
# [5] TrialType + SubjectID                                                                                                                                                                                                                                                                                                                                                 : 1.824212     ±1.49%
# [6] Feedback + TrialType + SubjectID                                                                                                                                                                                                                                                                                                                                      : 0.6658691    ±3.75%
# [7] BlockOrder + TrialType + SubjectID                                                                                                                                                                                                                                                                                                                                    : 0.7490953    ±1.07%
# [8] Feedback + BlockOrder + TrialType + SubjectID                                                                                                                                                                                                                                                                                                                         : 0.2637794    ±1.81%
# [9] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + SubjectID                                                                                                                                                                                                                                                                                                   : 0.1258421    ±3.96%
# [10] Feedback + TrialType + Feedback:TrialType + SubjectID                                                                                                                                                                                                                                                                                                                : 0.1997617    ±2.57%
# [11] Feedback + BlockOrder + TrialType + Feedback:TrialType + SubjectID                                                                                                                                                                                                                                                                                                   : 0.08046106   ±2.2%
# [12] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + SubjectID                                                                                                                                                                                                                                                                             : 0.03776849   ±5.24%
# [13] BlockOrder + TrialType + BlockOrder:TrialType + SubjectID                                                                                                                                                                                                                                                                                                            : 0.1505799    ±2.75%
# [14] Feedback + BlockOrder + TrialType + BlockOrder:TrialType + SubjectID                                                                                                                                                                                                                                                                                                 : 0.05628173   ±3.17%
# [15] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + SubjectID                                                                                                                                                                                                                                                                           : 0.02236484   ±5.07%
# [16] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + SubjectID                                                                                                                                                                                                                                                                            : 0.02092597   ±23.98%
# [17] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + SubjectID                                                                                                                                                                                                                                                      : 0.007244473  ±6.08%
# [18] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + SubjectID                                                                                                                                                                                                                      : 0.003335664  ±6.13%
# [19] CueType + SubjectID                                                                                                                                                                                                                                                                                                                                                  : 1.975211     ±1.12%
# [20] Feedback + CueType + SubjectID                                                                                                                                                                                                                                                                                                                                       : 0.7017501    ±2.26%
# [21] BlockOrder + CueType + SubjectID                                                                                                                                                                                                                                                                                                                                     : 0.8321197    ±2.91%
# [22] Feedback + BlockOrder + CueType + SubjectID                                                                                                                                                                                                                                                                                                                          : 0.2800686    ±1.84%
# [23] Feedback + BlockOrder + Feedback:BlockOrder + CueType + SubjectID                                                                                                                                                                                                                                                                                                    : 0.1248599    ±3.91%
# [24] TrialType + CueType + SubjectID                                                                                                                                                                                                                                                                                                                                      : 3.794312     ±1.21%
# [25] Feedback + TrialType + CueType + SubjectID                                                                                                                                                                                                                                                                                                                           : 1.499119     ±9.86%
# [26] BlockOrder + TrialType + CueType + SubjectID                                                                                                                                                                                                                                                                                                                         : 1.715202     ±2.5%
# [27] Feedback + BlockOrder + TrialType + CueType + SubjectID                                                                                                                                                                                                                                                                                                              : 0.5869073    ±2.96%
# [28] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + CueType + SubjectID                                                                                                                                                                                                                                                                                        : 0.2453613    ±4.83%
# [29] Feedback + TrialType + Feedback:TrialType + CueType + SubjectID                                                                                                                                                                                                                                                                                                      : 0.421701     ±4.19%
# [30] Feedback + BlockOrder + TrialType + Feedback:TrialType + CueType + SubjectID                                                                                                                                                                                                                                                                                         : 0.188738     ±4.82%
# [31] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + CueType + SubjectID                                                                                                                                                                                                                                                                   : 0.08475399   ±5.27%
# [32] BlockOrder + TrialType + BlockOrder:TrialType + CueType + SubjectID                                                                                                                                                                                                                                                                                                  : 0.3115108    ±3.01%
# [33] Feedback + BlockOrder + TrialType + BlockOrder:TrialType + CueType + SubjectID                                                                                                                                                                                                                                                                                       : 0.1226008    ±8.06%
# [34] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + CueType + SubjectID                                                                                                                                                                                                                                                                 : 0.04904153   ±5.36%
# [35] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + SubjectID                                                                                                                                                                                                                                                                  : 0.05008509   ±27.66%
# [36] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + SubjectID                                                                                                                                                                                                                                            : 0.01804575   ±7.01%
# [37] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     SubjectID                                                                                                                                                                                                        : 0.007492976  ±8.31%
# [38] Feedback + CueType + Feedback:CueType + SubjectID                                                                                                                                                                                                                                                                                                                    : 0.1440389    ±2.2%
# [39] Feedback + BlockOrder + CueType + Feedback:CueType + SubjectID                                                                                                                                                                                                                                                                                                       : 0.06071799   ±2.17%
# [40] Feedback + BlockOrder + Feedback:BlockOrder + CueType + Feedback:CueType + SubjectID                                                                                                                                                                                                                                                                                 : 0.02840214   ±4.99%
# [41] Feedback + TrialType + CueType + Feedback:CueType + SubjectID                                                                                                                                                                                                                                                                                                        : 0.3011616    ±3.26%
# [42] Feedback + BlockOrder + TrialType + CueType + Feedback:CueType + SubjectID                                                                                                                                                                                                                                                                                           : 0.1352267    ±11.55%
# [43] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + CueType + Feedback:CueType + SubjectID                                                                                                                                                                                                                                                                     : 0.06165324   ±5.93%
# [44] Feedback + TrialType + Feedback:TrialType + CueType + Feedback:CueType + SubjectID                                                                                                                                                                                                                                                                                   : 0.08814296   ±3.33%
# [45] Feedback + BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + SubjectID                                                                                                                                                                                                                                                                      : 0.03678313   ±4.54%
# [46] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + SubjectID                                                                                                                                                                                                                                                : 0.0196369    ±7.86%
# [47] Feedback + BlockOrder + TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + SubjectID                                                                                                                                                                                                                                                                    : 0.0249993    ±3.51%
# [48] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + SubjectID                                                                                                                                                                                                                                              : 0.01143232   ±6.65%
# [49] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + SubjectID                                                                                                                                                                                                                                               : 0.008155743  ±6.62%
# [50] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + SubjectID                                                                                                                                                                                                                         : 0.003457646  ±9.08%
# [51] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     Feedback:CueType + SubjectID                                                                                                                                                                                     : 0.001623954  ±9.36%
# [52] BlockOrder + CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                                                                                : 39.7047      ±1.99%
# [53] Feedback + BlockOrder + CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                                                                     : 13.46096     ±3.49%
# [54] Feedback + BlockOrder + Feedback:BlockOrder + CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                                               : 6.406154     ±4.43%
# [55] BlockOrder + TrialType + CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                                                                    : 94.41017     ±3.05%
# [56] Feedback + BlockOrder + TrialType + CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                                                         : 34.18797     ±4.5%
# [57] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                                   : 13.82027     ±5.53%
# [58] Feedback + BlockOrder + TrialType + Feedback:TrialType + CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                                    : 10.93147     ±5.15%
# [59] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                              : 5.28683      ±6.76%
# [60] BlockOrder + TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                                             : 17.81307     ±3.03%
# [61] Feedback + BlockOrder + TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                                  : 7.058938     ±5.27%
# [62] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                            : 2.841518     ±6.06%
# [63] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                             : 1.966521     ±5.49%
# [64] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                       : 0.8564373    ±6.68%
# [65] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     BlockOrder:CueType + SubjectID                                                                                                                                                                                   : 0.5178501    ±9.2%
# [66] Feedback + BlockOrder + CueType + Feedback:CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                                                  : 2.936311     ±4.6%
# [67] Feedback + BlockOrder + Feedback:BlockOrder + CueType + Feedback:CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                            : 1.317182     ±5.42%
# [68] Feedback + BlockOrder + TrialType + CueType + Feedback:CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                                      : 7.706947     ±5.48%
# [69] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + CueType + Feedback:CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                : 3.726383     ±6.44%
# [70] Feedback + BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                                 : 2.305831     ±6.1%
# [71] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                           : 1.110549     ±7.47%
# [72] Feedback + BlockOrder + TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                                               : 1.521502     ±6.61%
# [73] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                         : 0.6907084    ±6.76%
# [74] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                                                                          : 0.5599329    ±6.79%
# [75] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType +     SubjectID                                                                                                                                                                                                : 0.2462562    ±9.27%
# [76] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     Feedback:CueType + BlockOrder:CueType + SubjectID                                                                                                                                                                : 0.1420239    ±9.7%
# [77] Feedback + BlockOrder + Feedback:BlockOrder + CueType + Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType + SubjectID                                                                                                                                                                                                                              : 0.3780047    ±5.81%
# [78] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + CueType + Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType +     SubjectID                                                                                                                                                                                                              : 0.9776826    ±7.03%
# [79] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType +     SubjectID                                                                                                                                                                                         : 0.3514431    ±12.9%
# [80] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType +     SubjectID                                                                                                                                                                                       : 0.1617858    ±7.34%
# [81] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType +     Feedback:BlockOrder:CueType + SubjectID                                                                                                                                                                  : 0.07482171   ±12.45%
# [82] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType +     SubjectID                                                                                                                              : 0.03015773   ±11.93%
# [83] TrialType + CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                                                                                  : 0.9362596    ±3.03%
# [84] Feedback + TrialType + CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                                                                       : 0.3184248    ±4.48%
# [85] BlockOrder + TrialType + CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                                                                     : 0.3849521    ±2.58%
# [86] Feedback + BlockOrder + TrialType + CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                                                          : 0.1418151    ±6.22%
# [87] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                                    : 0.06722233   ±5.38%
# [88] Feedback + TrialType + Feedback:TrialType + CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                                                  : 0.1092953    ±5.43%
# [89] Feedback + BlockOrder + TrialType + Feedback:TrialType + CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                                     : 0.04101856   ±3.76%
# [90] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                               : 0.01913129   ±5.92%
# [91] BlockOrder + TrialType + BlockOrder:TrialType + CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                                              : 0.07977035   ±4.06%
# [92] Feedback + BlockOrder + TrialType + BlockOrder:TrialType + CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                                   : 0.02911579   ±13.15%
# [93] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                             : 0.01123343   ±5.74%
# [94] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                              : 0.007485363  ±4.17%
# [95] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                        : 0.004192193  ±8.99%
# [96] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     TrialType:CueType + SubjectID                                                                                                                                                                                    : 0.001590368  ±7.65%
# [97] Feedback + TrialType + CueType + Feedback:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                                                    : 0.08449412   ±14.45%
# [98] Feedback + BlockOrder + TrialType + CueType + Feedback:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                                       : 0.02830829   ±3.43%
# [99] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + CueType + Feedback:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                 : 0.01425618   ±7.14%
# [100] Feedback + TrialType + Feedback:TrialType + CueType + Feedback:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                              : 0.0199054    ±3.28%
# [101] Feedback + BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                 : 0.009084517  ±6.15%
# [102] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                           : 0.004726209  ±6.82%
# [103] Feedback + BlockOrder + TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                               : 0.008301493  ±30.9%
# [104] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                         : 0.002440551  ±7.36%
# [105] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                          : 0.001653781  ±3.85%
# [106] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + TrialType:CueType +     SubjectID                                                                                                                                                                                                : 0.0008293033 ±9.08%
# [107] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     Feedback:CueType + TrialType:CueType + SubjectID                                                                                                                                                                : 0.0004207614 ±11.7%
# [108] BlockOrder + TrialType + CueType + BlockOrder:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                                               : 21.51832     ±3.98%
# [109] Feedback + BlockOrder + TrialType + CueType + BlockOrder:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                                    : 8.476876     ±5.21%
# [110] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + CueType + BlockOrder:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                              : 4.104104     ±6.74%
# [111] Feedback + BlockOrder + TrialType + Feedback:TrialType + CueType + BlockOrder:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                               : 2.671346     ±6.03%
# [112] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + CueType + BlockOrder:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                         : 1.299451     ±7.91%
# [113] BlockOrder + TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                        : 4.67683      ±6%
# [114] Feedback + BlockOrder + TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                             : 1.621337     ±6.44%
# [115] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                       : 0.6847033    ±7.03%
# [116] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                        : 0.5272525    ±7.57%
# [117] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + TrialType:CueType +     SubjectID                                                                                                                                                                                              : 0.2457785    ±9.39%
# [118] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     BlockOrder:CueType + TrialType:CueType + SubjectID                                                                                                                                                              : 0.1019326    ±7.76%
# [119] Feedback + BlockOrder + TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType + SubjectID                                                                                                                                                                                                                                                 : 2.057893     ±6.89%
# [120] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     SubjectID                                                                                                                                                                                                                       : 0.8222147    ±6.44%
# [121] Feedback + BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     SubjectID                                                                                                                                                                                                                        : 0.6276622    ±7.07%
# [122] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     SubjectID                                                                                                                                                                                                  : 0.2638934    ±7.61%
# [123] Feedback + BlockOrder + TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     SubjectID                                                                                                                                                                                                                      : 0.4026182    ±7.62%
# [124] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     SubjectID                                                                                                                                                                                                : 0.1767236    ±8.46%
# ...
# [129] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType +     TrialType:CueType + SubjectID                                                                                                                                                                    : 0.08170812   ±10.42%
# [130] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType +     TrialType:CueType + SubjectID                                                                                                                                                                  : 0.05339526   ±11.25%
# [131] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType +     Feedback:BlockOrder:CueType + TrialType:CueType + SubjectID                                                                                                                                             : 0.0134865    ±9.63%
# [132] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType +     TrialType:CueType + SubjectID                                                                                                         : 0.007285236  ±14.19%
# [133] Feedback + TrialType + Feedback:TrialType + CueType + Feedback:CueType + TrialType:CueType + Feedback:TrialType:CueType + SubjectID                                                                                                                                                                                                                                 : 0.01382302   ±7.28%
# [134] Feedback + BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + TrialType:CueType + Feedback:TrialType:CueType +     SubjectID                                                                                                                                                                                                                : 0.005523012  ±8.8%
# [135] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + TrialType:CueType + Feedback:TrialType:CueType +     SubjectID                                                                                                                                                                                          : 0.002866601  ±9.49%
# [136] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + TrialType:CueType + Feedback:TrialType:CueType +     SubjectID                                                                                                                                                                                         : 0.001092842  ±7.18%
# [137] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + TrialType:CueType +     Feedback:TrialType:CueType + SubjectID                                                                                                                                                                   : 0.0005169891 ±12.9%
# [138] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     Feedback:CueType + TrialType:CueType + Feedback:TrialType:CueType +     SubjectID                                                                                                                               : 0.0002827125 ±12.93%
# [139] Feedback + BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     Feedback:TrialType:CueType + SubjectID                                                                                                                                                                                           : 0.3994028    ±8.99%
# [140] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     Feedback:TrialType:CueType + SubjectID                                                                                                                                                                     : 0.1805638    ±10.09%
# [141] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     Feedback:TrialType:CueType + SubjectID                                                                                                                                                                    : 0.07591617   ±11.22%
# [142] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType +     TrialType:CueType + Feedback:TrialType:CueType + SubjectID                                                                                                                                              : 0.02921617   ±10.69%
# [143] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     Feedback:TrialType:CueType + SubjectID                                                                                                          : 0.01389982   ±14.6%
# [144] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType +     TrialType:CueType + Feedback:TrialType:CueType + SubjectID                                                                                                                                       : 0.04024032   ±8.6%
# [145] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType +     Feedback:BlockOrder:CueType + TrialType:CueType + Feedback:TrialType:CueType +     SubjectID                                                                                                            : 0.01279976   ±16.86%
# [146] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType +     TrialType:CueType + Feedback:TrialType:CueType + SubjectID                                                                            : 0.005449541  ±14.98%
# [147] BlockOrder + TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + TrialType:CueType + BlockOrder:TrialType:CueType + SubjectID                                                                                                                                                                                                                         : 1.840107     ±3.5%
# [148] Feedback + BlockOrder + TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + TrialType:CueType + BlockOrder:TrialType:CueType +     SubjectID                                                                                                                                                                                                          : 0.7074053    ±7.6%
# [149] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + TrialType:CueType + BlockOrder:TrialType:CueType +     SubjectID                                                                                                                                                                                    : 0.3851337    ±7.84%
# [150] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + TrialType:CueType + BlockOrder:TrialType:CueType +     SubjectID                                                                                                                                                                                     : 0.2210885    ±7.92%
# [151] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + BlockOrder:CueType + TrialType:CueType +     BlockOrder:TrialType:CueType + SubjectID                                                                                                                                                               : 0.09072996   ±8.14%
# [152] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     BlockOrder:CueType + TrialType:CueType + BlockOrder:TrialType:CueType +     SubjectID                                                                                                                           : 0.05065451   ±11.08%
# [153] Feedback + BlockOrder + TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     BlockOrder:TrialType:CueType + SubjectID                                                                                                                                                                                       : 0.1647634    ±8.56%
# [154] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     BlockOrder:TrialType:CueType + SubjectID                                                                                                                                                                 : 0.08277442   ±10.5%
# [155] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     BlockOrder:TrialType:CueType + SubjectID                                                                                                                                                                  : 0.0576882    ±8.85%
# [156] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType +     TrialType:CueType + BlockOrder:TrialType:CueType + SubjectID                                                                                                                                            : 0.02396066   ±11.38%
# [157] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     BlockOrder:TrialType:CueType + SubjectID                                                                                                        : 0.0106918    ±11.33%
# [158] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType +     TrialType:CueType + BlockOrder:TrialType:CueType + SubjectID                                                                                                                                   : 0.02008737   ±10.8%
# [159] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType +     Feedback:BlockOrder:CueType + TrialType:CueType + BlockOrder:TrialType:CueType +     SubjectID                                                                                                          : 0.008542235  ±24.09%
# [160] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType +     TrialType:CueType + BlockOrder:TrialType:CueType + SubjectID                                                                          : 0.003304725  ±19.84%
# [161] Feedback + BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     Feedback:TrialType:CueType + BlockOrder:TrialType:CueType +     SubjectID                                                                                                                                 : 0.03733794   ±11.17%
# [162] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType +     TrialType:CueType + Feedback:TrialType:CueType + BlockOrder:TrialType:CueType +     SubjectID                                                                                                           : 0.0155852    ±10.26%
# [163] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     Feedback:CueType + BlockOrder:CueType + TrialType:CueType +     Feedback:TrialType:CueType + BlockOrder:TrialType:CueType +     SubjectID                                                                       : 0.007999839  ±14.43%
# [164] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + CueType + Feedback:CueType + BlockOrder:CueType +     Feedback:BlockOrder:CueType + TrialType:CueType + Feedback:TrialType:CueType +     BlockOrder:TrialType:CueType + SubjectID                                                                             : 0.004239993  ±13.85%
# [165] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType +     TrialType:CueType + Feedback:TrialType:CueType + BlockOrder:TrialType:CueType +     SubjectID                                         : 0.002293464  ±17.05%
# [166] Feedback + BlockOrder + Feedback:BlockOrder + TrialType + Feedback:TrialType + BlockOrder:TrialType + Feedback:BlockOrder:TrialType + CueType +     Feedback:CueType + BlockOrder:CueType + Feedback:BlockOrder:CueType +     TrialType:CueType + Feedback:TrialType:CueType + BlockOrder:TrialType:CueType +     Feedback:BlockOrder:TrialType:CueType + SubjectID : 0.0007231011 ±13.04%
#
# Against denominator:
#   IE ~ SubjectID
# ---
# Bayes factor type: BFlinearModel, JZS
#                                       Pr(prior) Pr(posterior) Inclusion BF
# Feedback                                  0.886         0.447        0.104
# BlockOrder                                0.886         0.959        2.994
# Feedback:BlockOrder                       0.503         0.140        0.161
# TrialType                                 0.886         0.800        0.513
# Feedback:TrialType                        0.503         0.095        0.103
# BlockOrder:TrialType                      0.503         0.137        0.157
# Feedback:BlockOrder:TrialType             0.120         0.003        0.020
# CueType                                   0.886         0.982        7.182
# Feedback:CueType                          0.503         0.090        0.097
# BlockOrder:CueType                        0.503         0.936       14.473
# Feedback:BlockOrder:CueType               0.120         0.007        0.053
# TrialType:CueType                         0.503         0.164        0.194
# Feedback:TrialType:CueType                0.120         0.002        0.018
# BlockOrder:TrialType:CueType              0.120         0.011        0.079
# Feedback:BlockOrder:TrialType:CueType     0.006         0.000        0.000
#
# Inclusion BFs compared among all models.
